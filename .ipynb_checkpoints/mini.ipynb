# %%
import csv
import itertools
import os
import random
import sys


def read_students(start_index=0, count=50, filepath="records.csv"):
    """Read up to count students starting from start_index (after header).
    Returns a list of student dicts with keys: tutorial group, id, school, name, gender, gpa
    """
    students = []

    with open(filepath, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        headers = next(reader, None)  # skip header if present

        # skip start_index rows
        for _ in range(start_index):
            try:
                next(reader)
            except StopIteration:
                return students

        for _ in range(count):
            try:
                row = next(reader)
            except StopIteration:
                break

            try:
                gpa = float(row[5])
            except Exception:
                # skip rows with non-numeric GPA
                continue

            student = {
                'tutorial group': row[0].strip(),
                'id': row[1].strip(),
                'school': row[2].strip(),
                'name': row[3].strip(),
                'gender': row[4].strip(),
                'gpa': gpa,
            }
            students.append(student)

    return students
    
read_students(start_index=0, count=50, filepath="records.csv")
# Out:
# [{'tutorial group': 'G-1',
#   'id': '5002',
#   'school': 'CCDS',
#   'name': 'Aarav Singh',
#   'gender': 'Male',
#   'gpa': 4.02},
#  {'tutorial group': 'G-1',
#   'id': '3838',
#   'school': 'EEE',
#   'name': 'Aarti Nair',
#   'gender': 'Female',
#   'gpa': 4.05},
#  {'tutorial group': 'G-1',
#   'id': '2091',
#   'school': 'EEE',
#   'name': 'Adlan Bin Rahman',
#   'gender': 'Male',
#   'gpa': 4.2},
#  {'tutorial group': 'G-1',
#   'id': '288',
#   'school': 'CoB (NBS)',
#   'name': 'Ajay Verma',
#   'gender': 'Male',
#   'gpa': 4.01},
#  {'tutorial group': 'G-1',
#   'id': '4479',
#   'school': 'CCDS',
#   'name': 'Amelia Kim',
#   'gender': 'Female',
#   'gpa': 4.11},
#  {'tutorial group': 'G-1',
#   'id': '5708',
#   'school': 'SoH',
#   'name': 'Ananya Ramesh',
#   'gender': 'Male',
#   'gpa': 4.2},
#  {'tutorial group': 'G-1',
#   'id': '4563',
#   'school': 'WKW SCI',
#   'name': 'Anjali Patel',
#   'gender': 'Female',
#   'gpa': 4.01},
#  {'tutorial group': 'G-1',
#   'id': '3989',
#   'school': 'WKW SCI',
#   'name': 'Anthony Liu',
#   'gender': 'Male',
#   'gpa': 4.15},
#  {'tutorial group': 'G-1',
#   'id': '2115',
#   'school': 'EEE',
#   'name': 'Anya Kumar',
#   'gender': 'Female',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '1383',
#   'school': 'CoB (NBS)',
#   'name': 'Areeba Khan',
#   'gender': 'Female',
#   'gpa': 4.19},
#  {'tutorial group': 'G-1',
#   'id': '1417',
#   'school': 'CoE',
#   'name': 'Darren Lee',
#   'gender': 'Male',
#   'gpa': 4.12},
#  {'tutorial group': 'G-1',
#   'id': '1075',
#   'school': 'CoB (NBS)',
#   'name': 'Felix Yip',
#   'gender': 'Male',
#   'gpa': 4.08},
#  {'tutorial group': 'G-1',
#   'id': '3148',
#   'school': 'EEE',
#   'name': 'Gabriel Young',
#   'gender': 'Male',
#   'gpa': 3.88},
#  {'tutorial group': 'G-1',
#   'id': '4402',
#   'school': 'CCDS',
#   'name': 'Grace Turner',
#   'gender': 'Female',
#   'gpa': 4.08},
#  {'tutorial group': 'G-1',
#   'id': '945',
#   'school': 'MAE',
#   'name': 'Han Li',
#   'gender': 'Female',
#   'gpa': 4.1},
#  {'tutorial group': 'G-1',
#   'id': '2230',
#   'school': 'CoB (NBS)',
#   'name': 'Harlow Wang',
#   'gender': 'Female',
#   'gpa': 4.18},
#  {'tutorial group': 'G-1',
#   'id': '4520',
#   'school': 'EEE',
#   'name': 'Henry Foster',
#   'gender': 'Male',
#   'gpa': 4.11},
#  {'tutorial group': 'G-1',
#   'id': '567',
#   'school': 'CoB (NBS)',
#   'name': 'Isabella Thompson',
#   'gender': 'Female',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '1841',
#   'school': 'MAE',
#   'name': 'Jett Morales',
#   'gender': 'Male',
#   'gpa': 4.12},
#  {'tutorial group': 'G-1',
#   'id': '4576',
#   'school': 'EEE',
#   'name': 'Jie Zhang',
#   'gender': 'Male',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '5703',
#   'school': 'SPMS',
#   'name': 'Karen Lee',
#   'gender': 'Female',
#   'gpa': 4.12},
#  {'tutorial group': 'G-1',
#   'id': '2353',
#   'school': 'SBS',
#   'name': 'Karen Wong',
#   'gender': 'Female',
#   'gpa': 3.95},
#  {'tutorial group': 'G-1',
#   'id': '2069',
#   'school': 'SSS',
#   'name': 'Kathy Lau',
#   'gender': 'Female',
#   'gpa': 4.48},
#  {'tutorial group': 'G-1',
#   'id': '3861',
#   'school': 'ASE',
#   'name': 'Layla Torres',
#   'gender': 'Female',
#   'gpa': 4.52},
#  {'tutorial group': 'G-1',
#   'id': '162',
#   'school': 'SSS',
#   'name': 'Lila Patel',
#   'gender': 'Female',
#   'gpa': 4.07},
#  {'tutorial group': 'G-1',
#   'id': '588',
#   'school': 'MAE',
#   'name': 'Lucas Walker',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '659',
#   'school': 'SSS',
#   'name': 'Maria Ivanovna',
#   'gender': 'Female',
#   'gpa': 4.2},
#  {'tutorial group': 'G-1',
#   'id': '4820',
#   'school': 'CoE',
#   'name': 'Meera Singh',
#   'gender': 'Female',
#   'gpa': 4.22},
#  {'tutorial group': 'G-1',
#   'id': '2151',
#   'school': 'EEE',
#   'name': 'Mei Hong',
#   'gender': 'Female',
#   'gpa': 4.02},
#  {'tutorial group': 'G-1',
#   'id': '235',
#   'school': 'CCDS',
#   'name': 'Ming Zhang',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '527',
#   'school': 'EEE',
#   'name': 'Mohit Desai',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '1329',
#   'school': 'NIE',
#   'name': 'Nguyen Van Sam',
#   'gender': 'Male',
#   'gpa': 3.85},
#  {'tutorial group': 'G-1',
#   'id': '5119',
#   'school': 'ADM',
#   'name': 'Nhung Vu',
#   'gender': 'Female',
#   'gpa': 4.04},
#  {'tutorial group': 'G-1',
#   'id': '809',
#   'school': 'CoB (NBS)',
#   'name': 'Nisha Das',
#   'gender': 'Female',
#   'gpa': 4.26},
#  {'tutorial group': 'G-1',
#   'id': '2650',
#   'school': 'SoH',
#   'name': 'Nurul Shafika',
#   'gender': 'Female',
#   'gpa': 4.09},
#  {'tutorial group': 'G-1',
#   'id': '4657',
#   'school': 'SoH',
#   'name': 'Oleg Petrovich',
#   'gender': 'Male',
#   'gpa': 4.0},
#  {'tutorial group': 'G-1',
#   'id': '2818',
#   'school': 'CoB (NBS)',
#   'name': 'Oliver Tan',
#   'gender': 'Male',
#   'gpa': 4.09},
#  {'tutorial group': 'G-1',
#   'id': '3628',
#   'school': 'EEE',
#   'name': 'Omer Ahmed',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '1555',
#   'school': 'MAE',
#   'name': 'Prerna Gupta',
#   'gender': 'Female',
#   'gpa': 4.04},
#  {'tutorial group': 'G-1',
#   'id': '1271',
#   'school': 'SSS',
#   'name': 'Priya Singh',
#   'gender': 'Female',
#   'gpa': 4.17},
#  {'tutorial group': 'G-1',
#   'id': '75',
#   'school': 'CCDS',
#   'name': 'Sakina Ahmed',
#   'gender': 'Female',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '4338',
#   'school': 'SPMS',
#   'name': 'Sana Jain',
#   'gender': 'Female',
#   'gpa': 4.22},
#  {'tutorial group': 'G-1',
#   'id': '71',
#   'school': 'SoH',
#   'name': 'Savannah Taylor',
#   'gender': 'Female',
#   'gpa': 4.19},
#  {'tutorial group': 'G-1',
#   'id': '2776',
#   'school': 'CCEB',
#   'name': 'Siddharth Nair',
#   'gender': 'Male',
#   'gpa': 4.14},
#  {'tutorial group': 'G-1',
#   'id': '2417',
#   'school': 'SSS',
#   'name': 'Truong Minh Chau',
#   'gender': 'Female',
#   'gpa': 3.88},
#  {'tutorial group': 'G-1',
#   'id': '5477',
#   'school': 'SoH',
#   'name': 'Vikram Desai',
#   'gender': 'Male',
#   'gpa': 4.09},
#  {'tutorial group': 'G-1',
#   'id': '2326',
#   'school': 'CoB (NBS)',
#   'name': 'Vivi Dwi',
#   'gender': 'Female',
#   'gpa': 3.95},
#  {'tutorial group': 'G-1',
#   'id': '3930',
#   'school': 'EEE',
#   'name': 'Xun Wei',
#   'gender': 'Female',
#   'gpa': 4.18},
#  {'tutorial group': 'G-1',
#   'id': '1645',
#   'school': 'CoE',
#   'name': 'Zachary Wu',
#   'gender': 'Male',
#   'gpa': 3.93},
#  {'tutorial group': 'G-1',
#   'id': '592',
#   'school': 'MSE',
#   'name': 'Zara Chang',
#   'gender': 'Female',
#   'gpa': 4.11}]

# %%
def count_total_students(filepath="records.csv"):
    """Count total number of student records (excluding header)."""
    if not os.path.exists(filepath):
        return 0
        
    with open(filepath, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        headers = next(reader, None)  # skip header
        return sum(1 for row in reader)

        
count_total_students(filepath="records.csv")
# Out:
# 6000

# %%
def form_groups(students, num_groups=10):
    """Form groups from a list of student dicts.
    Returns list of groups (each group is a list of students).
    """
    if not students:
        return []

    students_sorted = sorted(students, key=lambda x: x['gpa'], reverse=True)

    # split into up to 5 bands as evenly as possible
    n = len(students_sorted)
    band_size = max(1, n // 5)
    bands = [students_sorted[i:i + band_size] for i in range(0, n, band_size)]

    # split each band by gender
    band_males = []
    band_females = []
    for band in bands:
        males = [s for s in band if s['gender'].strip().lower() in ('m', 'male')]
        females = [s for s in band if s['gender'].strip().lower() in ('f', 'female')]
        random.shuffle(males)
        random.shuffle(females)
        band_males.append(males)
        band_females.append(females)

    total_males = sum(len(m) for m in band_males)
    total_females = sum(len(f) for f in band_females)

    if total_males > total_females:
        target_males_per_group, target_females_per_group = 3, 2
    else:
        target_males_per_group, target_females_per_group = 2, 3

    groups = [[] for _ in range(num_groups)]
    male_count = [0] * num_groups
    female_count = [0] * num_groups

    # distribute one student from each band into each group
    for band_idx in range(len(bands)):
        for group_idx in range(num_groups):
            # try to pick a student to respect the gender targets
            picked = False
            if male_count[group_idx] < target_males_per_group and band_males[band_idx]:
                groups[group_idx].append(band_males[band_idx].pop())
                male_count[group_idx] += 1
                picked = True
            elif female_count[group_idx] < target_females_per_group and band_females[band_idx]:
                groups[group_idx].append(band_females[band_idx].pop())
                female_count[group_idx] += 1
                picked = True
            elif band_males[band_idx]:
                groups[group_idx].append(band_males[band_idx].pop())
                male_count[group_idx] += 1
                picked = True
            elif band_females[band_idx]:
                groups[group_idx].append(band_females[band_idx].pop())
                female_count[group_idx] += 1
                picked = True

    return groups
form_groups(students, num_groups=10)
# Out:
# [[{'tutorial group': 'G-1',
#    'id': '2091',
#    'school': 'EEE',
#    'name': 'Adlan Bin Rahman',
#    'gender': 'Male',
#    'gpa': 4.2},
#   {'tutorial group': 'G-1',
#    'id': '4520',
#    'school': 'EEE',
#    'name': 'Henry Foster',
#    'gender': 'Male',
#    'gpa': 4.11},
#   {'tutorial group': 'G-1',
#    'id': '4402',
#    'school': 'CCDS',
#    'name': 'Grace Turner',
#    'gender': 'Female',
#    'gpa': 4.08},
#   {'tutorial group': 'G-1',
#    'id': '567',
#    'school': 'CoB (NBS)',
#    'name': 'Isabella Thompson',
#    'gender': 'Female',
#    'gpa': 4.03},
#   {'tutorial group': 'G-1',
#    'id': '2417',
#    'school': 'SSS',
#    'name': 'Truong Minh Chau',
#    'gender': 'Female',
#    'gpa': 3.88}],
#  [{'tutorial group': 'G-1',
#    'id': '5708',
#    'school': 'SoH',
#    'name': 'Ananya Ramesh',
#    'gender': 'Male',
#    'gpa': 4.2},
#   {'tutorial group': 'G-1',
#    'id': '2776',
#    'school': 'CCEB',
#    'name': 'Siddharth Nair',
#    'gender': 'Male',
#    'gpa': 4.14},
#   {'tutorial group': 'G-1',
#    'id': '592',
#    'school': 'MSE',
#    'name': 'Zara Chang',
#    'gender': 'Female',
#    'gpa': 4.11},
#   {'tutorial group': 'G-1',
#    'id': '3838',
#    'school': 'EEE',
#    'name': 'Aarti Nair',
#    'gender': 'Female',
#    'gpa': 4.05},
#   {'tutorial group': 'G-1',
#    'id': '2326',
#    'school': 'CoB (NBS)',
#    'name': 'Vivi Dwi',
#    'gender': 'Female',
#    'gpa': 3.95}],
#  [{'tutorial group': 'G-1',
#    'id': '1383',
#    'school': 'CoB (NBS)',
#    'name': 'Areeba Khan',
#    'gender': 'Female',
#    'gpa': 4.19},
#   {'tutorial group': 'G-1',
#    'id': '3989',
#    'school': 'WKW SCI',
#    'name': 'Anthony Liu',
#    'gender': 'Male',
#    'gpa': 4.15},
#   {'tutorial group': 'G-1',
#    'id': '588',
#    'school': 'MAE',
#    'name': 'Lucas Walker',
#    'gender': 'Male',
#    'gpa': 4.06},
#   {'tutorial group': 'G-1',
#    'id': '5119',
#    'school': 'ADM',
#    'name': 'Nhung Vu',
#    'gender': 'Female',
#    'gpa': 4.04},
#   {'tutorial group': 'G-1',
#    'id': '2353',
#    'school': 'SBS',
#    'name': 'Karen Wong',
#    'gender': 'Female',
#    'gpa': 3.95}],
#  [{'tutorial group': 'G-1',
#    'id': '71',
#    'school': 'SoH',
#    'name': 'Savannah Taylor',
#    'gender': 'Female',
#    'gpa': 4.19},
#   {'tutorial group': 'G-1',
#    'id': '1841',
#    'school': 'MAE',
#    'name': 'Jett Morales',
#    'gender': 'Male',
#    'gpa': 4.12},
#   {'tutorial group': 'G-1',
#    'id': '2818',
#    'school': 'CoB (NBS)',
#    'name': 'Oliver Tan',
#    'gender': 'Male',
#    'gpa': 4.09},
#   {'tutorial group': 'G-1',
#    'id': '2115',
#    'school': 'EEE',
#    'name': 'Anya Kumar',
#    'gender': 'Female',
#    'gpa': 4.03},
#   {'tutorial group': 'G-1',
#    'id': '2151',
#    'school': 'EEE',
#    'name': 'Mei Hong',
#    'gender': 'Female',
#    'gpa': 4.02}],
#  [{'tutorial group': 'G-1',
#    'id': '4338',
#    'school': 'SPMS',
#    'name': 'Sana Jain',
#    'gender': 'Female',
#    'gpa': 4.22},
#   {'tutorial group': 'G-1',
#    'id': '1417',
#    'school': 'CoE',
#    'name': 'Darren Lee',
#    'gender': 'Male',
#    'gpa': 4.12},
#   {'tutorial group': 'G-1',
#    'id': '235',
#    'school': 'CCDS',
#    'name': 'Ming Zhang',
#    'gender': 'Male',
#    'gpa': 4.06},
#   {'tutorial group': 'G-1',
#    'id': '1555',
#    'school': 'MAE',
#    'name': 'Prerna Gupta',
#    'gender': 'Female',
#    'gpa': 4.04},
#   {'tutorial group': 'G-1',
#    'id': '4563',
#    'school': 'WKW SCI',
#    'name': 'Anjali Patel',
#    'gender': 'Female',
#    'gpa': 4.01}],
#  [{'tutorial group': 'G-1',
#    'id': '2069',
#    'school': 'SSS',
#    'name': 'Kathy Lau',
#    'gender': 'Female',
#    'gpa': 4.48},
#   {'tutorial group': 'G-1',
#    'id': '3930',
#    'school': 'EEE',
#    'name': 'Xun Wei',
#    'gender': 'Female',
#    'gpa': 4.18},
#   {'tutorial group': 'G-1',
#    'id': '1075',
#    'school': 'CoB (NBS)',
#    'name': 'Felix Yip',
#    'gender': 'Male',
#    'gpa': 4.08},
#   {'tutorial group': 'G-1',
#    'id': '527',
#    'school': 'EEE',
#    'name': 'Mohit Desai',
#    'gender': 'Male',
#    'gpa': 4.06},
#   {'tutorial group': 'G-1',
#    'id': '3148',
#    'school': 'EEE',
#    'name': 'Gabriel Young',
#    'gender': 'Male',
#    'gpa': 3.88}],
#  [{'tutorial group': 'G-1',
#    'id': '809',
#    'school': 'CoB (NBS)',
#    'name': 'Nisha Das',
#    'gender': 'Female',
#    'gpa': 4.26},
#   {'tutorial group': 'G-1',
#    'id': '4479',
#    'school': 'CCDS',
#    'name': 'Amelia Kim',
#    'gender': 'Female',
#    'gpa': 4.11},
#   {'tutorial group': 'G-1',
#    'id': '5477',
#    'school': 'SoH',
#    'name': 'Vikram Desai',
#    'gender': 'Male',
#    'gpa': 4.09},
#   {'tutorial group': 'G-1',
#    'id': '3628',
#    'school': 'EEE',
#    'name': 'Omer Ahmed',
#    'gender': 'Male',
#    'gpa': 4.06},
#   {'tutorial group': 'G-1',
#    'id': '1329',
#    'school': 'NIE',
#    'name': 'Nguyen Van Sam',
#    'gender': 'Male',
#    'gpa': 3.85}],
#  [{'tutorial group': 'G-1',
#    'id': '3861',
#    'school': 'ASE',
#    'name': 'Layla Torres',
#    'gender': 'Female',
#    'gpa': 4.52},
#   {'tutorial group': 'G-1',
#    'id': '2230',
#    'school': 'CoB (NBS)',
#    'name': 'Harlow Wang',
#    'gender': 'Female',
#    'gpa': 4.18},
#   {'tutorial group': 'G-1',
#    'id': '945',
#    'school': 'MAE',
#    'name': 'Han Li',
#    'gender': 'Female',
#    'gpa': 4.1},
#   {'tutorial group': 'G-1',
#    'id': '5002',
#    'school': 'CCDS',
#    'name': 'Aarav Singh',
#    'gender': 'Male',
#    'gpa': 4.02},
#   {'tutorial group': 'G-1',
#    'id': '288',
#    'school': 'CoB (NBS)',
#    'name': 'Ajay Verma',
#    'gender': 'Male',
#    'gpa': 4.01}],
#  [{'tutorial group': 'G-1',
#    'id': '659',
#    'school': 'SSS',
#    'name': 'Maria Ivanovna',
#    'gender': 'Female',
#    'gpa': 4.2},
#   {'tutorial group': 'G-1',
#    'id': '5703',
#    'school': 'SPMS',
#    'name': 'Karen Lee',
#    'gender': 'Female',
#    'gpa': 4.12},
#   {'tutorial group': 'G-1',
#    'id': '162',
#    'school': 'SSS',
#    'name': 'Lila Patel',
#    'gender': 'Female',
#    'gpa': 4.07},
#   {'tutorial group': 'G-1',
#    'id': '4576',
#    'school': 'EEE',
#    'name': 'Jie Zhang',
#    'gender': 'Male',
#    'gpa': 4.03},
#   {'tutorial group': 'G-1',
#    'id': '1645',
#    'school': 'CoE',
#    'name': 'Zachary Wu',
#    'gender': 'Male',
#    'gpa': 3.93}],
#  [{'tutorial group': 'G-1',
#    'id': '4820',
#    'school': 'CoE',
#    'name': 'Meera Singh',
#    'gender': 'Female',
#    'gpa': 4.22},
#   {'tutorial group': 'G-1',
#    'id': '1271',
#    'school': 'SSS',
#    'name': 'Priya Singh',
#    'gender': 'Female',
#    'gpa': 4.17},
#   {'tutorial group': 'G-1',
#    'id': '2650',
#    'school': 'SoH',
#    'name': 'Nurul Shafika',
#    'gender': 'Female',
#    'gpa': 4.09},
#   {'tutorial group': 'G-1',
#    'id': '75',
#    'school': 'CCDS',
#    'name': 'Sakina Ahmed',
#    'gender': 'Female',
#    'gpa': 4.03},
#   {'tutorial group': 'G-1',
#    'id': '4657',
#    'school': 'SoH',
#    'name': 'Oleg Petrovich',
#    'gender': 'Male',
#    'gpa': 4.0}]]

# %%
def print_groups(groups, students_sorted, bands, batch_number=1):
    """Print groups with band information."""
    # Precompute band assignments for faster lookup
    student_to_band = {}
    for band_idx, band in enumerate(bands):
        for student in band:
            # Use a unique identifier (name + id) to handle duplicate names
            student_key = f"{student['name']}_{student['id']}"
            student_to_band[student_key] = band_idx + 1  # Band 1 = highest GPA

    print(f"=== BATCH {batch_number} ===")
    print(f"Total students in this batch: {len(students_sorted)}")
    print()
    
    for i, g in enumerate(groups, 1):
        print(f"Group {i}:")
        males_in_group = 0
        females_in_group = 0
        total_gpa = 0.0
        
        for student in g:
            # Determine which band the student came from
            student_key = f"{student['name']}_{student['id']}"
            band_number = student_to_band.get(student_key, "Unknown")
            
            gender_lower = student['gender'].lower()
            if gender_lower in ['m','male']:
                males_in_group += 1
            elif gender_lower in ['f', 'female']:
                females_in_group += 1
            total_gpa += student['gpa']
            print(f"  {student['name']} | {student['school']} | {student['gender']} | GPA: {student['gpa']:.2f} | Band: {band_number}")
        
        if g:
            avg_gpa = total_gpa / len(g)
            print(f"  Summary: {males_in_group} males, {females_in_group} females, Average GPA: {avg_gpa:.2f}")
        else:
            print("  Summary: Empty group")
        print()

print_groups(groups, students_sorted, bands, batch_number=1)
# Out:
# === BATCH 1 ===
# Total students in this batch: 50
#
# Group 1:
#   Sana Jain | SPMS | Female | GPA: 4.22 | Band: 1
#   Henry Foster | EEE | Male | GPA: 4.11 | Band: 2
#   Lila Patel | SSS | Female | GPA: 4.07 | Band: 3
#   Omer Ahmed | EEE | Male | GPA: 4.06 | Band: 4
#   Mei Hong | EEE | Female | GPA: 4.02 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.10
#
# Group 2:
#   Maria Ivanovna | SSS | Female | GPA: 4.20 | Band: 1
#   Darren Lee | CoE | Male | GPA: 4.12 | Band: 2
#   Grace Turner | CCDS | Female | GPA: 4.08 | Band: 3
#   Jie Zhang | EEE | Male | GPA: 4.03 | Band: 4
#   Anjali Patel | WKW SCI | Female | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 3:
#   Savannah Taylor | SoH | Female | GPA: 4.19 | Band: 1
#   Anthony Liu | WKW SCI | Male | GPA: 4.15 | Band: 2
#   Han Li | MAE | Female | GPA: 4.10 | Band: 3
#   Aarav Singh | CCDS | Male | GPA: 4.02 | Band: 4
#   Truong Minh Chau | SSS | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 4:
#   Areeba Khan | CoB (NBS) | Female | GPA: 4.19 | Band: 1
#   Jett Morales | MAE | Male | GPA: 4.12 | Band: 2
#   Zara Chang | MSE | Female | GPA: 4.11 | Band: 3
#   Mohit Desai | EEE | Male | GPA: 4.06 | Band: 4
#   Vivi Dwi | CoB (NBS) | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 5:
#   Layla Torres | ASE | Female | GPA: 4.52 | Band: 1
#   Siddharth Nair | CCEB | Male | GPA: 4.14 | Band: 2
#   Nurul Shafika | SoH | Female | GPA: 4.09 | Band: 3
#   Sakina Ahmed | CCDS | Female | GPA: 4.03 | Band: 4
#   Nguyen Van Sam | NIE | Male | GPA: 3.85 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.13
#
# Group 6:
#   Nisha Das | CoB (NBS) | Female | GPA: 4.26 | Band: 1
#   Amelia Kim | CCDS | Female | GPA: 4.11 | Band: 2
#   Lucas Walker | MAE | Male | GPA: 4.06 | Band: 3
#   Prerna Gupta | MAE | Female | GPA: 4.04 | Band: 4
#   Ajay Verma | CoB (NBS) | Male | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.10
#
# Group 7:
#   Kathy Lau | SSS | Female | GPA: 4.48 | Band: 1
#   Xun Wei | EEE | Female | GPA: 4.18 | Band: 2
#   Felix Yip | CoB (NBS) | Male | GPA: 4.08 | Band: 3
#   Anya Kumar | EEE | Female | GPA: 4.03 | Band: 4
#   Gabriel Young | EEE | Male | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.13
#
# Group 8:
#   Meera Singh | CoE | Female | GPA: 4.22 | Band: 1
#   Priya Singh | SSS | Female | GPA: 4.17 | Band: 2
#   Oliver Tan | CoB (NBS) | Male | GPA: 4.09 | Band: 3
#   Nhung Vu | ADM | Female | GPA: 4.04 | Band: 4
#   Zachary Wu | CoE | Male | GPA: 3.93 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 9:
#   Adlan Bin Rahman | EEE | Male | GPA: 4.20 | Band: 1
#   Harlow Wang | CoB (NBS) | Female | GPA: 4.18 | Band: 2
#   Ming Zhang | CCDS | Male | GPA: 4.06 | Band: 3
#   Isabella Thompson | CoB (NBS) | Female | GPA: 4.03 | Band: 4
#   Karen Wong | SBS | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 10:
#   Ananya Ramesh | SoH | Male | GPA: 4.20 | Band: 1
#   Karen Lee | SPMS | Female | GPA: 4.12 | Band: 2
#   Vikram Desai | SoH | Male | GPA: 4.09 | Band: 3
#   Aarti Nair | EEE | Female | GPA: 4.05 | Band: 4
#   Oleg Petrovich | SoH | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09

# %%
def print_groups(groups, students_sorted, bands, batch_number=1):
    """Print groups with band information."""
    # Precompute band assignments for faster lookup
    student_to_band = {}
    for band_idx, band in enumerate(bands):
        for student in band:
            # Use a unique identifier (name + id) to handle duplicate names
            student_key = f"{student['name']}_{student['id']}"
            student_to_band[student_key] = band_idx + 1  # Band 1 = highest GPA

    print(f"=== BATCH {batch_number} ===")
    print(f"Total students in this batch: {len(students_sorted)}")
    print()
    
    for i, g in enumerate(groups, 1):
        print(f"Group {i}:")
        males_in_group = 0
        females_in_group = 0
        total_gpa = 0.0
        
        for student in g:
            # Determine which band the student came from
            student_key = f"{student['name']}_{student['id']}"
            band_number = student_to_band.get(student_key, "Unknown")
            
            gender_lower = student['gender'].lower()
            if gender_lower in ['m','male']:
                males_in_group += 1
            elif gender_lower in ['f', 'female']:
                females_in_group += 1
            total_gpa += student['gpa']
            print(f"  {student['name']} | {student['school']} | {student['gender']} | GPA: {student['gpa']:.2f} | Band: {band_number}")
        
        if g:
            avg_gpa = total_gpa / len(g)
            print(f"  Summary: {males_in_group} males, {females_in_group} females, Average GPA: {avg_gpa:.2f}")
        else:
            print("  Summary: Empty group")
        print()

# %%
def save_groups_to_csv(all_groups_data, output_file="student_groups.csv"):
    """Save all groups data to a CSV file.
    
    Args:
        all_groups_data: List of tuples (batch_number, groups, students_sorted, bands)
        output_file: Name of the output CSV file
    """
    try:
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            
            # Write header
            writer.writerow([
                'Batch', 'Group', 'Student_Name', 'Student_ID', 'School', 
                'Gender', 'GPA', 'Band', 'Tutorial_Group'
            ])
            
            # Precompute band assignments for each batch and write data
            for batch_number, groups, students_sorted, bands in all_groups_data:
                # Create band lookup for this batch
                student_to_band = {}
                for band_idx, band in enumerate(bands):
                    for student in band:
                        student_key = f"{student['name']}_{student['id']}"
                        student_to_band[student_key] = band_idx + 1
                
                # Write groups for this batch
                for group_idx, group in enumerate(groups, 1):
                    for student in group:
                        student_key = f"{student['name']}_{student['id']}"
                        band_number = student_to_band.get(student_key, "Unknown")
                        
                        writer.writerow([
                            batch_number,
                            f"Group {group_idx}",
                            student['name'],
                            student['id'],
                            student['school'],
                            student['gender'],
                            f"{student['gpa']:.2f}",
                            band_number,
                            student['tutorial group']
                        ])
        
        print(f"All groups have been saved to '{output_file}'")
        return True
        
    except Exception as e:
        print(f"Error saving to CSV file: {e}")
        return False

# %%
if __name__ == "__main__":
    BATCH_SIZE = 50
    NUM_GROUPS = 10
    
    try:
        # Count total students first
        total_students = count_total_students()
        if total_students == 0:
            print("No student records found in the file.")
            sys.exit(1)
            
        print(f"Total students in file: {total_students}")
        print(f"Processing in batches of {BATCH_SIZE} students...")
        print("=" * 60)
        
        batch_number = 1
        start_index = 0
        
        # Process file in batches until all students are processed
        while True:
            print(f"Reading batch {batch_number} (students {start_index + 1} to {start_index + BATCH_SIZE})...")
            students = read_students(start_index, BATCH_SIZE)
            
            if not students:
                print("No more students to process.")
                break
                
            print(f"Processing {len(students)} students in batch {batch_number}...")
            
            # Sort students for band creation
            students_sorted = sorted(students, key=lambda x: x['gpa'], reverse=True)
            n = len(students_sorted)
            band_size = max(1, n // 5)
            bands = [students_sorted[i:i + band_size] for i in range(0, n, band_size)]

            # Form groups for this batch
            groups = form_groups(students, num_groups=NUM_GROUPS)
            
            # Print groups for this batch
            print_groups(groups, students_sorted, bands, batch_number)
            
            # Update for next batch
            start_index += BATCH_SIZE
            batch_number += 1
            
            # Add separator between batches
            if start_index < total_students:
                print("=" * 60)
                print()
        
        print(f"Processing complete! Processed {batch_number - 1} batch(es) total.")
        
    except FileNotFoundError as e:
        print(e)
        sys.exit(1)
    except Exception as e:
        print(f"An error occurred: {e}")
        sys.exit(1)
# Out:
# Total students in file: 6000
# Processing in batches of 50 students...
# ============================================================
# Reading batch 1 (students 1 to 50)...
# Processing 50 students in batch 1...
# === BATCH 1 ===
# Total students in this batch: 50
#
# Group 1:
#   Adlan Bin Rahman | EEE | Male | GPA: 4.20 | Band: 1
#   Henry Foster | EEE | Male | GPA: 4.11 | Band: 2
#   Zara Chang | MSE | Female | GPA: 4.11 | Band: 3
#   Isabella Thompson | CoB (NBS) | Female | GPA: 4.03 | Band: 4
#   Anjali Patel | WKW SCI | Female | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 2:
#   Ananya Ramesh | SoH | Male | GPA: 4.20 | Band: 1
#   Jett Morales | MAE | Male | GPA: 4.12 | Band: 2
#   Han Li | MAE | Female | GPA: 4.10 | Band: 3
#   Nhung Vu | ADM | Female | GPA: 4.04 | Band: 4
#   Vivi Dwi | CoB (NBS) | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 3:
#   Layla Torres | ASE | Female | GPA: 4.52 | Band: 1
#   Darren Lee | CoE | Male | GPA: 4.12 | Band: 2
#   Lucas Walker | MAE | Male | GPA: 4.06 | Band: 3
#   Aarti Nair | EEE | Female | GPA: 4.05 | Band: 4
#   Mei Hong | EEE | Female | GPA: 4.02 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.15
#
# Group 4:
#   Meera Singh | CoE | Female | GPA: 4.22 | Band: 1
#   Anthony Liu | WKW SCI | Male | GPA: 4.15 | Band: 2
#   Felix Yip | CoB (NBS) | Male | GPA: 4.08 | Band: 3
#   Prerna Gupta | MAE | Female | GPA: 4.04 | Band: 4
#   Karen Wong | SBS | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 5:
#   Nisha Das | CoB (NBS) | Female | GPA: 4.26 | Band: 1
#   Siddharth Nair | CCEB | Male | GPA: 4.14 | Band: 2
#   Ming Zhang | CCDS | Male | GPA: 4.06 | Band: 3
#   Sakina Ahmed | CCDS | Female | GPA: 4.03 | Band: 4
#   Truong Minh Chau | SSS | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 6:
#   Areeba Khan | CoB (NBS) | Female | GPA: 4.19 | Band: 1
#   Amelia Kim | CCDS | Female | GPA: 4.11 | Band: 2
#   Oliver Tan | CoB (NBS) | Male | GPA: 4.09 | Band: 3
#   Omer Ahmed | EEE | Male | GPA: 4.06 | Band: 4
#   Nguyen Van Sam | NIE | Male | GPA: 3.85 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.06
#
# Group 7:
#   Maria Ivanovna | SSS | Female | GPA: 4.20 | Band: 1
#   Priya Singh | SSS | Female | GPA: 4.17 | Band: 2
#   Vikram Desai | SoH | Male | GPA: 4.09 | Band: 3
#   Jie Zhang | EEE | Male | GPA: 4.03 | Band: 4
#   Gabriel Young | EEE | Male | GPA: 3.88 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.07
#
# Group 8:
#   Kathy Lau | SSS | Female | GPA: 4.48 | Band: 1
#   Xun Wei | EEE | Female | GPA: 4.18 | Band: 2
#   Nurul Shafika | SoH | Female | GPA: 4.09 | Band: 3
#   Aarav Singh | CCDS | Male | GPA: 4.02 | Band: 4
#   Oleg Petrovich | SoH | Male | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.15
#
# Group 9:
#   Savannah Taylor | SoH | Female | GPA: 4.19 | Band: 1
#   Karen Lee | SPMS | Female | GPA: 4.12 | Band: 2
#   Lila Patel | SSS | Female | GPA: 4.07 | Band: 3
#   Mohit Desai | EEE | Male | GPA: 4.06 | Band: 4
#   Zachary Wu | CoE | Male | GPA: 3.93 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 10:
#   Sana Jain | SPMS | Female | GPA: 4.22 | Band: 1
#   Harlow Wang | CoB (NBS) | Female | GPA: 4.18 | Band: 2
#   Grace Turner | CCDS | Female | GPA: 4.08 | Band: 3
#   Anya Kumar | EEE | Female | GPA: 4.03 | Band: 4
#   Ajay Verma | CoB (NBS) | Male | GPA: 4.01 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.10
#
# ============================================================
#
# Reading batch 2 (students 51 to 100)...
# Processing 50 students in batch 2...
# === BATCH 2 ===
# Total students in this batch: 50
#
# Group 1:
#   Will Chen | MAE | Male | GPA: 4.23 | Band: 1
#   Dante Wu | EEE | Male | GPA: 4.18 | Band: 2
#   Cheng Zhang | EEE | Male | GPA: 4.11 | Band: 3
#   Rhea Lee | CCEB | Female | GPA: 4.07 | Band: 4
#   Yasmine Villanueva | SSS | Female | GPA: 4.02 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.12
#
# Group 2:
#   Sho Nakajima | MAE | Male | GPA: 4.27 | Band: 1
#   Ming Wei | MAE | Male | GPA: 4.19 | Band: 2
#   Rizan Bin Ahmad | MAE | Male | GPA: 4.11 | Band: 3
#   Paula Wong | CoB (NBS) | Female | GPA: 4.06 | Band: 4
#   Tanya Lee | CoE | Female | GPA: 4.04 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.13
#
# Group 3:
#   Liam Jones | CCDS | Male | GPA: 4.20 | Band: 1
#   Isaiah Scott | SoH | Male | GPA: 4.15 | Band: 2
#   Leo Xu | CoB (NBS) | Male | GPA: 4.12 | Band: 3
#   Kiara Lin | CCDS | Female | GPA: 4.06 | Band: 4
#   Rhea Kapoor | MAE | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.11
#
# Group 4:
#   Yasir Ahmad | SoH | Male | GPA: 4.52 | Band: 1
#   Kendrick Alvarado | CCDS | Male | GPA: 4.18 | Band: 2
#   Hendra Mulyana | SPMS | Male | GPA: 4.10 | Band: 3
#   Kaya Chang | SBS | Female | GPA: 4.05 | Band: 4
#   Kerry Lim | CCEB | Female | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.17
#
# Group 5:
#   Yuzhi | SPMS | Male | GPA: 4.25 | Band: 1
#   Jaxon Hall | MAE | Male | GPA: 4.12 | Band: 2
#   Xander Cook | CoE | Male | GPA: 4.10 | Band: 3
#   Benjamin Turner | SBS | Male | GPA: 4.06 | Band: 4
#   Alyssa Green | ASE | Female | GPA: 3.94 | Band: 5
#   Summary: 4 males, 1 females, Average GPA: 4.09
#
# Group 6:
#   Kira Yamada | CCDS | Female | GPA: 4.26 | Band: 1
#   Christopher Miller | CoB (NBS) | Male | GPA: 4.17 | Band: 2
#   Freya Chen | MAE | Female | GPA: 4.09 | Band: 3
#   Tao Liu | ADM | Male | GPA: 4.05 | Band: 4
#   Zaki Bin Ibrahim | EEE | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.11
#
# Group 7:
#   Hae-Jin Lee | SoH | Female | GPA: 4.52 | Band: 1
#   Tianming | SoH | Female | GPA: 4.20 | Band: 2
#   Ayesha Javed | SoH | Female | GPA: 4.09 | Band: 3
#   Marco Garcia | CEE | Male | GPA: 4.04 | Band: 4
#   Xiao Chen | CoE | Male | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.14
#
# Group 8:
#   Ananya Singh | MAE | Female | GPA: 4.20 | Band: 1
#   Mia Zhang | EEE | Female | GPA: 4.18 | Band: 2
#   Nina Bennett | CCEB | Female | GPA: 4.08 | Band: 3
#   Rhys Tan | WKW SCI | Male | GPA: 4.06 | Band: 4
#   Michael Miller | CoB (NBS) | Male | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 9:
#   Sophie Cheung | MAE | Female | GPA: 4.20 | Band: 1
#   Kiran Farooq | WKW SCI | Female | GPA: 4.15 | Band: 2
#   Nina Patil | NIE | Female | GPA: 4.10 | Band: 3
#   Hunter Wilson | LKCMedicine | Male | GPA: 4.06 | Band: 4
#   Hassan Malik | MAE | Male | GPA: 4.03 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.11
#
# Group 10:
#   Nurul Aini Binti Ahmad | SPMS | Female | GPA: 4.20 | Band: 1
#   Tatum Flores | EEE | Female | GPA: 4.20 | Band: 2
#   Ximena Fernandez | MSE | Female | GPA: 4.12 | Band: 3
#   Adrian Castillo | MAE | Male | GPA: 4.07 | Band: 4
#   Soo-Young Kim | ASE | Female | GPA: 3.88 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.09
#
# ============================================================
#
# Reading batch 3 (students 101 to 150)...
# Processing 50 students in batch 3...
# === BATCH 3 ===
# Total students in this batch: 50
#
# Group 1:
#   Peter Choi | EEE | Male | GPA: 4.19 | Band: 1
#   Wesley Turner | SoH | Male | GPA: 4.17 | Band: 2
#   Fay Tan | CCEB | Female | GPA: 4.09 | Band: 3
#   Siti Maryam | CoB (NBS) | Female | GPA: 4.03 | Band: 4
#   Isabella Thomas | CCDS | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 2:
#   Ameer Bin Rahman | CoB (NBS) | Male | GPA: 4.20 | Band: 1
#   Hua Zhang | MSE | Male | GPA: 4.17 | Band: 2
#   Diya Nair | SSS | Female | GPA: 4.11 | Band: 3
#   Ying Liu | SPMS | Female | GPA: 4.03 | Band: 4
#   Iris Rivera | MAE | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 3:
#   Ashok Nair | CEE | Male | GPA: 4.52 | Band: 1
#   Adrian King | CCDS | Male | GPA: 4.12 | Band: 2
#   Tao Wang | SSS | Female | GPA: 4.12 | Band: 3
#   Fangling | CoB (NBS) | Female | GPA: 4.05 | Band: 4
#   Bella Perry | EEE | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.14
#
# Group 4:
#   Seema Kapoor | MAE | Female | GPA: 4.19 | Band: 1
#   Ali Rehman | CoE | Male | GPA: 4.14 | Band: 2
#   Jordan Chen | EEE | Male | GPA: 4.06 | Band: 3
#   Mia Wong | EEE | Female | GPA: 4.03 | Band: 4
#   Mia Hall | CCDS | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 5:
#   Raquel Huang | LKCMedicine | Female | GPA: 4.18 | Band: 1
#   Fiona Clark | EEE | Female | GPA: 4.15 | Band: 2
#   Carter Moore | NIE | Male | GPA: 4.10 | Band: 3
#   Tae-Soo Kim | WKW SCI | Male | GPA: 4.05 | Band: 4
#   Meera Menon | EEE | Female | GPA: 3.92 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 6:
#   Alina Malik | CoB (NBS) | Female | GPA: 4.19 | Band: 1
#   Maya Ong | CoB (NBS) | Female | GPA: 4.14 | Band: 2
#   Yasir Qureshi | CoE | Male | GPA: 4.08 | Band: 3
#   Owen Hill | CCDS | Male | GPA: 4.03 | Band: 4
#   Orlando Wu | SBS | Male | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 7:
#   Yuanqing | MAE | Female | GPA: 4.25 | Band: 1
#   Yumi Nishikawa | CoB (NBS) | Female | GPA: 4.14 | Band: 2
#   Fergus Mendoza | CoB (NBS) | Male | GPA: 4.11 | Band: 3
#   Danty Susanto | NIE | Male | GPA: 4.05 | Band: 4
#   Aiden Brown | WKW SCI | Male | GPA: 3.90 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 8:
#   Naina Gupta | CCEB | Female | GPA: 4.20 | Band: 1
#   Nadia Binti Azhar | CCEB | Female | GPA: 4.15 | Band: 2
#   Khalid Rahman | CEE | Male | GPA: 4.10 | Band: 3
#   Tommy Wu | EEE | Male | GPA: 4.03 | Band: 4
#   Bradley Huang | EEE | Male | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.10
#
# Group 9:
#   Margaret Li | CCEB | Female | GPA: 4.20 | Band: 1
#   Mia Phillips | SBS | Female | GPA: 4.17 | Band: 2
#   Rachel Lee | SoH | Female | GPA: 4.11 | Band: 3
#   Jack Foster | SPMS | Male | GPA: 4.05 | Band: 4
#   Caiyun | CoE | Male | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 10:
#   Anjali Nair | MSE | Female | GPA: 4.27 | Band: 1
#   Carla Wang | ASE | Female | GPA: 4.12 | Band: 2
#   Hassan Farooq | ADM | Female | GPA: 4.10 | Band: 3
#   Neelam Bhatia | SSS | Female | GPA: 4.05 | Band: 4
#   Han Zhang | CoB (NBS) | Male | GPA: 4.02 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.11
#
# ============================================================
#
# Reading batch 4 (students 151 to 200)...
# Processing 50 students in batch 4...
# === BATCH 4 ===
# Total students in this batch: 50
#
# Group 1:
#   Ajay Iyer | ADM | Male | GPA: 4.20 | Band: 1
#   Ethan Taylor | SSS | Male | GPA: 4.15 | Band: 2
#   Sofia Reddy | MAE | Female | GPA: 4.09 | Band: 3
#   Alani Lin | MAE | Female | GPA: 4.03 | Band: 4
#   Wani Binti Jalil | MAE | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 2:
#   Farhan Bin Azhar | SPMS | Male | GPA: 4.20 | Band: 1
#   Minghao | MAE | Male | GPA: 4.15 | Band: 2
#   Ning Li | CCEB | Female | GPA: 4.09 | Band: 3
#   Hope Chen | CCDS | Female | GPA: 4.04 | Band: 4
#   Madiha Ali | CoB (NBS) | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 3:
#   Asher Nelson | SPMS | Male | GPA: 4.21 | Band: 1
#   Owen Nugroho | MAE | Male | GPA: 4.15 | Band: 2
#   Hannah Smith | CoE | Female | GPA: 4.11 | Band: 3
#   Kate Tan | CoE | Female | GPA: 4.03 | Band: 4
#   Ying Wong | SoH | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 4:
#   Riley Lim | SoH | Male | GPA: 4.48 | Band: 1
#   Kevin Brown | EEE | Male | GPA: 4.18 | Band: 2
#   Rachel Choi | CoB (NBS) | Female | GPA: 4.12 | Band: 3
#   Shayla Wang | NIE | Female | GPA: 4.01 | Band: 4
#   Zoe King | ASE | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.13
#
# Group 5:
#   Daphne Tan | CCEB | Female | GPA: 4.26 | Band: 1
#   Xiao Ming | CoE | Male | GPA: 4.17 | Band: 2
#   Manish Singh | SBS | Male | GPA: 4.10 | Band: 3
#   Rishi Tan | CCDS | Male | GPA: 4.08 | Band: 4
#   Gia Tsai | SPMS | Female | GPA: 3.89 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.10
#
# Group 6:
#   Nguyen Thi Binh | CCDS | Female | GPA: 4.21 | Band: 1
#   Fatima Bhatia | ASE | Female | GPA: 4.19 | Band: 2
#   Christopher Cox | CCDS | Male | GPA: 4.12 | Band: 3
#   Jasper Wang | CCEB | Male | GPA: 4.08 | Band: 4
#   Kexin | LKCMedicine | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.12
#
# Group 7:
#   Evelyn Cheung | SBS | Female | GPA: 4.48 | Band: 1
#   Amaya Sharma | CoE | Female | GPA: 4.15 | Band: 2
#   Jaxon Lewis | EEE | Male | GPA: 4.12 | Band: 3
#   Nguyen Hoang Long | NIE | Male | GPA: 4.05 | Band: 4
#   Kieran Harris | MAE | Male | GPA: 3.91 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.14
#
# Group 8:
#   Zadie Harris | MAE | Female | GPA: 4.52 | Band: 1
#   Sophia Jones | CoB (NBS) | Female | GPA: 4.18 | Band: 2
#   Sandeep Rao | EEE | Male | GPA: 4.14 | Band: 3
#   Suraj Mishra | CoB (NBS) | Male | GPA: 4.08 | Band: 4
#   Jin Yang Tan | CoB (NBS) | Male | GPA: 3.95 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.17
#
# Group 9:
#   Lola Tan | SSS | Female | GPA: 4.20 | Band: 1
#   Khayla Rahayu | CCEB | Female | GPA: 4.15 | Band: 2
#   Eli Cruz | MSE | Male | GPA: 4.11 | Band: 3
#   Carter Thompson | SPMS | Male | GPA: 4.03 | Band: 4
#   Weijun | SPMS | Male | GPA: 3.85 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.07
#
# Group 10:
#   Savannah Torres | CCEB | Female | GPA: 4.20 | Band: 1
#   Isla Young | SBS | Female | GPA: 4.17 | Band: 2
#   Lucas Chen | CCDS | Male | GPA: 4.12 | Band: 3
#   Qi Chen | SPMS | Male | GPA: 4.04 | Band: 4
#   Wyatt Price | NIE | Male | GPA: 3.95 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.10
#
# ============================================================
#
# Reading batch 5 (students 201 to 250)...
# Processing 50 students in batch 5...
# === BATCH 5 ===
# Total students in this batch: 50
#
# Group 1:
#   Hao Yang Tan | MSE | Male | GPA: 4.30 | Band: 1
#   Raj Tan | SBS | Male | GPA: 4.17 | Band: 2
#   Nira Gupta | WKW SCI | Female | GPA: 4.12 | Band: 3
#   Liu Fang | SPMS | Female | GPA: 4.03 | Band: 4
#   Anjali Kumar | SSS | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.11
#
# Group 2:
#   Elisha Wu | NIE | Male | GPA: 4.23 | Band: 1
#   Henry Tan | MAE | Male | GPA: 4.12 | Band: 2
#   Kiran Shah | SSS | Female | GPA: 4.12 | Band: 3
#   Margarita Sokolova | SSS | Female | GPA: 4.03 | Band: 4
#   Sakshi Iyer | MAE | Female | GPA: 3.94 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 3:
#   Yong Hui | MAE | Male | GPA: 4.21 | Band: 1
#   Felix Wong | SSS | Male | GPA: 4.14 | Band: 2
#   Megan Walker | CEE | Female | GPA: 4.06 | Band: 3
#   Layla Cooper | MSE | Female | GPA: 4.03 | Band: 4
#   Nafisa Ali | EEE | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 4:
#   Ajay Bhatt | CCDS | Male | GPA: 4.22 | Band: 1
#   Ulysses Salazar | MAE | Male | GPA: 4.20 | Band: 2
#   Alina Awan | EEE | Female | GPA: 4.10 | Band: 3
#   Svetlana Chernyshova | LKCMedicine | Female | GPA: 4.06 | Band: 4
#   Min-Ji Park | SoH | Female | GPA: 4.03 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.12
#
# Group 5:
#   Omar Farooq | MAE | Male | GPA: 4.20 | Band: 1
#   Sakshi Singh | SSS | Female | GPA: 4.14 | Band: 2
#   Luca Torres | SoH | Male | GPA: 4.12 | Band: 3
#   Lyric Tan | EEE | Female | GPA: 4.04 | Band: 4
#   Melati Ahmad | CCDS | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 6:
#   Aria Murphy | CCEB | Female | GPA: 4.20 | Band: 1
#   Fariha Noor | CoE | Female | GPA: 4.14 | Band: 2
#   Bradley Yang | CEE | Male | GPA: 4.09 | Band: 3
#   Levi Huang | EEE | Male | GPA: 4.04 | Band: 4
#   Simran Singh | SBS | Female | GPA: 4.03 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.10
#
# Group 7:
#   Nisha Gupta | CoB (NBS) | Female | GPA: 4.21 | Band: 1
#   Gina Lau | CoB (NBS) | Female | GPA: 4.15 | Band: 2
#   Wyatt Thompson | NIE | Male | GPA: 4.09 | Band: 3
#   Cheng Fang Tan | SPMS | Male | GPA: 4.05 | Band: 4
#   Pranata Santoso | MSE | Male | GPA: 3.95 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 8:
#   Zoe Martinez | MAE | Female | GPA: 4.21 | Band: 1
#   Kanwal Bukhari | CoB (NBS) | Female | GPA: 4.16 | Band: 2
#   Hansel Bautista | SSS | Male | GPA: 4.06 | Band: 3
#   Asher Clark | SBS | Male | GPA: 4.03 | Band: 4
#   Travis Lim | SoH | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 9:
#   Sofia Hernandez | CCDS | Female | GPA: 4.26 | Band: 1
#   Maya Sari | CoE | Female | GPA: 4.15 | Band: 2
#   Zara Lim | CCEB | Female | GPA: 4.10 | Band: 3
#   Maximus Wright | CoE | Male | GPA: 4.05 | Band: 4
#   Minh Tran | CCDS | Male | GPA: 4.03 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.12
#
# Group 10:
#   Maharani Sari | CCEB | Female | GPA: 4.30 | Band: 1
#   Lan Nguyen | CCDS | Female | GPA: 4.15 | Band: 2
#   Nina Phillips | SBS | Female | GPA: 4.11 | Band: 3
#   Harsh Kumar | EEE | Male | GPA: 4.05 | Band: 4
#   Riku Takeda | WKW SCI | Male | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.12
#
# ============================================================
#
# Reading batch 6 (students 251 to 300)...
# Processing 50 students in batch 6...
# === BATCH 6 ===
# Total students in this batch: 50
#
# Group 1:
#   Dev Sharma | ASE | Male | GPA: 4.26 | Band: 1
#   Hikaru Sato | NIE | Male | GPA: 4.14 | Band: 2
#   Amna Bukhari | CCEB | Female | GPA: 4.11 | Band: 3
#   Yuna Wong | SBS | Female | GPA: 4.07 | Band: 4
#   Layla Fisher | SBS | Female | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.12
#
# Group 2:
#   David Young | CoE | Male | GPA: 4.19 | Band: 1
#   Everett Harris | CEE | Male | GPA: 4.14 | Band: 2
#   Carmen Ong | SoH | Female | GPA: 4.09 | Band: 3
#   Emily Scott | EEE | Female | GPA: 4.07 | Band: 4
#   Maggie Kwan | CCEB | Female | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 3:
#   Tommy Wu | SSS | Male | GPA: 4.22 | Band: 1
#   Samantha Khan | CoB (NBS) | Female | GPA: 4.19 | Band: 2
#   Mansoor Qureshi | CEE | Male | GPA: 4.12 | Band: 3
#   Queenie Lee | SoH | Female | GPA: 4.06 | Band: 4
#   Selina Loh | CoB (NBS) | Female | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.10
#
# Group 4:
#   Chong Wang | CoB (NBS) | Male | GPA: 4.25 | Band: 1
#   Sofia Kim | EEE | Female | GPA: 4.17 | Band: 2
#   Tyler Hall | CEE | Male | GPA: 4.11 | Band: 3
#   Shiloh Lin | LKCMedicine | Female | GPA: 4.05 | Band: 4
#   Nadia Binti Zulkifli | MSE | Female | GPA: 3.87 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 5:
#   Naim Bin Hashim | MSE | Male | GPA: 4.20 | Band: 1
#   Amira Tan | CCDS | Female | GPA: 4.15 | Band: 2
#   Talha Iqbal | CoE | Male | GPA: 4.11 | Band: 3
#   Saad Malik | MSE | Male | GPA: 4.05 | Band: 4
#   Yvonne Ng | CEE | Female | GPA: 3.80 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.06
#
# Group 6:
#   Fatima Baig | CCDS | Female | GPA: 4.25 | Band: 1
#   Willow Wong | EEE | Female | GPA: 4.19 | Band: 2
#   Zachary Lee | CoB (NBS) | Male | GPA: 4.11 | Band: 3
#   Isaac Thompson | EEE | Male | GPA: 4.03 | Band: 4
#   Eli Tan | ASE | Male | GPA: 3.88 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 7:
#   Maya Gonzales | SSS | Female | GPA: 4.22 | Band: 1
#   Fatima Malik | MAE | Female | GPA: 4.18 | Band: 2
#   Ethan White | SoH | Male | GPA: 4.11 | Band: 3
#   Dallas Huang | CEE | Male | GPA: 4.09 | Band: 4
#   Graham Jackson | SBS | Male | GPA: 3.97 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.11
#
# Group 8:
#   Hannah Sanders | CCDS | Female | GPA: 4.20 | Band: 1
#   Anjali Singh | SSS | Female | GPA: 4.16 | Band: 2
#   Vikram Singh | EEE | Male | GPA: 4.13 | Band: 3
#   Khalil Bin Ismail | SSS | Male | GPA: 4.09 | Band: 4
#   Irfan Bin Hassan | SPMS | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.12
#
# Group 9:
#   Asha Mehta | CCDS | Female | GPA: 4.52 | Band: 1
#   Kylie Chen | MAE | Female | GPA: 4.15 | Band: 2
#   Vy Nguyen | WKW SCI | Male | GPA: 4.11 | Band: 3
#   Fahim Hussein | CCDS | Male | GPA: 4.03 | Band: 4
#   Alan Chan | CEE | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.16
#
# Group 10:
#   Camila Li | MAE | Female | GPA: 4.27 | Band: 1
#   Aria Martinez | EEE | Female | GPA: 4.18 | Band: 2
#   Maya Wilson | SoH | Female | GPA: 4.13 | Band: 3
#   Simon Lee | CoB (NBS) | Male | GPA: 4.02 | Band: 4
#   Xiao Wei Tan | CEE | Male | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.11
#
# ============================================================
#
# Reading batch 7 (students 301 to 350)...
# Processing 50 students in batch 7...
# === BATCH 7 ===
# Total students in this batch: 50
#
# Group 1:
#   William Yip | EEE | Male | GPA: 4.22 | Band: 1
#   Waleed Malik | ASE | Male | GPA: 4.15 | Band: 2
#   Lila Wu | MAE | Female | GPA: 4.06 | Band: 3
#   Chloe Wu | MAE | Female | GPA: 4.03 | Band: 4
#   Nia Wong | CCEB | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 2:
#   Eamon Liu | NIE | Male | GPA: 4.16 | Band: 1
#   Shahid Ali | CCDS | Male | GPA: 4.11 | Band: 2
#   Ashna Mehta | SoH | Female | GPA: 4.06 | Band: 3
#   Isha Verma | SBS | Female | GPA: 4.03 | Band: 4
#   Lily Ong | CoB (NBS) | Female | GPA: 3.93 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 3:
#   Ryder Ward | MAE | Male | GPA: 4.15 | Band: 1
#   Anil Reddy | SoH | Male | GPA: 4.14 | Band: 2
#   Vera Ong | MAE | Female | GPA: 4.09 | Band: 3
#   Dahlia Chen | NIE | Female | GPA: 4.04 | Band: 4
#   Madison Scott | CoB (NBS) | Female | GPA: 3.92 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 4:
#   Jun Zhang | CoE | Male | GPA: 4.19 | Band: 1
#   Benjamin Huang | WKW SCI | Male | GPA: 4.11 | Band: 2
#   Anita Lim | CCDS | Female | GPA: 4.06 | Band: 3
#   Emily Johnson | SoH | Female | GPA: 4.03 | Band: 4
#   Anaya Singh | EEE | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 5:
#   Jason Tan | CCDS | Male | GPA: 4.16 | Band: 1
#   Rafael Wong | CCDS | Male | GPA: 4.11 | Band: 2
#   Sarah Liu | SPMS | Female | GPA: 4.09 | Band: 3
#   Kamran Farooq | EEE | Male | GPA: 4.01 | Band: 4
#   Chloe Scott | SBS | Female | GPA: 3.85 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.04
#
# Group 6:
#   Leo Pranata | CoB (NBS) | Male | GPA: 4.20 | Band: 1
#   Samantha Ong | SSS | Female | GPA: 4.10 | Band: 2
#   Zhen Zhang | CoB (NBS) | Male | GPA: 4.06 | Band: 3
#   Gideon Zhang | SPMS | Male | GPA: 4.01 | Band: 4
#   Fitri Binti Mohd | CCDS | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.07
#
# Group 7:
#   Emi Yamashita | CCDS | Female | GPA: 4.22 | Band: 1
#   Xena Reed | NIE | Female | GPA: 4.11 | Band: 2
#   Daniel Adams | CCDS | Male | GPA: 4.05 | Band: 3
#   Chandra Menon | ASE | Male | GPA: 4.03 | Band: 4
#   Zainab Noor | SoH | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 8:
#   Nisha Yadav | SSS | Female | GPA: 4.18 | Band: 1
#   Giselle Wu | SSS | Female | GPA: 4.14 | Band: 2
#   Nancy Yeo | SSS | Female | GPA: 4.08 | Band: 3
#   Lance Alvarado | CoE | Male | GPA: 4.04 | Band: 4
#   John Lim | WKW SCI | Male | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 9:
#   Chloe Tan | CCDS | Female | GPA: 4.17 | Band: 1
#   Pallavi Mehta | CEE | Female | GPA: 4.09 | Band: 2
#   Maya Rahman | CCEB | Female | GPA: 4.06 | Band: 3
#   Prashant Joshi | CCEB | Male | GPA: 4.03 | Band: 4
#   Gracelyn Dela Cruz | SSS | Female | GPA: 3.96 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.06
#
# Group 10:
#   Ying Zhang | EEE | Female | GPA: 4.18 | Band: 1
#   Priya Roy | EEE | Female | GPA: 4.11 | Band: 2
#   Sophia Taylor | WKW SCI | Female | GPA: 4.06 | Band: 3
#   Gideon Torres | CoB (NBS) | Male | GPA: 4.04 | Band: 4
#   Tara Wati | NIE | Female | GPA: 3.85 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.05
#
# ============================================================
#
# Reading batch 8 (students 351 to 400)...
# Processing 50 students in batch 8...
# === BATCH 8 ===
# Total students in this batch: 50
#
# Group 1:
#   Chen Bo | CEE | Male | GPA: 4.17 | Band: 1
#   Kiran Rao | SPMS | Male | GPA: 4.15 | Band: 2
#   Ping An | CoB (NBS) | Female | GPA: 4.10 | Band: 3
#   Kylie Zhang | SBS | Female | GPA: 4.04 | Band: 4
#   Olivia Miller | WKW SCI | Female | GPA: 3.87 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 2:
#   Imran Bin Zahid | CCDS | Male | GPA: 4.30 | Band: 1
#   Nicolas Ramos | CoB (NBS) | Male | GPA: 4.14 | Band: 2
#   Sabrina Zhao | CCEB | Female | GPA: 4.11 | Band: 3
#   Yumi Tanaka | ASE | Female | GPA: 4.03 | Band: 4
#   Vira Dwi | CCEB | Female | GPA: 3.80 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 3:
#   Max Johnson | SoH | Male | GPA: 4.21 | Band: 1
#   Saad Javed | ADM | Male | GPA: 4.15 | Band: 2
#   Pallavi Kumar | SSS | Female | GPA: 4.10 | Band: 3
#   Julia Tan | MAE | Female | GPA: 4.04 | Band: 4
#   Isabella Rodriguez | EEE | Female | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 4:
#   Callum Williams | SoH | Male | GPA: 4.19 | Band: 1
#   Dao Tran | MSE | Male | GPA: 4.15 | Band: 2
#   Chen Li | SBS | Female | GPA: 4.12 | Band: 3
#   Tatum Roberts | CCDS | Female | GPA: 4.06 | Band: 4
#   Aditi Kumar | SSS | Female | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.11
#
# Group 5:
#   Yang Jun | CCDS | Male | GPA: 4.17 | Band: 1
#   Bennett Liu | CCDS | Male | GPA: 4.14 | Band: 2
#   Alyssa Tan | CCDS | Female | GPA: 4.10 | Band: 3
#   Addison Lin | SSS | Female | GPA: 4.02 | Band: 4
#   Maya Torres | CCDS | Female | GPA: 3.92 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 6:
#   Charlotte Gonzalez | MAE | Female | GPA: 4.22 | Band: 1
#   Amit Agarwal | EEE | Male | GPA: 4.15 | Band: 2
#   Jonathan Wu | CoB (NBS) | Male | GPA: 4.09 | Band: 3
#   Mei Chen | SSS | Female | GPA: 4.02 | Band: 4
#   Arjun Nair | MAE | Male | GPA: 3.92 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 7:
#   Qiana Lestari | NIE | Female | GPA: 4.25 | Band: 1
#   Tessa Li | EEE | Female | GPA: 4.14 | Band: 2
#   Kunal Mehta | SoH | Male | GPA: 4.12 | Band: 3
#   Trung Le | CEE | Male | GPA: 4.06 | Band: 4
#   Vincent Wong | CoB (NBS) | Male | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.12
#
# Group 8:
#   Lola Zhang | MAE | Female | GPA: 4.22 | Band: 1
#   Amina Binti Zain | EEE | Female | GPA: 4.15 | Band: 2
#   Logan Martin | MAE | Male | GPA: 4.12 | Band: 3
#   Dallas Liu | NIE | Male | GPA: 4.05 | Band: 4
#   Haruki Suzuki | CoB (NBS) | Male | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.11
#
# Group 9:
#   Sophie Reed | SSS | Female | GPA: 4.23 | Band: 1
#   Cora Zhang | CoB (NBS) | Female | GPA: 4.15 | Band: 2
#   James Jackson | CEE | Male | GPA: 4.09 | Band: 3
#   Ricky Chen | CoE | Male | GPA: 4.09 | Band: 4
#   Shahid Raza | MAE | Male | GPA: 4.02 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.12
#
# Group 10:
#   Daphne Li | EEE | Female | GPA: 4.26 | Band: 1
#   Nisha Bansal | SSS | Female | GPA: 4.15 | Band: 2
#   Claudia Tan | CoB (NBS) | Female | GPA: 4.09 | Band: 3
#   Ronald Tan | CEE | Male | GPA: 4.05 | Band: 4
#   Devansh Mehta | CCDS | Male | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.11
#
# ============================================================
#
# Reading batch 9 (students 401 to 450)...
# Processing 50 students in batch 9...
# === BATCH 9 ===
# Total students in this batch: 50
#
# Group 1:
#   Cole Huang | EEE | Male | GPA: 4.19 | Band: 1
#   Om Tan | CCEB | Male | GPA: 4.15 | Band: 2
#   Quinn Larson | CCEB | Female | GPA: 4.12 | Band: 3
#   Charlotte Harris | SPMS | Female | GPA: 4.02 | Band: 4
#   Neelam Rani | CCEB | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 2:
#   Fahad Ali | MAE | Male | GPA: 4.19 | Band: 1
#   Reyansh Iyer | SPMS | Male | GPA: 4.14 | Band: 2
#   Miyu Nishimura | SoH | Female | GPA: 4.06 | Band: 3
#   Megan Zhao | MAE | Female | GPA: 4.01 | Band: 4
#   Aria Lee | CCEB | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 3:
#   Harrison Moore | EEE | Male | GPA: 4.19 | Band: 1
#   Hafiz Ahmad | WKW SCI | Male | GPA: 4.14 | Band: 2
#   Priya Nair | CCEB | Female | GPA: 4.12 | Band: 3
#   Gabriella Dela Cruz | MAE | Female | GPA: 4.01 | Band: 4
#   Zara Malik | EEE | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 4:
#   Jason Robinson | CoE | Male | GPA: 4.52 | Band: 1
#   Siddharth Gupta | CoB (NBS) | Male | GPA: 4.14 | Band: 2
#   Akemi Takahashi | EEE | Female | GPA: 4.12 | Band: 3
#   Aria Tan | CCDS | Female | GPA: 4.04 | Band: 4
#   Sienna Lee | CCDS | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.14
#
# Group 5:
#   Nolan Reyes | MAE | Male | GPA: 4.16 | Band: 1
#   Jingyi | SSS | Female | GPA: 4.15 | Band: 2
#   Noah Morris | SoH | Male | GPA: 4.11 | Band: 3
#   Minghao | CoB (NBS) | Female | GPA: 4.00 | Band: 4
#   Arya Kapoor | CCEB | Female | GPA: 3.97 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 6:
#   Oscar Villanueva | CoE | Male | GPA: 4.19 | Band: 1
#   Guofeng | CoE | Female | GPA: 4.15 | Band: 2
#   Rahul Mehta | MAE | Male | GPA: 4.08 | Band: 3
#   Cleo Morales | NIE | Female | GPA: 4.02 | Band: 4
#   Jun Liu | EEE | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 7:
#   Noel Pineda | EEE | Male | GPA: 4.19 | Band: 1
#   Tania Ng | CCEB | Female | GPA: 4.15 | Band: 2
#   Nikhil Sharma | WKW SCI | Male | GPA: 4.11 | Band: 3
#   Zedrick Ong | MAE | Male | GPA: 4.05 | Band: 4
#   Sergei Ivanovich | SPMS | Male | GPA: 4.00 | Band: 5
#   Summary: 4 males, 1 females, Average GPA: 4.10
#
# Group 8:
#   Kavitha Tan | EEE | Female | GPA: 4.30 | Band: 1
#   Isla Lee | MAE | Female | GPA: 4.15 | Band: 2
#   Oliver Martinez | CoB (NBS) | Male | GPA: 4.12 | Band: 3
#   Hoang Nguyen | ADM | Male | GPA: 4.02 | Band: 4
#   Dylan Li | EEE | Male | GPA: 3.90 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.10
#
# Group 9:
#   Mira Binti Zaki | SoH | Female | GPA: 4.20 | Band: 1
#   Eun-Hee Kim | NIE | Female | GPA: 4.14 | Band: 2
#   Kevin Wang | MAE | Male | GPA: 4.09 | Band: 3
#   Albert Wang | EEE | Male | GPA: 4.01 | Band: 4
#   Gandhi Saputra | CCEB | Male | GPA: 3.95 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 10:
#   Nisha Verma | LKCMedicine | Female | GPA: 4.18 | Band: 1
#   Piper Chen | CCDS | Female | GPA: 4.15 | Band: 2
#   Kathy Tan | CCEB | Female | GPA: 4.05 | Band: 3
#   Jai Mehta | SPMS | Male | GPA: 4.00 | Band: 4
#   Thomas Harris | CCDS | Male | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# ============================================================
#
# Reading batch 10 (students 451 to 500)...
# Processing 50 students in batch 10...
# === BATCH 10 ===
# Total students in this batch: 50
#
# Group 1:
#   Zane Navarro | CoB (NBS) | Male | GPA: 4.18 | Band: 1
#   Omar Rivera | SSS | Male | GPA: 4.12 | Band: 2
#   Ananya Roy | MAE | Female | GPA: 4.08 | Band: 3
#   Lana Tan | CCDS | Female | GPA: 4.00 | Band: 4
#   Zulaikha Binti Rahman | CCEB | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 2:
#   Qiang Zhang | SPMS | Male | GPA: 4.20 | Band: 1
#   Carter Hall | EEE | Male | GPA: 4.14 | Band: 2
#   Rina Ali | CCEB | Female | GPA: 4.09 | Band: 3
#   Xiaoling Chen | EEE | Female | GPA: 4.02 | Band: 4
#   Kavita Singh | CoB (NBS) | Female | GPA: 3.89 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 3:
#   Sana Menon | EEE | Female | GPA: 4.22 | Band: 1
#   Archer Powell | NIE | Male | GPA: 4.12 | Band: 2
#   Kai Qiang | CEE | Male | GPA: 4.04 | Band: 3
#   Jia Li | SBS | Female | GPA: 4.03 | Band: 4
#   Min-Jung Kim | ASE | Female | GPA: 3.85 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.05
#
# Group 4:
#   Lily Lim | CEE | Female | GPA: 4.19 | Band: 1
#   Liu Yang | SPMS | Male | GPA: 4.16 | Band: 2
#   Yuri Grigorev | CEE | Male | GPA: 4.10 | Band: 3
#   Le Van Minh | CCEB | Female | GPA: 4.02 | Band: 4
#   Nguyen Thi Hoa | CCDS | Female | GPA: 3.87 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 5:
#   Samantha Sanchez | CoB (NBS) | Female | GPA: 4.25 | Band: 1
#   Karan Patel | WKW SCI | Male | GPA: 4.14 | Band: 2
#   Emery Wu | NIE | Male | GPA: 4.10 | Band: 3
#   Cheryl Ong | CCEB | Female | GPA: 4.00 | Band: 4
#   Yumi Hayashi | SBS | Female | GPA: 3.89 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 6:
#   Victoria Reyes | MAE | Female | GPA: 4.20 | Band: 1
#   Nina Zhao | WKW SCI | Female | GPA: 4.15 | Band: 2
#   Arjun Sinha | EEE | Male | GPA: 4.09 | Band: 3
#   Xiangqi | EEE | Male | GPA: 4.00 | Band: 4
#   Charu Iyer | SSS | Female | GPA: 3.92 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 7:
#   Bria Tsai | MAE | Female | GPA: 4.23 | Band: 1
#   Suresh Bhat | CoE | Female | GPA: 4.14 | Band: 2
#   Vera Chan | CCEB | Female | GPA: 4.10 | Band: 3
#   Xiao Zhang | EEE | Male | GPA: 4.02 | Band: 4
#   Joko Susanto | MAE | Male | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 8:
#   Saanvi Roy | CCEB | Female | GPA: 4.25 | Band: 1
#   Hayden Wu | CCDS | Female | GPA: 4.12 | Band: 2
#   Meera Gupta | EEE | Female | GPA: 4.04 | Band: 3
#   Chad Dela Cruz | SPMS | Male | GPA: 4.02 | Band: 4
#   Tanishq Reddy | WKW SCI | Male | GPA: 3.92 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 9:
#   Amelia Lewis | SPMS | Female | GPA: 4.22 | Band: 1
#   Misha Malik | CoB (NBS) | Female | GPA: 4.14 | Band: 2
#   Amara Siti | SSS | Female | GPA: 4.03 | Band: 3
#   Zane Wong | CCDS | Male | GPA: 4.03 | Band: 4
#   Harvey Lim | MAE | Male | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 10:
#   Riana Binti Abdul | MSE | Female | GPA: 4.25 | Band: 1
#   Madison Torres | SPMS | Female | GPA: 4.12 | Band: 2
#   Samreen Ali | CCDS | Female | GPA: 4.07 | Band: 3
#   Daniel Tan | CEE | Male | GPA: 4.00 | Band: 4
#   Nina Binti Noor | ASE | Female | GPA: 3.86 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.06
#
# ============================================================
#
# Reading batch 11 (students 501 to 550)...
# Processing 50 students in batch 11...
# === BATCH 11 ===
# Total students in this batch: 50
#
# Group 1:
#   Cameron Ward | CCDS | Male | GPA: 4.19 | Band: 1
#   Chen Ming | MAE | Male | GPA: 4.11 | Band: 2
#   Malia Tan | CEE | Female | GPA: 4.08 | Band: 3
#   Harini Nair | EEE | Female | GPA: 4.02 | Band: 4
#   Camila Allen | ADM | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 2:
#   Asher Thompson | SPMS | Male | GPA: 4.52 | Band: 1
#   Shoji Takahashi | EEE | Male | GPA: 4.11 | Band: 2
#   Priya Menon | SSS | Female | GPA: 4.09 | Band: 3
#   Renee Lee | CCEB | Female | GPA: 4.01 | Band: 4
#   Rafika Binti Harun | WKW SCI | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.13
#
# Group 3:
#   Caleb Parker | CoB (NBS) | Male | GPA: 4.18 | Band: 1
#   Rizqi Bin Farhan | MAE | Male | GPA: 4.15 | Band: 2
#   Vidya Menon | SSS | Female | GPA: 4.07 | Band: 3
#   Pooja Nair | MAE | Female | GPA: 4.03 | Band: 4
#   Maya Devi | EEE | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 4:
#   Liang Bo | CoE | Male | GPA: 4.19 | Band: 1
#   Shun Takahashi | SSS | Male | GPA: 4.11 | Band: 2
#   Nadya Zainal | MSE | Female | GPA: 4.09 | Band: 3
#   Mae Chang | SBS | Female | GPA: 4.02 | Band: 4
#   Hina Waseem | CCDS | Female | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 5:
#   Matthew Martinez | CEE | Male | GPA: 4.57 | Band: 1
#   Mason King | CCDS | Male | GPA: 4.18 | Band: 2
#   Lindsey Lin | CCEB | Female | GPA: 4.10 | Band: 3
#   Riya Mehta | CoB (NBS) | Female | GPA: 4.02 | Band: 4
#   Yan Mei | CCDS | Female | GPA: 3.87 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.15
#
# Group 6:
#   Shreya Rani | EEE | Female | GPA: 4.22 | Band: 1
#   Kendrick Alvarado | SSS | Male | GPA: 4.18 | Band: 2
#   Zheng Guo | EEE | Male | GPA: 4.08 | Band: 3
#   Rajiv Nair | SoH | Male | GPA: 4.02 | Band: 4
#   Ivy Wang | SSS | Female | GPA: 3.89 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 7:
#   Sophia Lee | CCEB | Female | GPA: 4.22 | Band: 1
#   Julian Wu | WKW SCI | Male | GPA: 4.12 | Band: 2
#   Shahril Bin Hamid | CCDS | Male | GPA: 4.10 | Band: 3
#   Rajendra Kumar | CEE | Male | GPA: 4.01 | Band: 4
#   Siti Aisya Binti Ibrahim | SoH | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 8:
#   Sakura Yamamoto | CCDS | Female | GPA: 4.21 | Band: 1
#   Sheng Liu | SBS | Female | GPA: 4.14 | Band: 2
#   Hugo Long | CoE | Male | GPA: 4.06 | Band: 3
#   Samuel Lee | CoB (NBS) | Male | GPA: 4.02 | Band: 4
#   Aarav Nair | CCDS | Male | GPA: 3.89 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.06
#
# Group 9:
#   Hana Watanabe | EEE | Female | GPA: 4.18 | Band: 1
#   Ruby Diaz | CCDS | Female | GPA: 4.12 | Band: 2
#   Zeeshan Ahmed | CCEB | Male | GPA: 4.06 | Band: 3
#   Nguyen Van Cuong | CEE | Male | GPA: 4.02 | Band: 4
#   Raj Patel | CEE | Male | GPA: 3.80 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.04
#
# Group 10:
#   Tara Lim | EEE | Female | GPA: 4.19 | Band: 1
#   Qing Liu | CoE | Female | GPA: 4.11 | Band: 2
#   Noah Gray | CoB (NBS) | Male | GPA: 4.06 | Band: 3
#   Liam Reddy | NIE | Male | GPA: 4.02 | Band: 4
#   Randy Lim | SSS | Male | GPA: 3.88 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.05
#
# ============================================================
#
# Reading batch 12 (students 551 to 600)...
# Processing 50 students in batch 12...
# === BATCH 12 ===
# Total students in this batch: 50
#
# Group 1:
#   Cheng Wei Yeo | EEE | Male | GPA: 4.20 | Band: 1
#   Cole Moore | CCDS | Male | GPA: 4.17 | Band: 2
#   Hana Takemura | CoB (NBS) | Female | GPA: 4.11 | Band: 3
#   Ophelia Santos | CCDS | Female | GPA: 4.01 | Band: 4
#   Ritika Joshi | MAE | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 2:
#   Kong Wei Tan | EEE | Male | GPA: 4.22 | Band: 1
#   Phan Van Hoa | EEE | Male | GPA: 4.17 | Band: 2
#   Liu Hong | CCEB | Female | GPA: 4.12 | Band: 3
#   Miriam Tan | CCEB | Female | GPA: 4.02 | Band: 4
#   Riya Verma | MAE | Female | GPA: 3.85 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 3:
#   Logan Harris | EEE | Male | GPA: 4.22 | Band: 1
#   Ajay Reddy | SPMS | Male | GPA: 4.17 | Band: 2
#   Sana Rehman | CCDS | Female | GPA: 4.11 | Band: 3
#   Alina Smith | SoH | Female | GPA: 4.01 | Band: 4
#   Alia Mohd | EEE | Female | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 4:
#   Zhi Wei Lim | EEE | Male | GPA: 4.22 | Band: 1
#   Norah Ng | CCEB | Female | GPA: 4.14 | Band: 2
#   Fangling | EEE | Male | GPA: 4.05 | Band: 3
#   Hussain Bin Mohd | EEE | Male | GPA: 4.00 | Band: 4
#   Zarina Binti Ibrahim | CCEB | Female | GPA: 3.90 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.06
#
# Group 5:
#   Nori Matsuda | CoB (NBS) | Female | GPA: 4.20 | Band: 1
#   Kanti Gupta | MAE | Female | GPA: 4.17 | Band: 2
#   Asad Ali | MSE | Male | GPA: 4.11 | Band: 3
#   Noah Harris | EEE | Male | GPA: 4.01 | Band: 4
#   Xuefeng | CCEB | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.10
#
# Group 6:
#   Ifti Binti Rahman | CoB (NBS) | Female | GPA: 4.20 | Band: 1
#   Lina Teo | SPMS | Female | GPA: 4.14 | Band: 2
#   James Taylor | CoE | Male | GPA: 4.09 | Band: 3
#   Shahril Bin Muni | NIE | Male | GPA: 4.05 | Band: 4
#   Arav Singh | CCDS | Female | GPA: 3.89 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 7:
#   Carmen Tan | CCEB | Female | GPA: 4.30 | Band: 1
#   Suriya Tan | CoB (NBS) | Female | GPA: 4.19 | Band: 2
#   Cassidy Wang | CoB (NBS) | Female | GPA: 4.12 | Band: 3
#   Nitin Chaudhary | CCDS | Male | GPA: 4.01 | Band: 4
#   Alvin Dela Cruz | EEE | Male | GPA: 3.96 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.12
#
# Group 8:
#   Sofia Wong | CEE | Female | GPA: 4.20 | Band: 1
#   Nia Carter | MSE | Female | GPA: 4.14 | Band: 2
#   Claire Bennett | SBS | Female | GPA: 4.06 | Band: 3
#   Raj Patel | EEE | Male | GPA: 4.05 | Band: 4
#   Rameez Shah | NIE | Male | GPA: 3.96 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 9:
#   Harlow Chen | CCEB | Female | GPA: 4.26 | Band: 1
#   Zoey Chen | CCEB | Female | GPA: 4.15 | Band: 2
#   Hanh Pham | CoB (NBS) | Female | GPA: 4.09 | Band: 3
#   Kendrick White | CEE | Male | GPA: 4.00 | Band: 4
#   Shahrir Bin Rahman | WKW SCI | Male | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 10:
#   Samantha Wilson | CoB (NBS) | Female | GPA: 4.22 | Band: 1
#   Wendy Cheung | CoB (NBS) | Female | GPA: 4.18 | Band: 2
#   Nova Ong | SSS | Female | GPA: 4.08 | Band: 3
#   Kenta Suzuki | CCDS | Male | GPA: 4.02 | Band: 4
#   Maya Binti Rahim | CCEB | Female | GPA: 3.95 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.09
#
# ============================================================
#
# Reading batch 13 (students 601 to 650)...
# Processing 50 students in batch 13...
# === BATCH 13 ===
# Total students in this batch: 50
#
# Group 1:
#   Seth Lim | CoB (NBS) | Male | GPA: 4.22 | Band: 1
#   Jin Lee | SPMS | Male | GPA: 4.15 | Band: 2
#   Riya Khan | CCEB | Female | GPA: 4.04 | Band: 3
#   Charlotte Martin | CoB (NBS) | Female | GPA: 4.01 | Band: 4
#   Ying Zhao | CoB (NBS) | Female | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 2:
#   Chengwei | SPMS | Male | GPA: 4.20 | Band: 1
#   Zhao Rui | EEE | Male | GPA: 4.17 | Band: 2
#   Alondra Santos | CoB (NBS) | Female | GPA: 4.08 | Band: 3
#   Alison Wong | CCDS | Female | GPA: 4.00 | Band: 4
#   Kelly Lim | EEE | Female | GPA: 3.96 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 3:
#   Peiyu | CEE | Male | GPA: 4.30 | Band: 1
#   William Carter | EEE | Male | GPA: 4.10 | Band: 2
#   Chloe Hu | CoB (NBS) | Female | GPA: 4.03 | Band: 3
#   Tara Kumar | EEE | Female | GPA: 4.01 | Band: 4
#   Daya Kumari | SSS | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 4:
#   Jovian Tan | EEE | Male | GPA: 4.22 | Band: 1
#   Hugo Huang | SBS | Male | GPA: 4.17 | Band: 2
#   Peilin | CEE | Female | GPA: 4.05 | Band: 3
#   Lian Liu | MAE | Female | GPA: 4.00 | Band: 4
#   Charlotte Thomas | MAE | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 5:
#   Dylan Anderson | EEE | Male | GPA: 4.25 | Band: 1
#   Liang Mei | EEE | Female | GPA: 4.12 | Band: 2
#   Ethan Ong | CCEB | Male | GPA: 4.08 | Band: 3
#   Julian Tan | CoB (NBS) | Male | GPA: 4.03 | Band: 4
#   Dewi Astuti | MAE | Female | GPA: 3.90 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 6:
#   Aisha Fitria | MSE | Female | GPA: 4.30 | Band: 1
#   Sana Ali | EEE | Female | GPA: 4.15 | Band: 2
#   Sebastian Mitchell | CCDS | Male | GPA: 4.04 | Band: 3
#   William Lim | CoB (NBS) | Male | GPA: 4.01 | Band: 4
#   Nina Butler | SBS | Female | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 7:
#   Neha Kapoor | CoE | Female | GPA: 4.20 | Band: 1
#   Zainab Rahman | CCDS | Female | GPA: 4.15 | Band: 2
#   Noah Wilson | CoB (NBS) | Male | GPA: 4.05 | Band: 3
#   Jacob Howard | EEE | Male | GPA: 4.03 | Band: 4
#   Richa Agarwal | CoB (NBS) | Female | GPA: 3.97 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 8:
#   Tania Kurnia | SSS | Female | GPA: 4.30 | Band: 1
#   Nguyen Hoang Khoa | ADM | Female | GPA: 4.14 | Band: 2
#   Caleb Murphy | CCDS | Male | GPA: 4.05 | Band: 3
#   Tyler Moore | WKW SCI | Male | GPA: 4.02 | Band: 4
#   Elena Vladimirovna | CEE | Female | GPA: 3.87 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 9:
#   Tanvi Agarwal | SSS | Female | GPA: 4.20 | Band: 1
#   Ella Johnson | CoE | Female | GPA: 4.12 | Band: 2
#   Wesley Turner | EEE | Male | GPA: 4.09 | Band: 3
#   Erqi | CCDS | Male | GPA: 4.00 | Band: 4
#   Kunal Tan | CoB (NBS) | Male | GPA: 3.80 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.04
#
# Group 10:
#   Cleo Wang | MAE | Female | GPA: 4.17 | Band: 1
#   Nora Zhang | ADM | Female | GPA: 4.16 | Band: 2
#   Arun Singh | EEE | Male | GPA: 4.06 | Band: 3
#   Ethan Lee | NIE | Male | GPA: 4.02 | Band: 4
#   Tian Yi | WKW SCI | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# ============================================================
#
# Reading batch 14 (students 651 to 700)...
# Processing 50 students in batch 14...
# === BATCH 14 ===
# Total students in this batch: 50
#
# Group 1:
#   Rohan Shah | NIE | Male | GPA: 4.18 | Band: 1
#   Shi Wei Lim | MAE | Male | GPA: 4.10 | Band: 2
#   Brianna Foster | CCEB | Female | GPA: 4.09 | Band: 3
#   Riley Baker | EEE | Female | GPA: 4.03 | Band: 4
#   Chloe Turner | CEE | Female | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 2:
#   Tobias Alonzo | MSE | Male | GPA: 4.16 | Band: 1
#   Kevin Ross | SSS | Male | GPA: 4.11 | Band: 2
#   Nora Alia | SPMS | Female | GPA: 4.08 | Band: 3
#   Mizuki Yamashita | CCDS | Female | GPA: 4.03 | Band: 4
#   Akemi Watanabe | SBS | Female | GPA: 3.87 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.05
#
# Group 3:
#   Silas Kim | CoE | Male | GPA: 4.27 | Band: 1
#   Nashit Lee | CEE | Male | GPA: 4.15 | Band: 2
#   Olga Reyes | MSE | Female | GPA: 4.06 | Band: 3
#   Fatima Binti | CoE | Female | GPA: 4.02 | Band: 4
#   Anya Bogdanova | CCDS | Female | GPA: 3.94 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 4:
#   Jia Wei | EEE | Male | GPA: 4.16 | Band: 1
#   Faisal Malik | CCDS | Male | GPA: 4.15 | Band: 2
#   Emma Black | CCEB | Female | GPA: 4.03 | Band: 3
#   Zara Binti | MAE | Female | GPA: 4.03 | Band: 4
#   Rina Ahmad | CoB (NBS) | Female | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 5:
#   Laila Thomas | CoB (NBS) | Female | GPA: 4.18 | Band: 1
#   Wren Tsai | SoH | Female | GPA: 4.16 | Band: 2
#   Wei Jun | CEE | Male | GPA: 4.10 | Band: 3
#   Samuel Cook | LKCMedicine | Male | GPA: 4.02 | Band: 4
#   Madison Edwards | MAE | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 6:
#   Avery Chan | CoB (NBS) | Female | GPA: 4.21 | Band: 1
#   Quang Vu | CCDS | Female | GPA: 4.14 | Band: 2
#   Jaxon Lee | WKW SCI | Male | GPA: 4.06 | Band: 3
#   Sukanya Das | CCDS | Female | GPA: 4.03 | Band: 4
#   Gage Yang | NIE | Male | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 7:
#   Alana Lee | CoB (NBS) | Female | GPA: 4.19 | Band: 1
#   Ying Mei | MAE | Female | GPA: 4.11 | Band: 2
#   Anthony Liu | EEE | Male | GPA: 4.06 | Band: 3
#   Cheng Wu | CoB (NBS) | Female | GPA: 4.01 | Band: 4
#   Jason Lam | MAE | Male | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 8:
#   Sarah Wang | CoE | Female | GPA: 4.17 | Band: 1
#   Anjali Sharma | CCDS | Female | GPA: 4.10 | Band: 2
#   Glenn Wong | ASE | Male | GPA: 4.05 | Band: 3
#   Nurul Izzah | SSS | Female | GPA: 4.03 | Band: 4
#   Rajesh Desai | CoB (NBS) | Male | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 9:
#   Wendy Chia | EEE | Female | GPA: 4.19 | Band: 1
#   Alaina Chang | SSS | Female | GPA: 4.15 | Band: 2
#   Nash Tan | CEE | Male | GPA: 4.06 | Band: 3
#   Nadia Binti | SBS | Female | GPA: 4.03 | Band: 4
#   Jamal Bin Rahman | MSE | Male | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 10:
#   Aubrey Davis | SBS | Female | GPA: 4.17 | Band: 1
#   Yuna Takahashi | SSS | Female | GPA: 4.11 | Band: 2
#   Vincent Lim | NIE | Male | GPA: 4.08 | Band: 3
#   Ashlyn Wu | CCEB | Female | GPA: 4.01 | Band: 4
#   Eric Wong | SSS | Male | GPA: 4.01 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# ============================================================
#
# Reading batch 15 (students 701 to 750)...
# Processing 50 students in batch 15...
# === BATCH 15 ===
# Total students in this batch: 50
#
# Group 1:
#   Panshi | CoB (NBS) | Male | GPA: 4.30 | Band: 1
#   Tyler Reddy | EEE | Male | GPA: 4.15 | Band: 2
#   Tian Hua | CEE | Male | GPA: 4.09 | Band: 3
#   Lily Scott | ADM | Female | GPA: 4.03 | Band: 4
#   Siti Nurhaliza Binti Idris | CCEB | Female | GPA: 3.80 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.07
#
# Group 2:
#   Kartik Reddy | CoB (NBS) | Male | GPA: 4.30 | Band: 1
#   Shinichi Nakagawa | ASE | Male | GPA: 4.17 | Band: 2
#   Afreen Bukhari | MAE | Male | GPA: 4.12 | Band: 3
#   Madison Bailey | SSS | Female | GPA: 4.03 | Band: 4
#   Haojun | MAE | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.12
#
# Group 3:
#   Mateo Huang | SSS | Male | GPA: 4.52 | Band: 1
#   Thomas Harris | SoH | Male | GPA: 4.15 | Band: 2
#   Caleb Gray | EEE | Male | GPA: 4.10 | Band: 3
# ...
#   Isabella White | SoH | Female | GPA: 3.94 | Band: 4
#   Emily Ho | MAE | Female | GPA: 3.88 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.07
#
# Group 4:
#   Subhash Yadav | SSS | Male | GPA: 4.19 | Band: 1
#   Siddharth Patil | CoE | Male | GPA: 4.11 | Band: 2
#   Caden Rivera | CEE | Male | GPA: 4.03 | Band: 3
#   Layla Tan | EEE | Female | GPA: 3.94 | Band: 4
#   Scarlett Lee | SoH | Female | GPA: 3.89 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.03
#
# Group 5:
#   Jae-Min Park | CCDS | Male | GPA: 4.52 | Band: 1
#   Jesse Bennett | EEE | Male | GPA: 4.11 | Band: 2
#   Quincy Ramos | CoB (NBS) | Male | GPA: 4.05 | Band: 3
#   Riku Nakamura | CoB (NBS) | Male | GPA: 4.00 | Band: 4
#   Kanya Setiawati | EEE | Female | GPA: 3.90 | Band: 5
#   Summary: 4 males, 1 females, Average GPA: 4.12
#
# Group 6:
#   Darren Scott | CoE | Male | GPA: 4.18 | Band: 1
#   Ming Yu | MSE | Male | GPA: 4.12 | Band: 2
#   Rizky Hidayat | CCEB | Male | GPA: 4.10 | Band: 3
#   Nianzu | WKW SCI | Male | GPA: 4.00 | Band: 4
#   Zara Binti Zain | CEE | Female | GPA: 3.91 | Band: 5
#   Summary: 4 males, 1 females, Average GPA: 4.06
#
# Group 7:
#   Matthew Baker | CCDS | Male | GPA: 4.50 | Band: 1
#   Anam Iqbal | SSS | Female | GPA: 4.14 | Band: 2
#   Lillian Cooper | CCEB | Female | GPA: 4.05 | Band: 3
#   Hui Ying Tan | CoB (NBS) | Male | GPA: 4.00 | Band: 4
#   Igor Kuznetsov | CoB (NBS) | Male | GPA: 3.90 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.12
#
# Group 8:
#   Yong Cheng Tan | CoE | Male | GPA: 4.20 | Band: 1
#   Manisha Wadhwa | SoH | Female | GPA: 4.17 | Band: 2
#   Saniya Ali | SSS | Female | GPA: 4.08 | Band: 3
#   Rishabh Yadav | EEE | Male | GPA: 4.01 | Band: 4
#   Souta Watanabe | CoE | Male | GPA: 3.80 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.05
#
# Group 9:
#   Ying Hui | CCDS | Female | GPA: 4.20 | Band: 1
#   Dahlia Cooper | MAE | Female | GPA: 4.10 | Band: 2
#   Malaya Chen | SSS | Female | GPA: 4.03 | Band: 3
#   Aditya Bansal | WKW SCI | Male | GPA: 4.02 | Band: 4
#   Kenta Matsumoto | CCEB | Male | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.04
#
# Group 10:
#   Lijun | EEE | Female | GPA: 4.20 | Band: 1
#   Madeline Wu | SSS | Female | GPA: 4.11 | Band: 2
#   Zara Noor | ADM | Female | GPA: 4.04 | Band: 3
#   Liam Yu | MAE | Male | GPA: 4.01 | Band: 4
#   Koh Tze | NIE | Male | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.05
#
# ============================================================
#
# Reading batch 117 (students 5801 to 5850)...
# Processing 50 students in batch 117...
# === BATCH 117 ===
# Total students in this batch: 50
#
# Group 1:
#   Yun Chen | SBS | Male | GPA: 4.20 | Band: 1
#   Zhao Lei | WKW SCI | Male | GPA: 4.15 | Band: 2
#   Ellie Rivera | SSS | Female | GPA: 4.10 | Band: 3
#   Ying Xue | MSE | Female | GPA: 4.02 | Band: 4
#   Gwen Kwan | MAE | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 2:
#   Jin-Soo Lee | MAE | Male | GPA: 4.17 | Band: 1
#   Alexander Green | EEE | Male | GPA: 4.10 | Band: 2
#   Aditi Chai | SSS | Female | GPA: 4.03 | Band: 3
#   Caiyun | EEE | Female | GPA: 4.00 | Band: 4
#   Aisha Binti Rahman | CCEB | Female | GPA: 3.85 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.03
#
# Group 3:
#   Oscar Lim | EEE | Male | GPA: 4.17 | Band: 1
#   Kunal Sinha | SBS | Male | GPA: 4.12 | Band: 2
#   Jessica Tan | CoB (NBS) | Female | GPA: 4.04 | Band: 3
#   Vera Smith | MSE | Female | GPA: 4.02 | Band: 4
#   Ella Wright | SBS | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.05
#
# Group 4:
#   Marina Tan | CCDS | Female | GPA: 4.17 | Band: 1
#   Ethan Harris | EEE | Male | GPA: 4.14 | Band: 2
#   Asher Li | EEE | Male | GPA: 4.04 | Band: 3
#   Samantha Flores | CoB (NBS) | Female | GPA: 4.02 | Band: 4
#   Ellie Bell | LKCMedicine | Female | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.05
#
# Group 5:
#   Ranya Al-Mansoori | CCDS | Female | GPA: 4.17 | Band: 1
#   Isaiah Li | CoB (NBS) | Male | GPA: 4.15 | Band: 2
#   Liam Wang | EEE | Male | GPA: 4.06 | Band: 3
#   Faisal Bukhari | CoB (NBS) | Female | GPA: 4.03 | Band: 4
#   Yumiko Watanabe | CCEB | Female | GPA: 3.94 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 6:
#   Olive Lim | SBS | Female | GPA: 4.21 | Band: 1
#   Samuel Robinson | CoB (NBS) | Male | GPA: 4.14 | Band: 2
#   Victor Santos | CCDS | Male | GPA: 4.10 | Band: 3
#   Cody Evans | SBS | Male | GPA: 4.02 | Band: 4
#   Zahra Lestari | EEE | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 7:
#   Zhaofeng | CoB (NBS) | Female | GPA: 4.25 | Band: 1
#   Derek Chen | EEE | Male | GPA: 4.10 | Band: 2
#   Manish Verma | CoB (NBS) | Male | GPA: 4.05 | Band: 3
#   Dmitri Andreevich | CEE | Male | GPA: 4.00 | Band: 4
#   Una Kaur | CCEB | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 8:
#   Huilin | SoH | Female | GPA: 4.20 | Band: 1
#   Zara Ali | CCDS | Female | GPA: 4.11 | Band: 2
#   Rida Iqbal | CCEB | Female | GPA: 4.06 | Band: 3
#   Ayaan Shah | CCDS | Male | GPA: 4.02 | Band: 4
#   Jack Peterson | EEE | Male | GPA: 3.95 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 9:
#   Fang Xiu | EEE | Female | GPA: 4.17 | Band: 1
#   Patty Lim | CCDS | Female | GPA: 4.12 | Band: 2
#   Ritika Mehta | CCEB | Female | GPA: 4.08 | Band: 3
#   Dhruv Srivastava | CCDS | Male | GPA: 4.03 | Band: 4
#   Liang Bo | LKCMedicine | Male | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 10:
#   Sophie Taylor | CoB (NBS) | Female | GPA: 4.52 | Band: 1
#   Sophia Smith | MAE | Female | GPA: 4.15 | Band: 2
#   Nadia Binti Ahmad | SSS | Female | GPA: 4.10 | Band: 3
#   Chad Dela Cruz | CoB (NBS) | Male | GPA: 4.02 | Band: 4
#   Anjali Tiwari | LKCMedicine | Female | GPA: 3.94 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.15
#
# ============================================================
#
# Reading batch 118 (students 5851 to 5900)...
# Processing 50 students in batch 118...
# === BATCH 118 ===
# Total students in this batch: 50
#
# Group 1:
#   Wicaksono Adi | CCDS | Male | GPA: 4.20 | Band: 1
#   Long Thi Bich | EEE | Male | GPA: 4.17 | Band: 2
#   Violet Lee | CCEB | Female | GPA: 4.05 | Band: 3
#   Kira Dewi | EEE | Female | GPA: 4.00 | Band: 4
#   Kiran Iyer | CCDS | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 2:
#   Jayden Chen | CoE | Male | GPA: 4.20 | Band: 1
#   Bodhi Yang | SPMS | Male | GPA: 4.17 | Band: 2
#   Layla Zhao | ADM | Female | GPA: 4.10 | Band: 3
#   Kaira Lim | CCDS | Female | GPA: 4.01 | Band: 4
#   Asha Rahman | SSS | Female | GPA: 3.89 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 3:
#   Priti Choudhary | EEE | Female | GPA: 4.26 | Band: 1
#   Zohra Khan | SSS | Female | GPA: 4.18 | Band: 2
#   Alexander Mitchell | CoB (NBS) | Male | GPA: 4.06 | Band: 3
#   Lachlan Thompson | CCEB | Male | GPA: 4.03 | Band: 4
#   Jin-Ah Kim | CCDS | Female | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 4:
#   Rongxian | CCEB | Female | GPA: 4.30 | Band: 1
#   Lola Zhao | CEE | Female | GPA: 4.19 | Band: 2
#   Chao Zhang | CoB (NBS) | Male | GPA: 4.12 | Band: 3
#   Wei Fang | SPMS | Male | GPA: 4.01 | Band: 4
#   Hannah Rogers | SBS | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.10
#
# Group 5:
#   Maya Chua | SBS | Female | GPA: 4.21 | Band: 1
#   Maya Gupta | CoB (NBS) | Female | GPA: 4.14 | Band: 2
#   Tony Tsang | CEE | Male | GPA: 4.07 | Band: 3
#   Quinn Yip | CEE | Male | GPA: 4.04 | Band: 4
#   Margo Wang | CoE | Female | GPA: 3.91 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 6:
#   Bella Ramirez | CoB (NBS) | Female | GPA: 4.26 | Band: 1
#   Olive Wong | CCDS | Female | GPA: 4.18 | Band: 2
#   Bashir Raza | CCDS | Male | GPA: 4.11 | Band: 3
#   Zhou Wei | SBS | Male | GPA: 4.02 | Band: 4
#   Aria Thompson | SBS | Female | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.09
#
# Group 7:
#   Tanya Acharya | CEE | Female | GPA: 4.20 | Band: 1
#   Akira Kobayashi | CoB (NBS) | Female | GPA: 4.14 | Band: 2
#   Bohan | SSS | Female | GPA: 4.10 | Band: 3
#   Adrian Chen | ASE | Male | GPA: 3.97 | Band: 4
#   Ali Raza | EEE | Male | GPA: 3.89 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 8:
#   Scarlett Evans | CoB (NBS) | Female | GPA: 4.20 | Band: 1
#   Ayesha Siddiqui | CCEB | Female | GPA: 4.16 | Band: 2
#   Maya Wood | CCEB | Female | GPA: 4.06 | Band: 3
#   Mei Xuan Tan | CoB (NBS) | Female | GPA: 4.00 | Band: 4
#   Quade Cruz | SSS | Male | GPA: 3.89 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.06
#
# Group 9:
#   Keira Martinez | CCEB | Female | GPA: 4.26 | Band: 1
#   Emily Evans | SSS | Female | GPA: 4.19 | Band: 2
#   Savannah Wood | SBS | Female | GPA: 4.06 | Band: 3
#   Diana Khan | ADM | Female | GPA: 4.00 | Band: 4
#   Grayson Wright | EEE | Male | GPA: 3.89 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.08
#
# Group 10:
#   Mei Liu | SSS | Female | GPA: 4.25 | Band: 1
#   Xiu Ying | CCEB | Female | GPA: 4.17 | Band: 2
#   Siti Aminah Binti Ibrahim | CCDS | Female | GPA: 4.10 | Band: 3
#   Jasmine Wong | MAE | Female | GPA: 4.01 | Band: 4
#   Kinsley Price | CCDS | Female | GPA: 3.87 | Band: 5
#   Summary: 0 males, 5 females, Average GPA: 4.08
#
# ============================================================
#
# Reading batch 119 (students 5901 to 5950)...
# Processing 50 students in batch 119...
# === BATCH 119 ===
# Total students in this batch: 50
#
# Group 1:
#   Josh Thompson | NIE | Male | GPA: 4.18 | Band: 1
#   Jason Lam | CEE | Male | GPA: 4.14 | Band: 2
#   Zhi Xuan | CoB (NBS) | Male | GPA: 4.04 | Band: 3
#   Abigail King | CoB (NBS) | Female | GPA: 4.02 | Band: 4
#   Kaiming | SBS | Female | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 2:
#   Siddharth Mehta | CCDS | Male | GPA: 4.21 | Band: 1
#   Haru Yamaguchi | CCDS | Male | GPA: 4.14 | Band: 2
#   Ryusei Nakamura | MSE | Male | GPA: 4.09 | Band: 3
#   Michelle Lee | SSS | Female | GPA: 4.02 | Band: 4
#   Hana Wong | CoB (NBS) | Female | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.09
#
# Group 3:
#   Gage Fisher | CCDS | Male | GPA: 4.22 | Band: 1
#   Colton Bailey | MAE | Male | GPA: 4.12 | Band: 2
#   Matthew Evans | EEE | Male | GPA: 4.11 | Band: 3
#   Mindy Kwan | SSS | Female | GPA: 4.02 | Band: 4
#   Victoria Reed | MAE | Female | GPA: 3.89 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.07
#
# Group 4:
#   Syahrul Bin Omar | CCDS | Male | GPA: 4.20 | Band: 1
#   Uriah Salazar | EEE | Male | GPA: 4.15 | Band: 2
#   Budi Santoso | CCDS | Male | GPA: 4.05 | Band: 3
#   Tara Menon | EEE | Female | GPA: 4.03 | Band: 4
#   Paige Wang | EEE | Female | GPA: 3.88 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.06
#
# Group 5:
#   Hugo Yang | SoH | Male | GPA: 4.26 | Band: 1
#   Dhruv Singh | CCDS | Male | GPA: 4.14 | Band: 2
#   Henry Hill | WKW SCI | Male | GPA: 4.10 | Band: 3
#   Zoe Lee | EEE | Female | GPA: 4.03 | Band: 4
#   Emily Li | EEE | Female | GPA: 4.01 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.11
#
# Group 6:
#   Malachi Foster | CEE | Male | GPA: 4.26 | Band: 1
#   Liu Chen | ADM | Male | GPA: 4.14 | Band: 2
#   Jay Patel | SoH | Male | GPA: 4.03 | Band: 3
#   Caleb Lim | CCDS | Male | GPA: 4.02 | Band: 4
#   Diana Binti Mohd | MAE | Female | GPA: 3.88 | Band: 5
#   Summary: 4 males, 1 females, Average GPA: 4.07
#
# Group 7:
#   Asher Wang | CCDS | Male | GPA: 4.27 | Band: 1
#   Carter Lee | SPMS | Male | GPA: 4.11 | Band: 2
#   Leah Wilson | SBS | Female | GPA: 4.08 | Band: 3
#   Finnley Brooks | EEE | Male | GPA: 4.02 | Band: 4
#   Umar Sembiring | CoE | Male | GPA: 3.90 | Band: 5
#   Summary: 4 males, 1 females, Average GPA: 4.08
#
# Group 8:
#   Dawn Lim | CCDS | Female | GPA: 4.20 | Band: 1
#   Avery Smith | SSS | Female | GPA: 4.12 | Band: 2
#   Ritika Sharma | ASE | Female | GPA: 4.06 | Band: 3
#   Judah Hall | MSE | Male | GPA: 4.03 | Band: 4
#   Alexander King | SoH | Male | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# Group 9:
#   Asha Devi | CCDS | Female | GPA: 4.52 | Band: 1
#   Katherine Young | CoB (NBS) | Female | GPA: 4.14 | Band: 2
#   Maya Lewis | ADM | Female | GPA: 4.05 | Band: 3
#   Logan Taylor | CCDS | Male | GPA: 4.02 | Band: 4
#   Jae-Suk Jung | CCDS | Male | GPA: 3.97 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.14
#
# Group 10:
#   Nianzu | NIE | Female | GPA: 4.30 | Band: 1
#   Pei Li | CCEB | Female | GPA: 4.18 | Band: 2
#   Nina Lin | CEE | Female | GPA: 4.08 | Band: 3
#   Aiden Chen | EEE | Male | GPA: 4.01 | Band: 4
#   Henry Bennett | SPMS | Male | GPA: 3.85 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.08
#
# ============================================================
#
# Reading batch 120 (students 5951 to 6000)...
# Processing 50 students in batch 120...
# === BATCH 120 ===
# Total students in this batch: 50
#
# Group 1:
#   Kylan Yang | MAE | Male | GPA: 4.18 | Band: 1
#   Rafael De Leon | MSE | Male | GPA: 4.11 | Band: 2
#   Sophie Rivera | SSS | Female | GPA: 4.06 | Band: 3
#   Sana Tan | EEE | Female | GPA: 4.02 | Band: 4
#   Natalia Fedorova | SSS | Female | GPA: 4.00 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 2:
#   Zachary Chen | EEE | Male | GPA: 4.19 | Band: 1
#   Michael Walker | CoE | Male | GPA: 4.14 | Band: 2
#   Ella Santos | SoH | Female | GPA: 4.03 | Band: 3
#   Maya Morgan | CCEB | Female | GPA: 4.03 | Band: 4
#   Amaya Tan | SPMS | Female | GPA: 3.92 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 3:
#   William Yang | CoE | Male | GPA: 4.20 | Band: 1
#   Ikram Tan | CCDS | Male | GPA: 4.11 | Band: 2
#   Aria Wadhwa | EEE | Female | GPA: 4.03 | Band: 3
#   Aaliyah Howard | CoB (NBS) | Female | GPA: 4.00 | Band: 4
#   Aki Yoshida | MAE | Female | GPA: 3.90 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.05
#
# Group 4:
#   Ronin Huang | EEE | Male | GPA: 4.15 | Band: 1
#   Queenie Li | EEE | Female | GPA: 4.12 | Band: 2
#   Phan Duc Minh | WKW SCI | Male | GPA: 4.05 | Band: 3
#   Joanna Tan | CEE | Female | GPA: 4.02 | Band: 4
#   Fatima Iqbal | EEE | Female | GPA: 3.96 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 5:
#   Lian Chen | SSS | Female | GPA: 4.26 | Band: 1
#   Kiran Malhotra | SSS | Female | GPA: 4.08 | Band: 2
#   Nash Li | SPMS | Male | GPA: 4.08 | Band: 3
#   Hassan Shah | WKW SCI | Male | GPA: 4.01 | Band: 4
#   Samantha Rogers | CoE | Female | GPA: 3.88 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.06
#
# Group 6:
#   Karla Bautista | SSS | Female | GPA: 4.15 | Band: 1
#   Natalia Wong | ADM | Female | GPA: 4.11 | Band: 2
#   Niko Setiawan | CEE | Male | GPA: 4.05 | Band: 3
#   Daniel White | NIE | Male | GPA: 4.00 | Band: 4
#   Naoko Ueda | MSE | Female | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.03
#
# Group 7:
#   Xiaoling Zhang | CCEB | Female | GPA: 4.17 | Band: 1
#   Mai Tran | SoH | Female | GPA: 4.14 | Band: 2
#   Qasim Bin Noor | CEE | Male | GPA: 4.05 | Band: 3
#   Vikas Mehta | CCEB | Male | GPA: 4.01 | Band: 4
#   Ali Zain | CoB (NBS) | Male | GPA: 3.94 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.06
#
# Group 8:
#   Katherine Morales | CCDS | Female | GPA: 4.18 | Band: 1
#   Layla Turner | CoB (NBS) | Female | GPA: 4.12 | Band: 2
#   Nobu Yamamoto | WKW SCI | Male | GPA: 4.06 | Band: 3
#   Travis Wong | CCDS | Male | GPA: 4.02 | Band: 4
#   Manoj Patel | CCDS | Male | GPA: 4.00 | Band: 5
#   Summary: 3 males, 2 females, Average GPA: 4.08
#
# Group 9:
#   Meera Shah | SSS | Female | GPA: 4.25 | Band: 1
#   Rina Tan | CCEB | Female | GPA: 4.13 | Band: 2
#   Samuel Wright | CoB (NBS) | Male | GPA: 4.08 | Band: 3
#   Nisha Malik | SoH | Female | GPA: 4.03 | Band: 4
#   Matthew Garcia | MAE | Male | GPA: 3.86 | Band: 5
#   Summary: 2 males, 3 females, Average GPA: 4.07
#
# Group 10:
#   Maya Hughes | ASE | Female | GPA: 4.27 | Band: 1
#   Hana Binti Ali | CCDS | Female | GPA: 4.10 | Band: 2
#   Ruby Nelson | CCDS | Female | GPA: 4.08 | Band: 3
#   Farah Binti Omar | CCEB | Female | GPA: 4.00 | Band: 4
#   Zion Tan | SSS | Male | GPA: 4.00 | Band: 5
#   Summary: 1 males, 4 females, Average GPA: 4.09
#
# Reading batch 121 (students 6001 to 6050)...
# No more students to process.
# Processing complete! Processed 120 batch(es) total.

# %%
import matplotlib.pyplot as plt
import random

# Set random seed for reproducibility
random.seed(42)

# Generate realistic GPA data for 6000 students using only basic Python
def generate_gpa_data(num_students):
    gpa_data = []
    for _ in range(num_students):
        # Generate GPA using uniform distribution between 2.0 and 4.0
        # with some random variation to create a normal-like distribution
        base_gpa = 3.0 + (random.random() - 0.5) * 1.2
        # Add some random noise
        gpa = base_gpa + (random.random() - 0.5) * 0.4
        # Clip to reasonable GPA range
        gpa = max(2.0, min(4.0, gpa))
        gpa_data.append(gpa)
    return gpa_data

# Generate student GPAs
gpa_data = generate_gpa_data(6000)

# Calculate individual student statistics
individual_mean = sum(gpa_data) / len(gpa_data)
individual_min = min(gpa_data)
individual_max = max(gpa_data)

# Form groups of 5 students each (120 groups)
random.shuffle(gpa_data)
groups = []
group_avg_gpa = []

for i in range(0, len(gpa_data), 5):
    if i + 5 <= len(gpa_data):
        group = gpa_data[i:i+5]
        groups.append(group)
        group_avg = sum(group) / len(group)
        group_avg_gpa.append(group_avg)

# Calculate group statistics
group_mean = sum(group_avg_gpa) / len(group_avg_gpa)
group_min = min(group_avg_gpa)
group_max = max(group_avg_gpa)

# Create the visualization
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

# Plot 1: Distribution of individual student GPAs
ax1.hist(gpa_data, bins=30, alpha=0.7, color='skyblue', edgecolor='black')
ax1.axvline(individual_mean, color='red', linestyle='--', linewidth=2, 
            label=f'Mean: {individual_mean:.3f}')
ax1.set_xlabel('GPA')
ax1.set_ylabel('Number of Students')
ax1.set_title('Distribution of Individual Student GPAs\n(6000 Students)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Plot 2: Distribution of group average GPAs
ax2.hist(group_avg_gpa, bins=20, alpha=0.7, color='lightgreen', edgecolor='black')
ax2.axvline(group_mean, color='red', linestyle='--', linewidth=2, 
            label=f'Mean: {group_mean:.3f}')
ax2.set_xlabel('Average GPA')
ax2.set_ylabel('Number of Groups')
ax2.set_title('Distribution of Group Average GPAs\n(120 Groups of 5 Students Each)')
ax2.legend()
ax2.grid(True, alpha=0.3)

# Plot 3: Comparison of distributions
# Individual student GPAs
ax3.hist(gpa_data, bins=30, alpha=0.5, color='skyblue', 
         label='Individual Students', density=True)
# Group average GPAs
ax3.hist(group_avg_gpa, bins=20, alpha=0.5, color='lightgreen', 
         label='Group Averages', density=True)

ax3.set_xlabel('GPA')
ax3.set_ylabel('Density')
ax3.set_title('Comparison: Individual vs Group Average GPA Distributions')
ax3.legend()
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print statistical summary
print("=" * 60)
print("STATISTICAL SUMMARY")
print("=" * 60)
print(f"Individual Student GPAs (n=6000):")
print(f"  Mean: {individual_mean:.3f}")
print(f"  Range: {individual_min:.3f} - {individual_max:.3f}")

print(f"\nGroup Average GPAs (n=120 groups of 5 students):")
print(f"  Mean: {group_mean:.3f}")
print(f"  Range: {group_min:.3f} - {group_max:.3f}")

# Calculate variance manually
def calculate_variance(data):
    mean = sum(data) / len(data)
    squared_diffs = [(x - mean) ** 2 for x in data]
    return sum(squared_diffs) / len(data)

individual_variance = calculate_variance(gpa_data)
group_variance = calculate_variance(group_avg_gpa)

print(f"\nKey Observations:")
print(f"  • Individual GPA variance: {individual_variance:.3f}")
print(f"  • Group average GPA variance: {group_variance:.3f}")
print(f"  • Variance reduction: {individual_variance/group_variance:.1f}x less")

# Count extreme values manually
individual_low_extreme = sum(1 for gpa in gpa_data if gpa < 2.5)
individual_high_extreme = sum(1 for gpa in gpa_data if gpa > 3.5)
group_low_extreme = sum(1 for avg_gpa in group_avg_gpa if avg_gpa < 2.8)
group_high_extreme = sum(1 for avg_gpa in group_avg_gpa if avg_gpa > 3.2)

print(f"\nExtreme Value Analysis:")
print(f"  Individual students with GPA < 2.5: {individual_low_extreme} ({individual_low_extreme/60:.1f}%)")
print(f"  Individual students with GPA > 3.5: {individual_high_extreme} ({individual_high_extreme/60:.1f}%)")
print(f"  Groups with average GPA < 2.8: {group_low_extreme} ({group_low_extreme/1.2:.1f}%)")
print(f"  Groups with average GPA > 3.2: {group_high_extreme} ({group_high_extreme/1.2:.1f}%)")
