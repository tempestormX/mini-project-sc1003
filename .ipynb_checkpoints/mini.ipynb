# %%
import csv
import itertools
import os
import random
import sys


def read_students(start_index=0, count=50, filepath="records.csv"):
    """Read up to count students starting from start_index (after header).
    Returns a list of student dicts with keys: tutorial group, id, school, name, gender, gpa
    """
    students = []
    if not os.path.exists(filepath):
        raise FileNotFoundError(f"{filepath} not found")

    with open(filepath, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        headers = next(reader, None)  # skip header if present

        # skip start_index rows
        for _ in range(start_index):
            try:
                next(reader)
            except StopIteration:
                return students

        for _ in range(count):
            try:
                row = next(reader)
            except StopIteration:
                break
            if len(row) < 6:
                # skip malformed line
                continue
            try:
                gpa = float(row[5])
            except Exception:
                # skip rows with non-numeric GPA
                continue

            student = {
                'tutorial group': row[0].strip(),
                'id': row[1].strip(),
                'school': row[2].strip(),
                'name': row[3].strip(),
                'gender': row[4].strip(),
                'gpa': gpa,
            }
            students.append(student)

    return students
    
read_students(start_index=0, count=50, filepath="records.csv")
# Out:
# Student 1: {'tutorial group': 'G-1', 'id': '5002', 'school': 'CCDS', 'name': 'Aarav Singh', 'gender': 'Male', 'gpa': 4.02}
# Student 2: {'tutorial group': 'G-1', 'id': '3838', 'school': 'EEE', 'name': 'Aarti Nair', 'gender': 'Female', 'gpa': 4.05}
# Student 3: {'tutorial group': 'G-1', 'id': '2091', 'school': 'EEE', 'name': 'Adlan Bin Rahman', 'gender': 'Male', 'gpa': 4.2}
# Student 4: {'tutorial group': 'G-1', 'id': '288', 'school': 'CoB (NBS)', 'name': 'Ajay Verma', 'gender': 'Male', 'gpa': 4.01}
# Student 5: {'tutorial group': 'G-1', 'id': '4479', 'school': 'CCDS', 'name': 'Amelia Kim', 'gender': 'Female', 'gpa': 4.11}
# Student 6: {'tutorial group': 'G-1', 'id': '5708', 'school': 'SoH', 'name': 'Ananya Ramesh', 'gender': 'Male', 'gpa': 4.2}
# Student 7: {'tutorial group': 'G-1', 'id': '4563', 'school': 'WKW SCI', 'name': 'Anjali Patel', 'gender': 'Female', 'gpa': 4.01}
# Student 8: {'tutorial group': 'G-1', 'id': '3989', 'school': 'WKW SCI', 'name': 'Anthony Liu', 'gender': 'Male', 'gpa': 4.15}
# Student 9: {'tutorial group': 'G-1', 'id': '2115', 'school': 'EEE', 'name': 'Anya Kumar', 'gender': 'Female', 'gpa': 4.03}
# Student 10: {'tutorial group': 'G-1', 'id': '1383', 'school': 'CoB (NBS)', 'name': 'Areeba Khan', 'gender': 'Female', 'gpa': 4.19}
# Student 11: {'tutorial group': 'G-1', 'id': '1417', 'school': 'CoE', 'name': 'Darren Lee', 'gender': 'Male', 'gpa': 4.12}
# Student 12: {'tutorial group': 'G-1', 'id': '1075', 'school': 'CoB (NBS)', 'name': 'Felix Yip', 'gender': 'Male', 'gpa': 4.08}
# Student 13: {'tutorial group': 'G-1', 'id': '3148', 'school': 'EEE', 'name': 'Gabriel Young', 'gender': 'Male', 'gpa': 3.88}
# Student 14: {'tutorial group': 'G-1', 'id': '4402', 'school': 'CCDS', 'name': 'Grace Turner', 'gender': 'Female', 'gpa': 4.08}
# Student 15: {'tutorial group': 'G-1', 'id': '945', 'school': 'MAE', 'name': 'Han Li', 'gender': 'Female', 'gpa': 4.1}
# Student 16: {'tutorial group': 'G-1', 'id': '2230', 'school': 'CoB (NBS)', 'name': 'Harlow Wang', 'gender': 'Female', 'gpa': 4.18}
# Student 17: {'tutorial group': 'G-1', 'id': '4520', 'school': 'EEE', 'name': 'Henry Foster', 'gender': 'Male', 'gpa': 4.11}
# Student 18: {'tutorial group': 'G-1', 'id': '567', 'school': 'CoB (NBS)', 'name': 'Isabella Thompson', 'gender': 'Female', 'gpa': 4.03}
# Student 19: {'tutorial group': 'G-1', 'id': '1841', 'school': 'MAE', 'name': 'Jett Morales', 'gender': 'Male', 'gpa': 4.12}
# Student 20: {'tutorial group': 'G-1', 'id': '4576', 'school': 'EEE', 'name': 'Jie Zhang', 'gender': 'Male', 'gpa': 4.03}
# Student 21: {'tutorial group': 'G-1', 'id': '5703', 'school': 'SPMS', 'name': 'Karen Lee', 'gender': 'Female', 'gpa': 4.12}
# Student 22: {'tutorial group': 'G-1', 'id': '2353', 'school': 'SBS', 'name': 'Karen Wong', 'gender': 'Female', 'gpa': 3.95}
# Student 23: {'tutorial group': 'G-1', 'id': '2069', 'school': 'SSS', 'name': 'Kathy Lau', 'gender': 'Female', 'gpa': 4.48}
# Student 24: {'tutorial group': 'G-1', 'id': '3861', 'school': 'ASE', 'name': 'Layla Torres', 'gender': 'Female', 'gpa': 4.52}
# Student 25: {'tutorial group': 'G-1', 'id': '162', 'school': 'SSS', 'name': 'Lila Patel', 'gender': 'Female', 'gpa': 4.07}
# Student 26: {'tutorial group': 'G-1', 'id': '588', 'school': 'MAE', 'name': 'Lucas Walker', 'gender': 'Male', 'gpa': 4.06}
# Student 27: {'tutorial group': 'G-1', 'id': '659', 'school': 'SSS', 'name': 'Maria Ivanovna', 'gender': 'Female', 'gpa': 4.2}
# Student 28: {'tutorial group': 'G-1', 'id': '4820', 'school': 'CoE', 'name': 'Meera Singh', 'gender': 'Female', 'gpa': 4.22}
# Student 29: {'tutorial group': 'G-1', 'id': '2151', 'school': 'EEE', 'name': 'Mei Hong', 'gender': 'Female', 'gpa': 4.02}
# Student 30: {'tutorial group': 'G-1', 'id': '235', 'school': 'CCDS', 'name': 'Ming Zhang', 'gender': 'Male', 'gpa': 4.06}
# Student 31: {'tutorial group': 'G-1', 'id': '527', 'school': 'EEE', 'name': 'Mohit Desai', 'gender': 'Male', 'gpa': 4.06}
# Student 32: {'tutorial group': 'G-1', 'id': '1329', 'school': 'NIE', 'name': 'Nguyen Van Sam', 'gender': 'Male', 'gpa': 3.85}
# Student 33: {'tutorial group': 'G-1', 'id': '5119', 'school': 'ADM', 'name': 'Nhung Vu', 'gender': 'Female', 'gpa': 4.04}
# Student 34: {'tutorial group': 'G-1', 'id': '809', 'school': 'CoB (NBS)', 'name': 'Nisha Das', 'gender': 'Female', 'gpa': 4.26}
# Student 35: {'tutorial group': 'G-1', 'id': '2650', 'school': 'SoH', 'name': 'Nurul Shafika', 'gender': 'Female', 'gpa': 4.09}
# Student 36: {'tutorial group': 'G-1', 'id': '4657', 'school': 'SoH', 'name': 'Oleg Petrovich', 'gender': 'Male', 'gpa': 4.0}
# Student 37: {'tutorial group': 'G-1', 'id': '2818', 'school': 'CoB (NBS)', 'name': 'Oliver Tan', 'gender': 'Male', 'gpa': 4.09}
# Student 38: {'tutorial group': 'G-1', 'id': '3628', 'school': 'EEE', 'name': 'Omer Ahmed', 'gender': 'Male', 'gpa': 4.06}
# Student 39: {'tutorial group': 'G-1', 'id': '1555', 'school': 'MAE', 'name': 'Prerna Gupta', 'gender': 'Female', 'gpa': 4.04}
# Student 40: {'tutorial group': 'G-1', 'id': '1271', 'school': 'SSS', 'name': 'Priya Singh', 'gender': 'Female', 'gpa': 4.17}
# Student 41: {'tutorial group': 'G-1', 'id': '75', 'school': 'CCDS', 'name': 'Sakina Ahmed', 'gender': 'Female', 'gpa': 4.03}
# Student 42: {'tutorial group': 'G-1', 'id': '4338', 'school': 'SPMS', 'name': 'Sana Jain', 'gender': 'Female', 'gpa': 4.22}
# Student 43: {'tutorial group': 'G-1', 'id': '71', 'school': 'SoH', 'name': 'Savannah Taylor', 'gender': 'Female', 'gpa': 4.19}
# Student 44: {'tutorial group': 'G-1', 'id': '2776', 'school': 'CCEB', 'name': 'Siddharth Nair', 'gender': 'Male', 'gpa': 4.14}
# Student 45: {'tutorial group': 'G-1', 'id': '2417', 'school': 'SSS', 'name': 'Truong Minh Chau', 'gender': 'Female', 'gpa': 3.88}
# Student 46: {'tutorial group': 'G-1', 'id': '5477', 'school': 'SoH', 'name': 'Vikram Desai', 'gender': 'Male', 'gpa': 4.09}
# Student 47: {'tutorial group': 'G-1', 'id': '2326', 'school': 'CoB (NBS)', 'name': 'Vivi Dwi', 'gender': 'Female', 'gpa': 3.95}
# Student 48: {'tutorial group': 'G-1', 'id': '3930', 'school': 'EEE', 'name': 'Xun Wei', 'gender': 'Female', 'gpa': 4.18}
# Student 49: {'tutorial group': 'G-1', 'id': '1645', 'school': 'CoE', 'name': 'Zachary Wu', 'gender': 'Male', 'gpa': 3.93}
# Student 50: {'tutorial group': 'G-1', 'id': '592', 'school': 'MSE', 'name': 'Zara Chang', 'gender': 'Female', 'gpa': 4.11}

# %%
male = 0 
female = 0 
for student in students:
    gender_lower = student['gender'].lower()
    if gender_lower in ['m','male']:
        male += 1
    elif gender_lower in ['f', 'female']:
        female += 1

# Determine optimal gender ratio
if male > female:
    target_males_per_group = 3
    target_females_per_group = 2
else:
    target_males_per_group = 2
    target_females_per_group = 3

# Sort students by GPA and split into 5 bands
students_sorted = sorted(students, key=lambda x: x["gpa"], reverse=True)
bands = [students_sorted[i:i+10] for i in range(0, 50, 10)]

# Print GPA bands information
print("GPA Bands Distribution:")
for i, band in enumerate(bands, 1):
    band_gpas = [student['gpa'] for student in band]
    print(f"Band {i}: {min(band_gpas):.2f} - {max(band_gpas):.2f} GPA ({len(band)} students)")
print()
# Out:
# GPA Bands Distribution:
# Band 1: 4.19 - 4.52 GPA (10 students)
# Band 2: 4.11 - 4.18 GPA (10 students)
# Band 3: 4.06 - 4.11 GPA (10 students)
# Band 4: 4.02 - 4.06 GPA (10 students)
# Band 5: 3.85 - 4.02 GPA (10 students)

# %%
# Separate each band into males and females
band_males = []
band_females = []
for band in bands:
    males_in_band = []
    females_in_band = []
    for student in band:
        gender_lower = student['gender'].lower()
        if gender_lower in ['m','male']:
            males_in_band.append(student)
        elif gender_lower in ['f', 'female']:
            females_in_band.append(student)
    random.shuffle(males_in_band)
    random.shuffle(females_in_band)
    band_males.append(males_in_band)
    band_females.append(females_in_band)
print(band_males)
print(band_females)

num_groups = 10
groups = [[] for _ in range(num_groups)]
#For every num_groups that we are forming, we would initialise a 0
male_count = [0] * num_groups
female_count = [0] * num_groups

# Distribute students with gender optimization - one from each band
for group_idx in range(num_groups):
    for band_idx in range(len(bands)):
        current_male_ratio = male_count[group_idx] / target_males_per_group if target_males_per_group > 0 else 0
        current_female_ratio = female_count[group_idx] / target_females_per_group if target_females_per_group > 0 else 0
        
        if current_male_ratio < current_female_ratio and band_males[band_idx]:
            student = band_males[band_idx].pop(0)
            groups[group_idx].append(student)
            male_count[group_idx] += 1
        elif band_females[band_idx]:
            student = band_females[band_idx].pop(0)
            groups[group_idx].append(student)
            female_count[group_idx] += 1
        elif band_males[band_idx]:
            student = band_males[band_idx].pop(0)
            groups[group_idx].append(student)
            male_count[group_idx] += 1

# Print group allocations with details
for i, g in enumerate(groups, 1):
    males_in_group = 0
    females_in_group = 0
    total_gpa = 0
    
    print(f"Group {i}:")
# Out:
# [[{'tutorial group': 'G-1', 'id': '2091', 'school': 'EEE', 'name': 'Adlan Bin Rahman', 'gender': 'Male', 'gpa': 4.2}, {'tutorial group': 'G-1', 'id': '5708', 'school': 'SoH', 'name': 'Ananya Ramesh', 'gender': 'Male', 'gpa': 4.2}], [{'tutorial group': 'G-1', 'id': '4520', 'school': 'EEE', 'name': 'Henry Foster', 'gender': 'Male', 'gpa': 4.11}, {'tutorial group': 'G-1', 'id': '1417', 'school': 'CoE', 'name': 'Darren Lee', 'gender': 'Male', 'gpa': 4.12}, {'tutorial group': 'G-1', 'id': '3989', 'school': 'WKW SCI', 'name': 'Anthony Liu', 'gender': 'Male', 'gpa': 4.15}, {'tutorial group': 'G-1', 'id': '1841', 'school': 'MAE', 'name': 'Jett Morales', 'gender': 'Male', 'gpa': 4.12}, {'tutorial group': 'G-1', 'id': '2776', 'school': 'CCEB', 'name': 'Siddharth Nair', 'gender': 'Male', 'gpa': 4.14}], [{'tutorial group': 'G-1', 'id': '588', 'school': 'MAE', 'name': 'Lucas Walker', 'gender': 'Male', 'gpa': 4.06}, {'tutorial group': 'G-1', 'id': '1075', 'school': 'CoB (NBS)', 'name': 'Felix Yip', 'gender': 'Male', 'gpa': 4.08}, {'tutorial group': 'G-1', 'id': '2818', 'school': 'CoB (NBS)', 'name': 'Oliver Tan', 'gender': 'Male', 'gpa': 4.09}, {'tutorial group': 'G-1', 'id': '235', 'school': 'CCDS', 'name': 'Ming Zhang', 'gender': 'Male', 'gpa': 4.06}, {'tutorial group': 'G-1', 'id': '5477', 'school': 'SoH', 'name': 'Vikram Desai', 'gender': 'Male', 'gpa': 4.09}], [{'tutorial group': 'G-1', 'id': '3628', 'school': 'EEE', 'name': 'Omer Ahmed', 'gender': 'Male', 'gpa': 4.06}, {'tutorial group': 'G-1', 'id': '4576', 'school': 'EEE', 'name': 'Jie Zhang', 'gender': 'Male', 'gpa': 4.03}, {'tutorial group': 'G-1', 'id': '5002', 'school': 'CCDS', 'name': 'Aarav Singh', 'gender': 'Male', 'gpa': 4.02}, {'tutorial group': 'G-1', 'id': '527', 'school': 'EEE', 'name': 'Mohit Desai', 'gender': 'Male', 'gpa': 4.06}], [{'tutorial group': 'G-1', 'id': '1329', 'school': 'NIE', 'name': 'Nguyen Van Sam', 'gender': 'Male', 'gpa': 3.85}, {'tutorial group': 'G-1', 'id': '288', 'school': 'CoB (NBS)', 'name': 'Ajay Verma', 'gender': 'Male', 'gpa': 4.01}, {'tutorial group': 'G-1', 'id': '3148', 'school': 'EEE', 'name': 'Gabriel Young', 'gender': 'Male', 'gpa': 3.88}, {'tutorial group': 'G-1', 'id': '1645', 'school': 'CoE', 'name': 'Zachary Wu', 'gender': 'Male', 'gpa': 3.93}, {'tutorial group': 'G-1', 'id': '4657', 'school': 'SoH', 'name': 'Oleg Petrovich', 'gender': 'Male', 'gpa': 4.0}]]
# [[{'tutorial group': 'G-1', 'id': '4338', 'school': 'SPMS', 'name': 'Sana Jain', 'gender': 'Female', 'gpa': 4.22}, {'tutorial group': 'G-1', 'id': '659', 'school': 'SSS', 'name': 'Maria Ivanovna', 'gender': 'Female', 'gpa': 4.2}, {'tutorial group': 'G-1', 'id': '71', 'school': 'SoH', 'name': 'Savannah Taylor', 'gender': 'Female', 'gpa': 4.19}, {'tutorial group': 'G-1', 'id': '1383', 'school': 'CoB (NBS)', 'name': 'Areeba Khan', 'gender': 'Female', 'gpa': 4.19}, {'tutorial group': 'G-1', 'id': '3861', 'school': 'ASE', 'name': 'Layla Torres', 'gender': 'Female', 'gpa': 4.52}, {'tutorial group': 'G-1', 'id': '809', 'school': 'CoB (NBS)', 'name': 'Nisha Das', 'gender': 'Female', 'gpa': 4.26}, {'tutorial group': 'G-1', 'id': '2069', 'school': 'SSS', 'name': 'Kathy Lau', 'gender': 'Female', 'gpa': 4.48}, {'tutorial group': 'G-1', 'id': '4820', 'school': 'CoE', 'name': 'Meera Singh', 'gender': 'Female', 'gpa': 4.22}], [{'tutorial group': 'G-1', 'id': '4479', 'school': 'CCDS', 'name': 'Amelia Kim', 'gender': 'Female', 'gpa': 4.11}, {'tutorial group': 'G-1', 'id': '3930', 'school': 'EEE', 'name': 'Xun Wei', 'gender': 'Female', 'gpa': 4.18}, {'tutorial group': 'G-1', 'id': '1271', 'school': 'SSS', 'name': 'Priya Singh', 'gender': 'Female', 'gpa': 4.17}, {'tutorial group': 'G-1', 'id': '2230', 'school': 'CoB (NBS)', 'name': 'Harlow Wang', 'gender': 'Female', 'gpa': 4.18}, {'tutorial group': 'G-1', 'id': '5703', 'school': 'SPMS', 'name': 'Karen Lee', 'gender': 'Female', 'gpa': 4.12}], [{'tutorial group': 'G-1', 'id': '162', 'school': 'SSS', 'name': 'Lila Patel', 'gender': 'Female', 'gpa': 4.07}, {'tutorial group': 'G-1', 'id': '4402', 'school': 'CCDS', 'name': 'Grace Turner', 'gender': 'Female', 'gpa': 4.08}, {'tutorial group': 'G-1', 'id': '945', 'school': 'MAE', 'name': 'Han Li', 'gender': 'Female', 'gpa': 4.1}, {'tutorial group': 'G-1', 'id': '592', 'school': 'MSE', 'name': 'Zara Chang', 'gender': 'Female', 'gpa': 4.11}, {'tutorial group': 'G-1', 'id': '2650', 'school': 'SoH', 'name': 'Nurul Shafika', 'gender': 'Female', 'gpa': 4.09}], [{'tutorial group': 'G-1', 'id': '75', 'school': 'CCDS', 'name': 'Sakina Ahmed', 'gender': 'Female', 'gpa': 4.03}, {'tutorial group': 'G-1', 'id': '1555', 'school': 'MAE', 'name': 'Prerna Gupta', 'gender': 'Female', 'gpa': 4.04}, {'tutorial group': 'G-1', 'id': '2115', 'school': 'EEE', 'name': 'Anya Kumar', 'gender': 'Female', 'gpa': 4.03}, {'tutorial group': 'G-1', 'id': '5119', 'school': 'ADM', 'name': 'Nhung Vu', 'gender': 'Female', 'gpa': 4.04}, {'tutorial group': 'G-1', 'id': '567', 'school': 'CoB (NBS)', 'name': 'Isabella Thompson', 'gender': 'Female', 'gpa': 4.03}, {'tutorial group': 'G-1', 'id': '3838', 'school': 'EEE', 'name': 'Aarti Nair', 'gender': 'Female', 'gpa': 4.05}], [{'tutorial group': 'G-1', 'id': '2151', 'school': 'EEE', 'name': 'Mei Hong', 'gender': 'Female', 'gpa': 4.02}, {'tutorial group': 'G-1', 'id': '4563', 'school': 'WKW SCI', 'name': 'Anjali Patel', 'gender': 'Female', 'gpa': 4.01}, {'tutorial group': 'G-1', 'id': '2417', 'school': 'SSS', 'name': 'Truong Minh Chau', 'gender': 'Female', 'gpa': 3.88}, {'tutorial group': 'G-1', 'id': '2326', 'school': 'CoB (NBS)', 'name': 'Vivi Dwi', 'gender': 'Female', 'gpa': 3.95}, {'tutorial group': 'G-1', 'id': '2353', 'school': 'SBS', 'name': 'Karen Wong', 'gender': 'Female', 'gpa': 3.95}]]
# Group 1:
# Group 2:
# Group 3:
# Group 4:
# Group 5:
# Group 6:
# Group 7:
# Group 8:
# Group 9:
# Group 10:

# %%
    
# Sort by GPA band for display (Band 1 = highest GPA, Band 5 = lowest GPA)

for student in g:
        # Determine which band the student came from
        band_number = None
        for band_idx, band in enumerate(bands):
            original_band_students = students_sorted[band_idx*10:(band_idx+1)*10]
            if student in original_band_students:
                band_number = band_idx + 1
                break
        
        gender_lower = student['gender'].lower()
        if gender_lower in ['m','male']:
            males_in_group += 1
        elif gender_lower in ['f', 'female']:
            females_in_group += 1
        total_gpa += student['gpa']
        print(f"  {student['name']} | {student['school']} | {student['gender']} | GPA: {student['gpa']:.2f} | Band: {band_number}")
    
    avg_gpa = total_gpa / len('gpa')
    print(f"  Summary: {males_in_group} males, {females_in_group} females, Average GPA: {avg_gpa:.2f}")
    print()
# Out:
#   File <string>:21
#     avg_gpa = total_gpa / len('gpa')
#                                     ^
# IndentationError: unindent does not match any outer indentation level
