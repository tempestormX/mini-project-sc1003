# %% [markdown]
# # SC1003 FDAB Group 5 Mini Project Presentation

# %% [markdown]
# ## 1. Overall interpretation of Task and Priorities

# %% [markdown]
# We interpret 'diversity' to mean having a **varity** of CGPAs, genders and school affiliations. We ensure fairness by making each group have members of **differing academic abilities**, **genders** and **school backgrounds**. We prioritize CGPA first, followed by gender and then school affiliation. This is beacause we feel that CGPA is the **strongest** factor that will affect a group's performance for the mini project.

# %% [markdown]
# ### 1.1 Thought Process and Computational Thinking Concepts Used + flowchart

# %% [markdown]
# We decompose our problem according to the following flowchart:
#
# ```mermaid
# graph TD
#     A[Start] --> B[Read csv file to create a list of dictionaries representing each student];
#     B --> C[For each tutorial grp, create 5 CGPA bands separately for each gender];
#     C --> D[Determine gender ratio target for each tutorial grp];
#     D --> E[Assign 1 person from each CGPA band to each grp of 5, respecting the gender target];
#     E --> F[End];

# %% [markdown]
# ## 2. Creation of dictionary of students
#
# ### **2a. read_students(start_index=0, count=50, filepath="records.csv"))**
# #### **Key considerations(Thought Process):**
# #### Assuming that we do not know the number of students, to simplify the problem, we try to make one loop for the first 50 students
#
# #### This function is to obtain a dictionary in a list named **students** based on the respective headers, so that the data can be easily retrieved from the list named students for further sorting.
#
# 1. Opening the csv file using a with statement (context manager), specifying UTF-8 encoding to **handle special characters**
# 2. **Initialise** by including students variable to store a dictionary of the first 50 students from the csv file
# 2. Sets newline = '' to **properly handle** CSV file across different operating system (os)
# 4. csv.reader() to read the file line by line, would **stop once the file ran out of lines**
# 5. Skips the header to prevent overcounting the header as students
# 6. Uses next(reader) to skip start_index number of rows for flexible data access
# 7. Implements controlled reading loop that attempts to read exactly count records but stops gracefully at EOF
# 8. Validates GPA data by converting to float and skips invalid records to maintain data quality
# 9. Creates structured dictionary for each student with cleaned data using .strip() on string fields
# 10. Gracefully handles end-of-file situations without crashing using StopIteration exception handling
#
# ### **Return Value:**
# ##### Returns a **list of dictionaries**, where each dictionary represents a validated student record with cleaned and properly typed data fields.
#
#
#
# ### **2b. count_total_students(filepath="records.csv")**
# ### **Key considerations(Thought Process):**
# #### We are considering to get through the whole list of students in each tutorial group as stated in the csv file, so the key assumption is that each tutorial group all have 50 students.
#
# #### This function is to find the total number of students that is in the csv file, so that we can decide how many loops we should consider to finish running the entire csv file to form groups
#
#
#
# 1. Open "records.csv" with **proper encoding and newline handling**
# 2. Create CSV reader iterator
# 3. Skip header row (if present)
# 4. For each remaining row: generate 1
# 5. Sum all generated 1s → total student count
# 6. Return count
#
# ### **Return Value:**
# ##### Returns an integer representing the total number of student records in the CSV file, excluding the header row.

# %%
import csv
import itertools
import os
import random
import sys


def read_students(start_index=0, count=50, filepath="records.csv"):
    """Read up to count students starting from start_index (after header).
    Returns a list of student dicts with keys: tutorial group, id, school, name, gender, gpa
    """
    students = []

    with open(filepath, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        headers = next(reader, None)  # skip header if present

        # skip start_index rows
        for _ in range(start_index):
            try:
                next(reader)
            except StopIteration:
                return students

        for _ in range(count):
            try:
                row = next(reader)
                
            except StopIteration:
                break

            try:
                gpa = float(row[5])
            except Exception:
                # skip rows with non-numeric GPA
                continue

            student = {
                'tutorial group': row[0].strip(),
                'id': row[1].strip(),
                'school': row[2].strip(),
                'name': row[3].strip(),
                'gender': row[4].strip(),
                'gpa': gpa,
            }
            students.append(student)

    return students
    
read_students(start_index=0, count=50, filepath="records.csv")
# Out:
# [{'tutorial group': 'G-1',
#   'id': '5002',
#   'school': 'CCDS',
#   'name': 'Aarav Singh',
#   'gender': 'Male',
#   'gpa': 4.02},
#  {'tutorial group': 'G-1',
#   'id': '3838',
#   'school': 'EEE',
#   'name': 'Aarti Nair',
#   'gender': 'Female',
#   'gpa': 4.05},
#  {'tutorial group': 'G-1',
#   'id': '2091',
#   'school': 'EEE',
#   'name': 'Adlan Bin Rahman',
#   'gender': 'Male',
#   'gpa': 4.2},
#  {'tutorial group': 'G-1',
#   'id': '288',
#   'school': 'CoB (NBS)',
#   'name': 'Ajay Verma',
#   'gender': 'Male',
#   'gpa': 4.01},
#  {'tutorial group': 'G-1',
#   'id': '4479',
#   'school': 'CCDS',
#   'name': 'Amelia Kim',
#   'gender': 'Female',
#   'gpa': 4.11},
#  {'tutorial group': 'G-1',
#   'id': '5708',
#   'school': 'SoH',
#   'name': 'Ananya Ramesh',
#   'gender': 'Male',
#   'gpa': 4.2},
#  {'tutorial group': 'G-1',
#   'id': '4563',
#   'school': 'WKW SCI',
#   'name': 'Anjali Patel',
#   'gender': 'Female',
#   'gpa': 4.01},
#  {'tutorial group': 'G-1',
#   'id': '3989',
#   'school': 'WKW SCI',
#   'name': 'Anthony Liu',
#   'gender': 'Male',
#   'gpa': 4.15},
#  {'tutorial group': 'G-1',
#   'id': '2115',
#   'school': 'EEE',
#   'name': 'Anya Kumar',
#   'gender': 'Female',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '1383',
#   'school': 'CoB (NBS)',
#   'name': 'Areeba Khan',
#   'gender': 'Female',
#   'gpa': 4.19},
#  {'tutorial group': 'G-1',
#   'id': '1417',
#   'school': 'CoE',
#   'name': 'Darren Lee',
#   'gender': 'Male',
#   'gpa': 4.12},
#  {'tutorial group': 'G-1',
#   'id': '1075',
#   'school': 'CoB (NBS)',
#   'name': 'Felix Yip',
#   'gender': 'Male',
#   'gpa': 4.08},
#  {'tutorial group': 'G-1',
#   'id': '3148',
#   'school': 'EEE',
#   'name': 'Gabriel Young',
#   'gender': 'Male',
#   'gpa': 3.88},
#  {'tutorial group': 'G-1',
#   'id': '4402',
#   'school': 'CCDS',
#   'name': 'Grace Turner',
#   'gender': 'Female',
#   'gpa': 4.08},
#  {'tutorial group': 'G-1',
#   'id': '945',
#   'school': 'MAE',
#   'name': 'Han Li',
#   'gender': 'Female',
#   'gpa': 4.1},
#  {'tutorial group': 'G-1',
#   'id': '2230',
#   'school': 'CoB (NBS)',
#   'name': 'Harlow Wang',
#   'gender': 'Female',
#   'gpa': 4.18},
#  {'tutorial group': 'G-1',
#   'id': '4520',
#   'school': 'EEE',
#   'name': 'Henry Foster',
#   'gender': 'Male',
#   'gpa': 4.11},
#  {'tutorial group': 'G-1',
#   'id': '567',
#   'school': 'CoB (NBS)',
#   'name': 'Isabella Thompson',
#   'gender': 'Female',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '1841',
#   'school': 'MAE',
#   'name': 'Jett Morales',
#   'gender': 'Male',
#   'gpa': 4.12},
#  {'tutorial group': 'G-1',
#   'id': '4576',
#   'school': 'EEE',
#   'name': 'Jie Zhang',
#   'gender': 'Male',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '5703',
#   'school': 'SPMS',
#   'name': 'Karen Lee',
#   'gender': 'Female',
#   'gpa': 4.12},
#  {'tutorial group': 'G-1',
#   'id': '2353',
#   'school': 'SBS',
#   'name': 'Karen Wong',
#   'gender': 'Female',
#   'gpa': 3.95},
#  {'tutorial group': 'G-1',
#   'id': '2069',
#   'school': 'SSS',
#   'name': 'Kathy Lau',
#   'gender': 'Female',
#   'gpa': 4.48},
#  {'tutorial group': 'G-1',
#   'id': '3861',
#   'school': 'ASE',
#   'name': 'Layla Torres',
#   'gender': 'Female',
#   'gpa': 4.52},
#  {'tutorial group': 'G-1',
#   'id': '162',
#   'school': 'SSS',
#   'name': 'Lila Patel',
#   'gender': 'Female',
#   'gpa': 4.07},
#  {'tutorial group': 'G-1',
#   'id': '588',
#   'school': 'MAE',
#   'name': 'Lucas Walker',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '659',
#   'school': 'SSS',
#   'name': 'Maria Ivanovna',
#   'gender': 'Female',
#   'gpa': 4.2},
#  {'tutorial group': 'G-1',
#   'id': '4820',
#   'school': 'CoE',
#   'name': 'Meera Singh',
#   'gender': 'Female',
#   'gpa': 4.22},
#  {'tutorial group': 'G-1',
#   'id': '2151',
#   'school': 'EEE',
#   'name': 'Mei Hong',
#   'gender': 'Female',
#   'gpa': 4.02},
#  {'tutorial group': 'G-1',
#   'id': '235',
#   'school': 'CCDS',
#   'name': 'Ming Zhang',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '527',
#   'school': 'EEE',
#   'name': 'Mohit Desai',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '1329',
#   'school': 'NIE',
#   'name': 'Nguyen Van Sam',
#   'gender': 'Male',
#   'gpa': 3.85},
#  {'tutorial group': 'G-1',
#   'id': '5119',
#   'school': 'ADM',
#   'name': 'Nhung Vu',
#   'gender': 'Female',
#   'gpa': 4.04},
#  {'tutorial group': 'G-1',
#   'id': '809',
#   'school': 'CoB (NBS)',
#   'name': 'Nisha Das',
#   'gender': 'Female',
#   'gpa': 4.26},
#  {'tutorial group': 'G-1',
#   'id': '2650',
#   'school': 'SoH',
#   'name': 'Nurul Shafika',
#   'gender': 'Female',
#   'gpa': 4.09},
#  {'tutorial group': 'G-1',
#   'id': '4657',
#   'school': 'SoH',
#   'name': 'Oleg Petrovich',
#   'gender': 'Male',
#   'gpa': 4.0},
#  {'tutorial group': 'G-1',
#   'id': '2818',
#   'school': 'CoB (NBS)',
#   'name': 'Oliver Tan',
#   'gender': 'Male',
#   'gpa': 4.09},
#  {'tutorial group': 'G-1',
#   'id': '3628',
#   'school': 'EEE',
#   'name': 'Omer Ahmed',
#   'gender': 'Male',
#   'gpa': 4.06},
#  {'tutorial group': 'G-1',
#   'id': '1555',
#   'school': 'MAE',
#   'name': 'Prerna Gupta',
#   'gender': 'Female',
#   'gpa': 4.04},
#  {'tutorial group': 'G-1',
#   'id': '1271',
#   'school': 'SSS',
#   'name': 'Priya Singh',
#   'gender': 'Female',
#   'gpa': 4.17},
#  {'tutorial group': 'G-1',
#   'id': '75',
#   'school': 'CCDS',
#   'name': 'Sakina Ahmed',
#   'gender': 'Female',
#   'gpa': 4.03},
#  {'tutorial group': 'G-1',
#   'id': '4338',
#   'school': 'SPMS',
#   'name': 'Sana Jain',
#   'gender': 'Female',
#   'gpa': 4.22},
#  {'tutorial group': 'G-1',
#   'id': '71',
#   'school': 'SoH',
#   'name': 'Savannah Taylor',
#   'gender': 'Female',
#   'gpa': 4.19},
#  {'tutorial group': 'G-1',
#   'id': '2776',
#   'school': 'CCEB',
#   'name': 'Siddharth Nair',
#   'gender': 'Male',
#   'gpa': 4.14},
#  {'tutorial group': 'G-1',
#   'id': '2417',
#   'school': 'SSS',
#   'name': 'Truong Minh Chau',
#   'gender': 'Female',
#   'gpa': 3.88},
#  {'tutorial group': 'G-1',
#   'id': '5477',
#   'school': 'SoH',
#   'name': 'Vikram Desai',
#   'gender': 'Male',
#   'gpa': 4.09},
#  {'tutorial group': 'G-1',
#   'id': '2326',
#   'school': 'CoB (NBS)',
#   'name': 'Vivi Dwi',
#   'gender': 'Female',
#   'gpa': 3.95},
#  {'tutorial group': 'G-1',
#   'id': '3930',
#   'school': 'EEE',
#   'name': 'Xun Wei',
#   'gender': 'Female',
#   'gpa': 4.18},
#  {'tutorial group': 'G-1',
#   'id': '1645',
#   'school': 'CoE',
#   'name': 'Zachary Wu',
#   'gender': 'Male',
#   'gpa': 3.93},
#  {'tutorial group': 'G-1',
#   'id': '592',
#   'school': 'MSE',
#   'name': 'Zara Chang',
#   'gender': 'Female',
#   'gpa': 4.11}]

# %%
def count_total_students(filepath="records.csv"):
    """Count total number of student records (excluding header)."""        
    with open(filepath, newline='', encoding='utf-8') as f:
        reader = csv.reader(f)
        headers = next(reader, None)  # skip header
        return sum(1 for row in reader)
        
count_total_students(filepath="records.csv")
# Out:
# 6000

# %% [markdown]
# ## 3. Program to determine Average GPA in each group

# %% [markdown]
# ### 3.1 The "GPA Band" Concept

# %% [markdown]
# To ensure that each group has a **similar average GPA** and a **balanced mix** of academically stronger and weaker students, we adopted a **GPA band** allocation strategy.
# Specifically, the 50 students in each tutorial group are first **sorted** in descending order by GPA and then **divided** into five bands of ten students each.
# When forming groups, one student is randomly selected from each band to create a five-member team.

# %% [markdown]
# ### 3.2 Simplified Pseudocode

# %% [markdown]
# The following Pseudocode explains the simplified logic of the function.

# %% [markdown]
# FUNCTION form_groups(students, num_groups=10):
#     IF students is empty:
#         RETURN empty list
#
#     # 1. Sort students by GPA descending
#     sorted_students = sort students by GPA descending
#
#     # 2. Split into 5 bands of equal size
#     n = length of sorted_students
#     band_size = ceil(n // 5)
#     bands = split sorted_students into 5 bands of size band_size
#
#     # 3. Shuffle each band to randomize selection
#     FOR each band in bands:
#         RANDOMLY shuffle(band)
#
#     # 4. Initialize empty groups
#     groups = list of num_groups empty lists
#
#     # 5. Form groups by taking one student from each band
#     FOR i from 0 to num_groups - 1:
#         FOR each band in bands:
#             student = pop a student from band
#             add student to groups[i]
#
#     RETURN groups

# %% [markdown]
# ### 3.3 Actual Code

# %%
def form_groups(students, num_groups=10):
    """Form groups from a list of student dicts.
    Returns list of groups (each group is a list of students).
    """
    if not students:
        return []

    students_sorted = sorted(students, key=lambda x: x['gpa'], reverse=True)

    # split into up to 5 bands as evenly as possible
    n = len(students_sorted)
    band_size = max(1, n // 5)
    bands = [students_sorted[i:i + band_size] for i in range(0, n, band_size)]

    # split each band by gender
    band_males = []
    band_females = []
    for band in bands:
        males = [s for s in band if s['gender'].strip().lower() in ('m', 'male')]
        females = [s for s in band if s['gender'].strip().lower() in ('f', 'female')]
        random.shuffle(males)
        random.shuffle(females)
        band_males.append(males)
        band_females.append(females)

    total_males = sum(len(m) for m in band_males)
    total_females = sum(len(f) for f in band_females)
    
    if total_males > total_females:
        target_males_per_group, target_females_per_group = 3, 2
    else:
        target_males_per_group, target_females_per_group = 2, 3

    groups = [[] for _ in range(num_groups)]
    male_count = [0] * num_groups
    female_count = [0] * num_groups

    # distribute one student from each band into each group
    for band_idx in range(len(bands)):
        for group_idx in range(num_groups):
            # try to pick a student to respect the gender targets
            picked = False
            if male_count[group_idx] < target_males_per_group and band_males[band_idx]:
                groups[group_idx].append(band_males[band_idx].pop())
                male_count[group_idx] += 1
                picked = True
            elif female_count[group_idx] < target_females_per_group and band_females[band_idx]:
                groups[group_idx].append(band_females[band_idx].pop())
                female_count[group_idx] += 1
                picked = True
            elif band_males[band_idx]:
                groups[group_idx].append(band_males[band_idx].pop())
                male_count[group_idx] += 1
                picked = True
            elif band_females[band_idx]:
                groups[group_idx].append(band_females[band_idx].pop())
                female_count[group_idx] += 1
                picked = True

    return groups

# %% [markdown]
# You can see that the function is not finished, and splits the 5 bands each into male and female. The next speaker will explained the details of why we changed the original logic.

# %% [markdown]
# ## 4. Gender diversity

# %% [markdown]
# ## 5. Execution of all the codes
# ### 5a. print_groups(groups, students_sorted, bands, batch_number=1)
#
# #### Code Execution for Displaying Team Assignments
# **Step 1:** Create Student-to-Band Mapping
#
# The code first builds a dictionary that connects each student to their assigned bands. It does this by going through every team created by the form_groups function, and for each student in those teams, it records which team number they belong to. This creates a master lookup table where any student can be quickly matched to their team.
#
#
#     ### student_to_band = {}
#     ### for band_idx, band in enumerate(bands):
#     ###   for student in band:
#     ###     student_key = f"{student['name']}_{student['id']}"
#     ###     student_to_band[student_key] = band_idx + 1
#
#
#
# **Step 2:** Create Student-to-Team Mapping
#
# The code first builds a dictionary that connects each student to their assigned team number. It does this by going through every team created by the form_groups function, and for each student in those teams, it records which team number they belong to. This creates a master lookup table where any student can be quickly matched to their team.
#
#
#     ### student_to_team = {}
#     ### for team_idx, team in enumerate(bands):
#     ###   for student in team:
#     ###     student_key = f"{student['name']}_{student['id']}"
#     ###     student_to_band[student_key] = team_idx
#
#
# **Step 3:** Organize Students by Tutorial Group
# Next, the code groups all students according to their tutorial groups. It creates a dictionary where each tutorial group name serves as a key, and the value is a list containing all students who belong to that particular tutorial group. This organization forms the main structure for the display output.
#
#     ### tutorial_groups = {}
#     ### for student in students_sorted:
#     ###       tutorial_group = student['tutorial group']
#     ###       if tutorial_group not in tutorial_groups:
#     ###            tutorial_groups[tutorial_group] = []
#     ###            tutorial_groups[tutorial_group].append(student)
#
#
#
# **Step 4:** Cross-Reference Teams Within Each Tutorial Group
# For each tutorial group, the code then determines how its students are distributed across different teams. It checks each student in the tutorial group against the student-to-team mapping created earlier. This process identifies which teams contain students from this tutorial group and groups those students accordingly under their respective team numbers.
#
#     ### team_assignments = {}
#     ### for student in students_in_tutorial:
#     ###   student_key = f"{student['name']}_{student['id']}"
#     ###   team_num = student_to_team.get(student_key)
#     ###   if team_num is not None:
#     ###      if team_num not in team_assignments:
#     ###        team_assignments[team_num] = []
#     ###        team_assignments[team_num].append(student)
#
#
# **Step 5:** Display the Organized Results
# Finally, the code prints the results in a structured format. For each tutorial group, it displays a header showing the tutorial group name. Underneath, it lists each team that contains students from that tutorial group, showing the team number followed by a numbered list of students in that team. Each student entry displays their name, ID, school, gender, GPA, and academic band.
#
#
#     ### for team_num in sorted(team_assignments.keys()):
#     ###     team_students = team_assignments[team_num]
#     ###     print(f"  Team {team_num}:")
#
#     ###     for student_num, student in enumerate(team_students, 1):
#     ###         # Display each student with all details
#     ###         print(f"    {student_num}. {student['name']} (ID: {student['id']}, ...)")
#
# **Step 6:** Provide Summary Statistics
# After listing all students in each team, the code calculates and displays summary statistics for that team, including the total number of students, gender distribution (male and female counts), and the average GPA of all students in that team.
#
#     ### avg_gpa = total_gpa / len(team_students)
#     ### print(f"    Summary: {len(team_students)} students "
#     ###       f"(M: {male_count}, F: {female_count}), "
#     ###       f"Avg GPA: {avg_gpa:.2f}")
#
#
# ### Final Output Structure
# The end result shows a clear, organized view where you can easily see:
#
# - All tutorial groups listed separately
#
# - Under each tutorial group, which teams contain its students
#
# - Detailed information about each student in those teams
#
# - Team-level statistics for quick reference
#
# This approach makes it simple to understand how students from each tutorial group are distributed across the various teams while maintaining all relevant student information and team statistics.

# %%
def print_groups(groups, students_sorted, bands, batch_number=1):
    """Print groups organized by Tutorial Group with team allocations."""
    print(f"\n=== Team Assignments by Tutorial Group ===")
    
    # Create band lookup for this batch
    student_to_band = {}
    for band_idx, band in enumerate(bands):
        for student in band:
            student_key = f"{student['name']}_{student['id']}"
            student_to_band[student_key] = band_idx + 1
    
    # Create team assignment lookup from the groups
    student_to_team = {}
    for team_idx, team in enumerate(groups, 1):
        for student in team:
            student_key = f"{student['name']}_{student['id']}"
            student_to_team[student_key] = team_idx
    
    # Organize all students by tutorial group
    tutorial_groups = {}
    for student in students_sorted:
        tutorial_group = student['tutorial group']
        if tutorial_group not in tutorial_groups:
            tutorial_groups[tutorial_group] = []
        tutorial_groups[tutorial_group].append(student)
    
    # Print each tutorial group with team assignments
    for tutorial_group in sorted(tutorial_groups.keys()):
        print(f"\nTutorial Group: {tutorial_group}")
        
        students_in_tutorial = tutorial_groups[tutorial_group]
        
        # Organize students by their assigned teams
        team_assignments = {}
        for student in students_in_tutorial:
            student_key = f"{student['name']}_{student['id']}"
            team_num = student_to_team.get(student_key)
            if team_num is not None:
                if team_num not in team_assignments:
                    team_assignments[team_num] = []
                team_assignments[team_num].append(student)
        
        # Print students for each team
        for team_num in sorted(team_assignments.keys()):
            team_students = team_assignments[team_num]
            print(f"  Team {team_num}:")
            
            total_gpa = 0.0
            male_count = 0
            female_count = 0
            
            for student_num, student in enumerate(team_students, 1):
                student_key = f"{student['name']}_{student['id']}"
                band_number = student_to_band.get(student_key, "Unknown")
                
                gender_lower = student['gender'].lower().strip()
                if gender_lower in ('m', 'male'):
                    gender_display = 'M'
                    male_count += 1
                elif gender_lower in ('f', 'female'):
                    gender_display = 'F'
                    female_count += 1
                else:
                    gender_display = student['gender']
                
                print(f"    {student_num}. {student['name']} "
                      f"(ID: {student['id']}, "
                      f"School: {student['school']}, "
                      f"Gender: {gender_display}, "
                      f"CGPA: {student['gpa']:.2f}, "
                      f"Band: {band_number})")
                
                total_gpa += student['gpa']
            
            # Print team summary
            if team_students:
                avg_gpa = total_gpa / len(team_students)
                print(f"    Summary: {len(team_students)} students "
                      f"(M: {male_count}, F: {female_count}), "
                      f"Avg GPA: {avg_gpa:.2f}")
        
        # Print tutorial group summary
        total_in_tutorial = len(students_in_tutorial)
        assigned_count = sum(len(students) for students in team_assignments.values())
        if assigned_count < total_in_tutorial:
            print(f"  Note: {total_in_tutorial - assigned_count} student(s) not assigned to any team")

# %% [markdown]
# ### 5b. saves_groups_to_csv(all_groups_data, output_file="student_groups.csv")
#
# **Step 1:** File set-up & Header writing
#
# The code first creates/overwrites a CSV file with UTF-8 encoding (handles special characters). Next, it would set up CSV writer with proper newline handling. The format would be given in the column header format of: Tutorial Group, Student ID, School, Name, Gender, CGPA, Team Assigned
#
#
#     ### with open(output_file, 'w', newline='', encoding='utf-8') as f:
#     ###    writer = csv.writer(f)
#
#
#     ###    writer.writerow([
#                             'Tutorial Group', 'Student ID', 'School', 'Name', 'Gender', 'CGPA', 'Team Assigned'
#                             ])
#
# **Step 2:** Data Processing and Loop Handling
# Similar to Step 1 in print_groups function
#
# **Step 3:** Data Processing and Loop Handling
#
# Iterates through groups with team numbering starting from 1
#
# Processes each student within each group
#
# Writes student records with all required fields
#
# Formats CGPA to 2 decimal places
#
# Assigns team labels like "Team 1", "Team 2", etc.
#
#     ### for group_idx, group in enumerate(groups, 1):
#     ###    for student in group:
#     ###        writer.writerow([
#     ###            student['tutorial group'],
#     ###            student['id'],
#     ###            student['school'],
#     ###            student['name'],
#     ###            student['gender'],
#     ###            f"{student['gpa']:.2f}",
#     ###            f"Team {group_idx}"
#     ###        ])

# %%
def save_groups_to_csv(all_groups_data, output_file="student_groups.csv"):
    """Save all groups data to a CSV file.
    
    Args:
        all_groups_data: List of tuples (batch_number, groups, students_sorted, bands)
        output_file: Name of the output CSV file
    """
    try:
        with open(output_file, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            
            # Write header with required column names
            writer.writerow([
                'Tutorial Group', 'Student ID', 'School', 'Name', 'Gender', 'CGPA', 'Team Assigned'
            ])
            
            # Precompute band assignments for each batch and write data
            for batch_number, groups, students_sorted, bands in all_groups_data:
                # Create band lookup for this batch
                student_to_band = {}
                for band_idx, band in enumerate(bands):
                    for student in band:
                        student_key = f"{student['name']}_{student['id']}"
                        student_to_band[student_key] = band_idx + 1
                
                # Write groups for this batch
                for group_idx, group in enumerate(groups, 1):
                    for student in group:
                        writer.writerow([
                            student['tutorial group'],
                            student['id'],
                            student['school'],
                            student['name'],
                            student['gender'],
                            f"{student['gpa']:.2f}",
                            f"Team {group_idx}"
                        ])
        
        print(f"All groups have been saved to '{output_file}'")
        return True
        
    except Exception as e:
        print(f"Error saving to CSV file: {e}")
        return False

# %% [markdown]
# ### 5c. Execution of all the functions

# %%
if __name__ == "__main__":
    BATCH_SIZE = 50
    NUM_GROUPS = 10
    all_groups_data = []  # ← ADD THIS LINE
    
    try:
        # Count total students first
        total_students = count_total_students()
        if total_students == 0:
            print("No student records found in the file.")
            sys.exit(1)

        
        batch_number = 1
        start_index = 0
        
        # Process file in batches until all students are processed
        while True:
            print(f"Reading batch {batch_number} (students {start_index + 1} to {start_index + BATCH_SIZE})...")
            students = read_students(start_index, BATCH_SIZE)
            
            if not students:
                print("No more students to process.")
                break
                
            print(f"Processing {len(students)} students {batch_number} times...")
            
            # Sort students for band creation
            students_sorted = sorted(students, key=lambda x: x['gpa'], reverse=True)
            n = len(students_sorted)
            band_size = max(1, n // 5)
            bands = [students_sorted[i:i + band_size] for i in range(0, n, band_size)]

            # Form groups for this batch
            groups = form_groups(students, num_groups=NUM_GROUPS)
            
            # Print groups for this batch
            print_groups(groups, students_sorted, bands, batch_number)

            all_groups_data.append((batch_number, groups, students_sorted, bands))
            
            # Update for next batch
            start_index += BATCH_SIZE
            batch_number += 1
            
            # Add separator between batches
            if start_index < total_students:
                print("=" * 60)
                print()
        
        # MOVE CSV SAVING HERE - AFTER ALL BATCHES ARE PROCESSED
        if all_groups_data:
            save_groups_to_csv(all_groups_data, "student_groups.csv")
            print(f"All groups have been saved to 'student_groups.csv'")
        else:
            print("No group data to save.")
        
        print(f"Processing complete! Processed {batch_number - 1} batch(es) total.")
        
    except FileNotFoundError as e:
        print(e)
        sys.exit(1)
        
    except Exception as e:
        print(f"An error occurred: {e}")
        sys.exit(1)
# Out:
# Reading batch 1 (students 1 to 50)...
# Processing 50 students 1 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-1
#   Team 1:
#     1. Ananya Ramesh (ID: 5708, School: SoH, Gender: M, CGPA: 4.20, Band: 1)
#     2. Siddharth Nair (ID: 2776, School: CCEB, Gender: M, CGPA: 4.14, Band: 2)
#     3. Grace Turner (ID: 4402, School: CCDS, Gender: F, CGPA: 4.08, Band: 3)
#     4. Anya Kumar (ID: 2115, School: EEE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Truong Minh Chau (ID: 2417, School: SSS, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 2:
#     1. Adlan Bin Rahman (ID: 2091, School: EEE, Gender: M, CGPA: 4.20, Band: 1)
#     2. Henry Foster (ID: 4520, School: EEE, Gender: M, CGPA: 4.11, Band: 2)
#     3. Zara Chang (ID: 592, School: MSE, Gender: F, CGPA: 4.11, Band: 3)
#     4. Prerna Gupta (ID: 1555, School: MAE, Gender: F, CGPA: 4.04, Band: 4)
#     5. Mei Hong (ID: 2151, School: EEE, Gender: F, CGPA: 4.02, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 3:
#     1. Nisha Das (ID: 809, School: CoB (NBS), Gender: F, CGPA: 4.26, Band: 1)
#     2. Anthony Liu (ID: 3989, School: WKW SCI, Gender: M, CGPA: 4.15, Band: 2)
#     3. Lucas Walker (ID: 588, School: MAE, Gender: M, CGPA: 4.06, Band: 3)
#     4. Sakina Ahmed (ID: 75, School: CCDS, Gender: F, CGPA: 4.03, Band: 4)
#     5. Vivi Dwi (ID: 2326, School: CoB (NBS), Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 4:
#     1. Layla Torres (ID: 3861, School: ASE, Gender: F, CGPA: 4.52, Band: 1)
#     2. Darren Lee (ID: 1417, School: CoE, Gender: M, CGPA: 4.12, Band: 2)
#     3. Oliver Tan (ID: 2818, School: CoB (NBS), Gender: M, CGPA: 4.09, Band: 3)
#     4. Nhung Vu (ID: 5119, School: ADM, Gender: F, CGPA: 4.04, Band: 4)
#     5. Anjali Patel (ID: 4563, School: WKW SCI, Gender: F, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.16
#   Team 5:
#     1. Meera Singh (ID: 4820, School: CoE, Gender: F, CGPA: 4.22, Band: 1)
#     2. Jett Morales (ID: 1841, School: MAE, Gender: M, CGPA: 4.12, Band: 2)
#     3. Ming Zhang (ID: 235, School: CCDS, Gender: M, CGPA: 4.06, Band: 3)
#     4. Aarti Nair (ID: 3838, School: EEE, Gender: F, CGPA: 4.05, Band: 4)
#     5. Karen Wong (ID: 2353, School: SBS, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 6:
#     1. Kathy Lau (ID: 2069, School: SSS, Gender: F, CGPA: 4.48, Band: 1)
#     2. Harlow Wang (ID: 2230, School: CoB (NBS), Gender: F, CGPA: 4.18, Band: 2)
#     3. Vikram Desai (ID: 5477, School: SoH, Gender: M, CGPA: 4.09, Band: 3)
#     4. Omer Ahmed (ID: 3628, School: EEE, Gender: M, CGPA: 4.06, Band: 4)
#     5. Ajay Verma (ID: 288, School: CoB (NBS), Gender: M, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.16
#   Team 7:
#     1. Maria Ivanovna (ID: 659, School: SSS, Gender: F, CGPA: 4.20, Band: 1)
#     2. Amelia Kim (ID: 4479, School: CCDS, Gender: F, CGPA: 4.11, Band: 2)
#     3. Felix Yip (ID: 1075, School: CoB (NBS), Gender: M, CGPA: 4.08, Band: 3)
#     4. Jie Zhang (ID: 4576, School: EEE, Gender: M, CGPA: 4.03, Band: 4)
#     5. Nguyen Van Sam (ID: 1329, School: NIE, Gender: M, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.05
#   Team 8:
#     1. Sana Jain (ID: 4338, School: SPMS, Gender: F, CGPA: 4.22, Band: 1)
#     2. Xun Wei (ID: 3930, School: EEE, Gender: F, CGPA: 4.18, Band: 2)
#     3. Lila Patel (ID: 162, School: SSS, Gender: F, CGPA: 4.07, Band: 3)
#     4. Mohit Desai (ID: 527, School: EEE, Gender: M, CGPA: 4.06, Band: 4)
#     5. Oleg Petrovich (ID: 4657, School: SoH, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
#   Team 9:
#     1. Savannah Taylor (ID: 71, School: SoH, Gender: F, CGPA: 4.19, Band: 1)
#     2. Priya Singh (ID: 1271, School: SSS, Gender: F, CGPA: 4.17, Band: 2)
#     3. Nurul Shafika (ID: 2650, School: SoH, Gender: F, CGPA: 4.09, Band: 3)
#     4. Aarav Singh (ID: 5002, School: CCDS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Gabriel Young (ID: 3148, School: EEE, Gender: M, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 10:
#     1. Areeba Khan (ID: 1383, School: CoB (NBS), Gender: F, CGPA: 4.19, Band: 1)
#     2. Karen Lee (ID: 5703, School: SPMS, Gender: F, CGPA: 4.12, Band: 2)
#     3. Han Li (ID: 945, School: MAE, Gender: F, CGPA: 4.10, Band: 3)
#     4. Isabella Thompson (ID: 567, School: CoB (NBS), Gender: F, CGPA: 4.03, Band: 4)
#     5. Zachary Wu (ID: 1645, School: CoE, Gender: M, CGPA: 3.93, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.07
# ============================================================
#
# Reading batch 2 (students 51 to 100)...
# Processing 50 students 2 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-10
#   Team 1:
#     1. Will Chen (ID: 2863, School: MAE, Gender: M, CGPA: 4.23, Band: 1)
#     2. Jaxon Hall (ID: 223, School: MAE, Gender: M, CGPA: 4.12, Band: 2)
#     3. Hendra Mulyana (ID: 611, School: SPMS, Gender: M, CGPA: 4.10, Band: 3)
#     4. Kiara Lin (ID: 2631, School: CCDS, Gender: F, CGPA: 4.06, Band: 4)
#     5. Tanya Lee (ID: 2515, School: CoE, Gender: F, CGPA: 4.04, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 2:
#     1. Yasir Ahmad (ID: 4077, School: SoH, Gender: M, CGPA: 4.52, Band: 1)
#     2. Isaiah Scott (ID: 565, School: SoH, Gender: M, CGPA: 4.15, Band: 2)
#     3. Leo Xu (ID: 4020, School: CoB (NBS), Gender: M, CGPA: 4.12, Band: 3)
#     4. Rhea Lee (ID: 3189, School: CCEB, Gender: F, CGPA: 4.07, Band: 4)
#     5. Alyssa Green (ID: 2581, School: ASE, Gender: F, CGPA: 3.94, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.16
#   Team 3:
#     1. Liam Jones (ID: 3732, School: CCDS, Gender: M, CGPA: 4.20, Band: 1)
#     2. Dante Wu (ID: 2253, School: EEE, Gender: M, CGPA: 4.18, Band: 2)
#     3. Rizan Bin Ahmad (ID: 4108, School: MAE, Gender: M, CGPA: 4.11, Band: 3)
#     4. Kaya Chang (ID: 375, School: SBS, Gender: F, CGPA: 4.05, Band: 4)
#     5. Kerry Lim (ID: 5122, School: CCEB, Gender: F, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 4:
#     1. Sho Nakajima (ID: 4308, School: MAE, Gender: M, CGPA: 4.27, Band: 1)
#     2. Kendrick Alvarado (ID: 2031, School: CCDS, Gender: M, CGPA: 4.18, Band: 2)
#     3. Cheng Zhang (ID: 5624, School: EEE, Gender: M, CGPA: 4.11, Band: 3)
#     4. Paula Wong (ID: 4588, School: CoB (NBS), Gender: F, CGPA: 4.06, Band: 4)
#     5. Yasmine Villanueva (ID: 3963, School: SSS, Gender: F, CGPA: 4.02, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.13
#   Team 5:
#     1. Yuzhi (ID: 4477, School: SPMS, Gender: M, CGPA: 4.25, Band: 1)
#     2. Christopher Miller (ID: 3794, School: CoB (NBS), Gender: M, CGPA: 4.17, Band: 2)
#     3. Xander Cook (ID: 2255, School: CoE, Gender: M, CGPA: 4.10, Band: 3)
#     4. Tao Liu (ID: 516, School: ADM, Gender: M, CGPA: 4.05, Band: 4)
#     5. Rhea Kapoor (ID: 3364, School: MAE, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 4, F: 1), Avg GPA: 4.11
#   Team 6:
#     1. Kira Yamada (ID: 3499, School: CCDS, Gender: F, CGPA: 4.26, Band: 1)
#     2. Ming Wei (ID: 1468, School: MAE, Gender: M, CGPA: 4.19, Band: 2)
#     3. Ayesha Javed (ID: 560, School: SoH, Gender: F, CGPA: 4.09, Band: 3)
#     4. Hunter Wilson (ID: 3051, School: LKCMedicine, Gender: M, CGPA: 4.06, Band: 4)
#     5. Zaki Bin Ibrahim (ID: 3388, School: EEE, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.12
#   Team 7:
#     1. Ananya Singh (ID: 594, School: MAE, Gender: F, CGPA: 4.20, Band: 1)
#     2. Kiran Farooq (ID: 435, School: WKW SCI, Gender: F, CGPA: 4.15, Band: 2)
#     3. Ximena Fernandez (ID: 5121, School: MSE, Gender: F, CGPA: 4.12, Band: 3)
#     4. Adrian Castillo (ID: 3329, School: MAE, Gender: M, CGPA: 4.07, Band: 4)
#     5. Xiao Chen (ID: 3903, School: CoE, Gender: M, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 8:
#     1. Nurul Aini Binti Ahmad (ID: 1139, School: SPMS, Gender: F, CGPA: 4.20, Band: 1)
#     2. Tatum Flores (ID: 16, School: EEE, Gender: F, CGPA: 4.20, Band: 2)
#     3. Nina Patil (ID: 5420, School: NIE, Gender: F, CGPA: 4.10, Band: 3)
#     4. Rhys Tan (ID: 5695, School: WKW SCI, Gender: M, CGPA: 4.06, Band: 4)
#     5. Michael Miller (ID: 3395, School: CoB (NBS), Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 9:
#     1. Sophie Cheung (ID: 5856, School: MAE, Gender: F, CGPA: 4.20, Band: 1)
#     2. Mia Zhang (ID: 3843, School: EEE, Gender: F, CGPA: 4.18, Band: 2)
#     3. Freya Chen (ID: 298, School: MAE, Gender: F, CGPA: 4.09, Band: 3)
#     4. Benjamin Turner (ID: 3841, School: SBS, Gender: M, CGPA: 4.06, Band: 4)
#     5. Hassan Malik (ID: 5734, School: MAE, Gender: M, CGPA: 4.03, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
#   Team 10:
#     1. Hae-Jin Lee (ID: 403, School: SoH, Gender: F, CGPA: 4.52, Band: 1)
#     2. Tianming (ID: 2857, School: SoH, Gender: F, CGPA: 4.20, Band: 2)
#     3. Nina Bennett (ID: 171, School: CCEB, Gender: F, CGPA: 4.08, Band: 3)
#     4. Marco Garcia (ID: 3111, School: CEE, Gender: M, CGPA: 4.04, Band: 4)
#     5. Soo-Young Kim (ID: 2405, School: ASE, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.14
# ============================================================
#
# Reading batch 3 (students 101 to 150)...
# Processing 50 students 3 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-100
#   Team 1:
#     1. Ashok Nair (ID: 424, School: CEE, Gender: M, CGPA: 4.52, Band: 1)
#     2. Adrian King (ID: 4043, School: CCDS, Gender: M, CGPA: 4.12, Band: 2)
#     3. Fay Tan (ID: 1145, School: CCEB, Gender: F, CGPA: 4.09, Band: 3)
#     4. Neelam Bhatia (ID: 5534, School: SSS, Gender: F, CGPA: 4.05, Band: 4)
#     5. Meera Menon (ID: 347, School: EEE, Gender: F, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.14
#   Team 2:
#     1. Peter Choi (ID: 5791, School: EEE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Wesley Turner (ID: 2040, School: SoH, Gender: M, CGPA: 4.17, Band: 2)
#     3. Hassan Farooq (ID: 4283, School: ADM, Gender: F, CGPA: 4.10, Band: 3)
#     4. Siti Maryam (ID: 2097, School: CoB (NBS), Gender: F, CGPA: 4.03, Band: 4)
#     5. Iris Rivera (ID: 438, School: MAE, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 3:
#     1. Ameer Bin Rahman (ID: 701, School: CoB (NBS), Gender: M, CGPA: 4.20, Band: 1)
#     2. Hua Zhang (ID: 861, School: MSE, Gender: M, CGPA: 4.17, Band: 2)
#     3. Tao Wang (ID: 1795, School: SSS, Gender: F, CGPA: 4.12, Band: 3)
#     4. Ying Liu (ID: 111, School: SPMS, Gender: F, CGPA: 4.03, Band: 4)
#     5. Isabella Thomas (ID: 2009, School: CCDS, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 4:
#     1. Seema Kapoor (ID: 412, School: MAE, Gender: F, CGPA: 4.19, Band: 1)
#     2. Ali Rehman (ID: 2603, School: CoE, Gender: M, CGPA: 4.14, Band: 2)
#     3. Khalid Rahman (ID: 745, School: CEE, Gender: M, CGPA: 4.10, Band: 3)
#     4. Mia Wong (ID: 370, School: EEE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Bella Perry (ID: 2468, School: EEE, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 5:
#     1. Raquel Huang (ID: 3137, School: LKCMedicine, Gender: F, CGPA: 4.18, Band: 1)
#     2. Nadia Binti Azhar (ID: 4268, School: CCEB, Gender: F, CGPA: 4.15, Band: 2)
#     3. Jordan Chen (ID: 4857, School: EEE, Gender: M, CGPA: 4.06, Band: 3)
#     4. Tae-Soo Kim (ID: 731, School: WKW SCI, Gender: M, CGPA: 4.05, Band: 4)
#     5. Mia Hall (ID: 1176, School: CCDS, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 6:
#     1. Anjali Nair (ID: 5269, School: MSE, Gender: F, CGPA: 4.27, Band: 1)
#     2. Yumi Nishikawa (ID: 5800, School: CoB (NBS), Gender: F, CGPA: 4.14, Band: 2)
#     3. Fergus Mendoza (ID: 5945, School: CoB (NBS), Gender: M, CGPA: 4.11, Band: 3)
#     4. Owen Hill (ID: 2698, School: CCDS, Gender: M, CGPA: 4.03, Band: 4)
#     5. Caiyun (ID: 2017, School: CoE, Gender: M, CGPA: 3.91, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.09
#   Team 7:
#     1. Alina Malik (ID: 3280, School: CoB (NBS), Gender: F, CGPA: 4.19, Band: 1)
#     2. Carla Wang (ID: 4425, School: ASE, Gender: F, CGPA: 4.12, Band: 2)
#     3. Carter Moore (ID: 4888, School: NIE, Gender: M, CGPA: 4.10, Band: 3)
#     4. Danty Susanto (ID: 2000, School: NIE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Bradley Huang (ID: 5743, School: EEE, Gender: M, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.09
#   Team 8:
#     1. Naina Gupta (ID: 4061, School: CCEB, Gender: F, CGPA: 4.20, Band: 1)
#     2. Mia Phillips (ID: 967, School: SBS, Gender: F, CGPA: 4.17, Band: 2)
#     3. Yasir Qureshi (ID: 356, School: CoE, Gender: M, CGPA: 4.08, Band: 3)
#     4. Jack Foster (ID: 4743, School: SPMS, Gender: M, CGPA: 4.05, Band: 4)
#     5. Han Zhang (ID: 2089, School: CoB (NBS), Gender: M, CGPA: 4.02, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.10
#   Team 9:
#     1. Yuanqing (ID: 1824, School: MAE, Gender: F, CGPA: 4.25, Band: 1)
#     2. Fiona Clark (ID: 2346, School: EEE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Rachel Lee (ID: 1875, School: SoH, Gender: F, CGPA: 4.11, Band: 3)
#     4. Tommy Wu (ID: 4274, School: EEE, Gender: M, CGPA: 4.03, Band: 4)
#     5. Aiden Brown (ID: 3242, School: WKW SCI, Gender: M, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 10:
#     1. Margaret Li (ID: 1547, School: CCEB, Gender: F, CGPA: 4.20, Band: 1)
#     2. Maya Ong (ID: 2332, School: CoB (NBS), Gender: F, CGPA: 4.14, Band: 2)
#     3. Diya Nair (ID: 1683, School: SSS, Gender: F, CGPA: 4.11, Band: 3)
#     4. Fangling (ID: 491, School: CoB (NBS), Gender: F, CGPA: 4.05, Band: 4)
#     5. Orlando Wu (ID: 5953, School: SBS, Gender: M, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.10
# ============================================================
#
# Reading batch 4 (students 151 to 200)...
# Processing 50 students 4 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-101
#   Team 1:
#     1. Asher Nelson (ID: 2425, School: SPMS, Gender: M, CGPA: 4.21, Band: 1)
#     2. Ethan Taylor (ID: 849, School: SSS, Gender: M, CGPA: 4.15, Band: 2)
#     3. Rachel Choi (ID: 5291, School: CoB (NBS), Gender: F, CGPA: 4.12, Band: 3)
#     4. Alani Lin (ID: 746, School: MAE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Wani Binti Jalil (ID: 456, School: MAE, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 2:
#     1. Riley Lim (ID: 35, School: SoH, Gender: M, CGPA: 4.48, Band: 1)
#     2. Owen Nugroho (ID: 5987, School: MAE, Gender: M, CGPA: 4.15, Band: 2)
#     3. Sofia Reddy (ID: 4045, School: MAE, Gender: F, CGPA: 4.09, Band: 3)
#     4. Shayla Wang (ID: 2852, School: NIE, Gender: F, CGPA: 4.01, Band: 4)
#     5. Ying Wong (ID: 3546, School: SoH, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.12
#   Team 3:
#     1. Farhan Bin Azhar (ID: 4167, School: SPMS, Gender: M, CGPA: 4.20, Band: 1)
#     2. Kevin Brown (ID: 4393, School: EEE, Gender: M, CGPA: 4.18, Band: 2)
#     3. Hannah Smith (ID: 5809, School: CoE, Gender: F, CGPA: 4.11, Band: 3)
#     4. Kate Tan (ID: 762, School: CoE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Madiha Ali (ID: 3382, School: CoB (NBS), Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 4:
#     1. Ajay Iyer (ID: 3886, School: ADM, Gender: M, CGPA: 4.20, Band: 1)
#     2. Xiao Ming (ID: 437, School: CoE, Gender: M, CGPA: 4.17, Band: 2)
#     3. Ning Li (ID: 5633, School: CCEB, Gender: F, CGPA: 4.09, Band: 3)
#     4. Hope Chen (ID: 4526, School: CCDS, Gender: F, CGPA: 4.04, Band: 4)
#     5. Kexin (ID: 1839, School: LKCMedicine, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 5:
#     1. Nguyen Thi Binh (ID: 1235, School: CCDS, Gender: F, CGPA: 4.21, Band: 1)
#     2. Minghao (ID: 3593, School: MAE, Gender: M, CGPA: 4.15, Band: 2)
#     3. Christopher Cox (ID: 621, School: CCDS, Gender: M, CGPA: 4.12, Band: 3)
#     4. Carter Thompson (ID: 1545, School: SPMS, Gender: M, CGPA: 4.03, Band: 4)
#     5. Zoe King (ID: 715, School: ASE, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.08
#   Team 6:
#     1. Lola Tan (ID: 1346, School: SSS, Gender: F, CGPA: 4.20, Band: 1)
#     2. Sophia Jones (ID: 2337, School: CoB (NBS), Gender: F, CGPA: 4.18, Band: 2)
#     3. Manish Singh (ID: 4346, School: SBS, Gender: M, CGPA: 4.10, Band: 3)
#     4. Jasper Wang (ID: 1293, School: CCEB, Gender: M, CGPA: 4.08, Band: 4)
#     5. Gia Tsai (ID: 615, School: SPMS, Gender: F, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 7:
#     1. Zadie Harris (ID: 2753, School: MAE, Gender: F, CGPA: 4.52, Band: 1)
#     2. Amaya Sharma (ID: 5210, School: CoE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Sandeep Rao (ID: 2349, School: EEE, Gender: M, CGPA: 4.14, Band: 3)
#     4. Suraj Mishra (ID: 5461, School: CoB (NBS), Gender: M, CGPA: 4.08, Band: 4)
#     5. Weijun (ID: 4928, School: SPMS, Gender: M, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.15
#   Team 8:
#     1. Evelyn Cheung (ID: 4173, School: SBS, Gender: F, CGPA: 4.48, Band: 1)
#     2. Fatima Bhatia (ID: 5015, School: ASE, Gender: F, CGPA: 4.19, Band: 2)
#     3. Lucas Chen (ID: 5468, School: CCDS, Gender: M, CGPA: 4.12, Band: 3)
#     4. Rishi Tan (ID: 2986, School: CCDS, Gender: M, CGPA: 4.08, Band: 4)
#     5. Wyatt Price (ID: 696, School: NIE, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.16
#   Team 9:
#     1. Savannah Torres (ID: 757, School: CCEB, Gender: F, CGPA: 4.20, Band: 1)
#     2. Khayla Rahayu (ID: 5191, School: CCEB, Gender: F, CGPA: 4.15, Band: 2)
#     3. Eli Cruz (ID: 3088, School: MSE, Gender: M, CGPA: 4.11, Band: 3)
#     4. Nguyen Hoang Long (ID: 2828, School: NIE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Kieran Harris (ID: 1353, School: MAE, Gender: M, CGPA: 3.91, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.08
#   Team 10:
#     1. Daphne Tan (ID: 23, School: CCEB, Gender: F, CGPA: 4.26, Band: 1)
#     2. Isla Young (ID: 5741, School: SBS, Gender: F, CGPA: 4.17, Band: 2)
#     3. Jaxon Lewis (ID: 4896, School: EEE, Gender: M, CGPA: 4.12, Band: 3)
#     4. Qi Chen (ID: 665, School: SPMS, Gender: M, CGPA: 4.04, Band: 4)
#     5. Jin Yang Tan (ID: 410, School: CoB (NBS), Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
# ============================================================
#
# Reading batch 5 (students 201 to 250)...
# Processing 50 students 5 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-102
#   Team 1:
#     1. Yong Hui (ID: 1362, School: MAE, Gender: M, CGPA: 4.21, Band: 1)
#     2. Ulysses Salazar (ID: 5913, School: MAE, Gender: M, CGPA: 4.20, Band: 2)
#     3. Alina Awan (ID: 3592, School: EEE, Gender: F, CGPA: 4.10, Band: 3)
#     4. Lyric Tan (ID: 39, School: EEE, Gender: F, CGPA: 4.04, Band: 4)
#     5. Min-Ji Park (ID: 5147, School: SoH, Gender: F, CGPA: 4.03, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.12
#   Team 2:
#     1. Elisha Wu (ID: 2373, School: NIE, Gender: M, CGPA: 4.23, Band: 1)
#     2. Henry Tan (ID: 2403, School: MAE, Gender: M, CGPA: 4.12, Band: 2)
#     3. Megan Walker (ID: 3957, School: CEE, Gender: F, CGPA: 4.06, Band: 3)
#     4. Liu Fang (ID: 2192, School: SPMS, Gender: F, CGPA: 4.03, Band: 4)
#     5. Anjali Kumar (ID: 5928, School: SSS, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 3:
#     1. Hao Yang Tan (ID: 2376, School: MSE, Gender: M, CGPA: 4.30, Band: 1)
#     2. Raj Tan (ID: 956, School: SBS, Gender: M, CGPA: 4.17, Band: 2)
#     3. Zara Lim (ID: 3909, School: CCEB, Gender: F, CGPA: 4.10, Band: 3)
#     4. Layla Cooper (ID: 902, School: MSE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Sakshi Iyer (ID: 3168, School: MAE, Gender: F, CGPA: 3.94, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
#   Team 4:
#     1. Ajay Bhatt (ID: 783, School: CCDS, Gender: M, CGPA: 4.22, Band: 1)
#     2. Felix Wong (ID: 3820, School: SSS, Gender: M, CGPA: 4.14, Band: 2)
#     3. Kiran Shah (ID: 3413, School: SSS, Gender: F, CGPA: 4.12, Band: 3)
#     4. Svetlana Chernyshova (ID: 5023, School: LKCMedicine, Gender: F, CGPA: 4.06, Band: 4)
#     5. Simran Singh (ID: 2560, School: SBS, Gender: F, CGPA: 4.03, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
#   Team 5:
#     1. Omar Farooq (ID: 4404, School: MAE, Gender: M, CGPA: 4.20, Band: 1)
#     2. Fariha Noor (ID: 2595, School: CoE, Gender: F, CGPA: 4.14, Band: 2)
#     3. Luca Torres (ID: 2246, School: SoH, Gender: M, CGPA: 4.12, Band: 3)
#     4. Margarita Sokolova (ID: 448, School: SSS, Gender: F, CGPA: 4.03, Band: 4)
#     5. Melati Ahmad (ID: 4862, School: CCDS, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 6:
#     1. Sofia Hernandez (ID: 1634, School: CCDS, Gender: F, CGPA: 4.26, Band: 1)
#     2. Lan Nguyen (ID: 5447, School: CCDS, Gender: F, CGPA: 4.15, Band: 2)
#     3. Hansel Bautista (ID: 818, School: SSS, Gender: M, CGPA: 4.06, Band: 3)
#     4. Harsh Kumar (ID: 3692, School: EEE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Nafisa Ali (ID: 3717, School: EEE, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 7:
#     1. Nisha Gupta (ID: 714, School: CoB (NBS), Gender: F, CGPA: 4.21, Band: 1)
#     2. Maya Sari (ID: 3043, School: CoE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Bradley Yang (ID: 5888, School: CEE, Gender: M, CGPA: 4.09, Band: 3)
#     4. Levi Huang (ID: 2221, School: EEE, Gender: M, CGPA: 4.04, Band: 4)
#     5. Riku Takeda (ID: 4386, School: WKW SCI, Gender: M, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.10
#   Team 8:
#     1. Zoe Martinez (ID: 4379, School: MAE, Gender: F, CGPA: 4.21, Band: 1)
#     2. Kanwal Bukhari (ID: 337, School: CoB (NBS), Gender: F, CGPA: 4.16, Band: 2)
#     3. Wyatt Thompson (ID: 2013, School: NIE, Gender: M, CGPA: 4.09, Band: 3)
#     4. Asher Clark (ID: 3439, School: SBS, Gender: M, CGPA: 4.03, Band: 4)
#     5. Minh Tran (ID: 5578, School: CCDS, Gender: M, CGPA: 4.03, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.10
#   Team 9:
#     1. Aria Murphy (ID: 5144, School: CCEB, Gender: F, CGPA: 4.20, Band: 1)
#     2. Sakshi Singh (ID: 828, School: SSS, Gender: F, CGPA: 4.14, Band: 2)
#     3. Nira Gupta (ID: 2720, School: WKW SCI, Gender: F, CGPA: 4.12, Band: 3)
#     4. Maximus Wright (ID: 103, School: CoE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Travis Lim (ID: 1768, School: SoH, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 10:
#     1. Maharani Sari (ID: 5690, School: CCEB, Gender: F, CGPA: 4.30, Band: 1)
#     2. Gina Lau (ID: 2079, School: CoB (NBS), Gender: F, CGPA: 4.15, Band: 2)
#     3. Nina Phillips (ID: 613, School: SBS, Gender: F, CGPA: 4.11, Band: 3)
#     4. Cheng Fang Tan (ID: 2315, School: SPMS, Gender: M, CGPA: 4.05, Band: 4)
#     5. Pranata Santoso (ID: 1688, School: MSE, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
# ============================================================
#
# Reading batch 6 (students 251 to 300)...
# Processing 50 students 6 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-103
#   Team 1:
#     1. Tommy Wu (ID: 2601, School: SSS, Gender: M, CGPA: 4.22, Band: 1)
#     2. Everett Harris (ID: 2559, School: CEE, Gender: M, CGPA: 4.14, Band: 2)
#     3. Amna Bukhari (ID: 5493, School: CCEB, Gender: F, CGPA: 4.11, Band: 3)
#     4. Yuna Wong (ID: 4837, School: SBS, Gender: F, CGPA: 4.07, Band: 4)
#     5. Layla Fisher (ID: 5970, School: SBS, Gender: F, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
#   Team 2:
#     1. Naim Bin Hashim (ID: 1879, School: MSE, Gender: M, CGPA: 4.20, Band: 1)
#     2. Hikaru Sato (ID: 3497, School: NIE, Gender: M, CGPA: 4.14, Band: 2)
#     3. Maya Wilson (ID: 835, School: SoH, Gender: F, CGPA: 4.13, Band: 3)
#     4. Queenie Lee (ID: 1292, School: SoH, Gender: F, CGPA: 4.06, Band: 4)
#     5. Nadia Binti Zulkifli (ID: 952, School: MSE, Gender: F, CGPA: 3.87, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 3:
#     1. David Young (ID: 2165, School: CoE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Fatima Malik (ID: 4051, School: MAE, Gender: F, CGPA: 4.18, Band: 2)
#     3. Vy Nguyen (ID: 3932, School: WKW SCI, Gender: M, CGPA: 4.11, Band: 3)
#     4. Emily Scott (ID: 3251, School: EEE, Gender: F, CGPA: 4.07, Band: 4)
#     5. Selina Loh (ID: 778, School: CoB (NBS), Gender: F, CGPA: 3.91, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 4:
#     1. Chong Wang (ID: 397, School: CoB (NBS), Gender: M, CGPA: 4.25, Band: 1)
#     2. Samantha Khan (ID: 4821, School: CoB (NBS), Gender: F, CGPA: 4.19, Band: 2)
#     3. Zachary Lee (ID: 2189, School: CoB (NBS), Gender: M, CGPA: 4.11, Band: 3)
#     4. Shiloh Lin (ID: 40, School: LKCMedicine, Gender: F, CGPA: 4.05, Band: 4)
#     5. Yvonne Ng (ID: 2302, School: CEE, Gender: F, CGPA: 3.80, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 5:
#     1. Dev Sharma (ID: 5040, School: ASE, Gender: M, CGPA: 4.26, Band: 1)
#     2. Sofia Kim (ID: 4559, School: EEE, Gender: F, CGPA: 4.17, Band: 2)
#     3. Mansoor Qureshi (ID: 1911, School: CEE, Gender: M, CGPA: 4.12, Band: 3)
#     4. Dallas Huang (ID: 1618, School: CEE, Gender: M, CGPA: 4.09, Band: 4)
#     5. Maggie Kwan (ID: 1551, School: CCEB, Gender: F, CGPA: 3.91, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 6:
#     1. Fatima Baig (ID: 2602, School: CCDS, Gender: F, CGPA: 4.25, Band: 1)
#     2. Anjali Singh (ID: 5627, School: SSS, Gender: F, CGPA: 4.16, Band: 2)
#     3. Ethan White (ID: 4224, School: SoH, Gender: M, CGPA: 4.11, Band: 3)
#     4. Simon Lee (ID: 4181, School: CoB (NBS), Gender: M, CGPA: 4.02, Band: 4)
#     5. Eli Tan (ID: 4616, School: ASE, Gender: M, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.08
#   Team 7:
#     1. Maya Gonzales (ID: 1202, School: SSS, Gender: F, CGPA: 4.22, Band: 1)
#     2. Amira Tan (ID: 1495, School: CCDS, Gender: F, CGPA: 4.15, Band: 2)
#     3. Vikram Singh (ID: 4809, School: EEE, Gender: M, CGPA: 4.13, Band: 3)
#     4. Khalil Bin Ismail (ID: 2679, School: SSS, Gender: M, CGPA: 4.09, Band: 4)
#     5. Xiao Wei Tan (ID: 1787, School: CEE, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 8:
#     1. Asha Mehta (ID: 3554, School: CCDS, Gender: F, CGPA: 4.52, Band: 1)
#     2. Kylie Chen (ID: 4612, School: MAE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Talha Iqbal (ID: 1847, School: CoE, Gender: M, CGPA: 4.11, Band: 3)
#     4. Fahim Hussein (ID: 2099, School: CCDS, Gender: M, CGPA: 4.03, Band: 4)
#     5. Alan Chan (ID: 18, School: CEE, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.16
#   Team 9:
#     1. Camila Li (ID: 5483, School: MAE, Gender: F, CGPA: 4.27, Band: 1)
#     2. Willow Wong (ID: 4427, School: EEE, Gender: F, CGPA: 4.19, Band: 2)
#     3. Tyler Hall (ID: 344, School: CEE, Gender: M, CGPA: 4.11, Band: 3)
#     4. Saad Malik (ID: 925, School: MSE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Graham Jackson (ID: 1613, School: SBS, Gender: M, CGPA: 3.97, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.12
#   Team 10:
#     1. Hannah Sanders (ID: 4964, School: CCDS, Gender: F, CGPA: 4.20, Band: 1)
#     2. Aria Martinez (ID: 4132, School: EEE, Gender: F, CGPA: 4.18, Band: 2)
#     3. Carmen Ong (ID: 4842, School: SoH, Gender: F, CGPA: 4.09, Band: 3)
#     4. Isaac Thompson (ID: 1553, School: EEE, Gender: M, CGPA: 4.03, Band: 4)
#     5. Irfan Bin Hassan (ID: 4678, School: SPMS, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
# ============================================================
#
# Reading batch 7 (students 301 to 350)...
# Processing 50 students 7 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-104
#   Team 1:
#     1. Eamon Liu (ID: 3595, School: NIE, Gender: M, CGPA: 4.16, Band: 1)
#     2. Benjamin Huang (ID: 4349, School: WKW SCI, Gender: M, CGPA: 4.11, Band: 2)
#     3. Anita Lim (ID: 4039, School: CCDS, Gender: F, CGPA: 4.06, Band: 3)
#     4. Chloe Wu (ID: 2556, School: MAE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Zainab Noor (ID: 2562, School: SoH, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 2:
#     1. Jason Tan (ID: 5596, School: CCDS, Gender: M, CGPA: 4.16, Band: 1)
#     2. Shahid Ali (ID: 3665, School: CCDS, Gender: M, CGPA: 4.11, Band: 2)
#     3. Sophia Taylor (ID: 1600, School: WKW SCI, Gender: F, CGPA: 4.06, Band: 3)
#     4. Dahlia Chen (ID: 1446, School: NIE, Gender: F, CGPA: 4.04, Band: 4)
#     5. Chloe Scott (ID: 2233, School: SBS, Gender: F, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.04
#   Team 3:
#     1. Leo Pranata (ID: 3873, School: CoB (NBS), Gender: M, CGPA: 4.20, Band: 1)
#     2. Anil Reddy (ID: 1395, School: SoH, Gender: M, CGPA: 4.14, Band: 2)
#     3. Maya Rahman (ID: 5685, School: CCEB, Gender: F, CGPA: 4.06, Band: 3)
#     4. Isha Verma (ID: 4187, School: SBS, Gender: F, CGPA: 4.03, Band: 4)
#     5. Gracelyn Dela Cruz (ID: 2932, School: SSS, Gender: F, CGPA: 3.96, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 4:
#     1. Ryder Ward (ID: 1891, School: MAE, Gender: M, CGPA: 4.15, Band: 1)
#     2. Rafael Wong (ID: 4988, School: CCDS, Gender: M, CGPA: 4.11, Band: 2)
#     3. Lila Wu (ID: 1950, School: MAE, Gender: F, CGPA: 4.06, Band: 3)
#     4. Emily Johnson (ID: 5684, School: SoH, Gender: F, CGPA: 4.03, Band: 4)
#     5. Madison Scott (ID: 5962, School: CoB (NBS), Gender: F, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 5:
#     1. Jun Zhang (ID: 2962, School: CoE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Waleed Malik (ID: 33, School: ASE, Gender: M, CGPA: 4.15, Band: 2)
#     3. Vera Ong (ID: 1649, School: MAE, Gender: F, CGPA: 4.09, Band: 3)
#     4. Lance Alvarado (ID: 4664, School: CoE, Gender: M, CGPA: 4.04, Band: 4)
#     5. Anaya Singh (ID: 2204, School: EEE, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.09
#   Team 6:
#     1. William Yip (ID: 3335, School: EEE, Gender: M, CGPA: 4.22, Band: 1)
#     2. Priya Roy (ID: 2622, School: EEE, Gender: F, CGPA: 4.11, Band: 2)
#     3. Zhen Zhang (ID: 5317, School: CoB (NBS), Gender: M, CGPA: 4.06, Band: 3)
#     4. Gideon Torres (ID: 3268, School: CoB (NBS), Gender: M, CGPA: 4.04, Band: 4)
#     5. Nia Wong (ID: 3050, School: CCEB, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.08
#   Team 7:
#     1. Chloe Tan (ID: 2653, School: CCDS, Gender: F, CGPA: 4.17, Band: 1)
#     2. Pallavi Mehta (ID: 1375, School: CEE, Gender: F, CGPA: 4.09, Band: 2)
#     3. Daniel Adams (ID: 759, School: CCDS, Gender: M, CGPA: 4.05, Band: 3)
#     4. Chandra Menon (ID: 90, School: ASE, Gender: M, CGPA: 4.03, Band: 4)
#     5. Tara Wati (ID: 3080, School: NIE, Gender: F, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.04
#   Team 8:
#     1. Emi Yamashita (ID: 5905, School: CCDS, Gender: F, CGPA: 4.22, Band: 1)
#     2. Xena Reed (ID: 5020, School: NIE, Gender: F, CGPA: 4.11, Band: 2)
#     3. Sarah Liu (ID: 832, School: SPMS, Gender: F, CGPA: 4.09, Band: 3)
#     4. Gideon Zhang (ID: 5570, School: SPMS, Gender: M, CGPA: 4.01, Band: 4)
#     5. John Lim (ID: 1542, School: WKW SCI, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 9:
#     1. Nisha Yadav (ID: 3937, School: SSS, Gender: F, CGPA: 4.18, Band: 1)
#     2. Giselle Wu (ID: 82, School: SSS, Gender: F, CGPA: 4.14, Band: 2)
#     3. Ashna Mehta (ID: 4001, School: SoH, Gender: F, CGPA: 4.06, Band: 3)
#     4. Kamran Farooq (ID: 5540, School: EEE, Gender: M, CGPA: 4.01, Band: 4)
#     5. Lily Ong (ID: 5263, School: CoB (NBS), Gender: F, CGPA: 3.93, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.06
#   Team 10:
#     1. Ying Zhang (ID: 4403, School: EEE, Gender: F, CGPA: 4.18, Band: 1)
#     2. Samantha Ong (ID: 2273, School: SSS, Gender: F, CGPA: 4.10, Band: 2)
#     3. Nancy Yeo (ID: 2898, School: SSS, Gender: F, CGPA: 4.08, Band: 3)
#     4. Prashant Joshi (ID: 238, School: CCEB, Gender: M, CGPA: 4.03, Band: 4)
#     5. Fitri Binti Mohd (ID: 4894, School: CCDS, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.08
# ============================================================
#
# Reading batch 8 (students 351 to 400)...
# Processing 50 students 8 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-105
#   Team 1:
#     1. Chen Bo (ID: 1550, School: CEE, Gender: M, CGPA: 4.17, Band: 1)
#     2. Dao Tran (ID: 1927, School: MSE, Gender: M, CGPA: 4.15, Band: 2)
#     3. Ping An (ID: 4758, School: CoB (NBS), Gender: F, CGPA: 4.10, Band: 3)
#     4. Mei Chen (ID: 1141, School: SSS, Gender: F, CGPA: 4.02, Band: 4)
#     5. Aditi Kumar (ID: 5909, School: SSS, Gender: F, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 2:
#     1. Imran Bin Zahid (ID: 5003, School: CCDS, Gender: M, CGPA: 4.30, Band: 1)
#     2. Saad Javed (ID: 3668, School: ADM, Gender: M, CGPA: 4.15, Band: 2)
#     3. Chen Li (ID: 4431, School: SBS, Gender: F, CGPA: 4.12, Band: 3)
#     4. Kylie Zhang (ID: 4510, School: SBS, Gender: F, CGPA: 4.04, Band: 4)
#     5. Isabella Rodriguez (ID: 1803, School: EEE, Gender: F, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 3:
#     1. Callum Williams (ID: 5339, School: SoH, Gender: M, CGPA: 4.19, Band: 1)
#     2. Nicolas Ramos (ID: 5355, School: CoB (NBS), Gender: M, CGPA: 4.14, Band: 2)
#     3. Pallavi Kumar (ID: 3108, School: SSS, Gender: F, CGPA: 4.10, Band: 3)
#     4. Addison Lin (ID: 2732, School: SSS, Gender: F, CGPA: 4.02, Band: 4)
#     5. Maya Torres (ID: 333, School: CCDS, Gender: F, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 4:
#     1. Max Johnson (ID: 2392, School: SoH, Gender: M, CGPA: 4.21, Band: 1)
#     2. Kiran Rao (ID: 4869, School: SPMS, Gender: M, CGPA: 4.15, Band: 2)
#     3. Claudia Tan (ID: 28, School: CoB (NBS), Gender: F, CGPA: 4.09, Band: 3)
#     4. Tatum Roberts (ID: 3415, School: CCDS, Gender: F, CGPA: 4.06, Band: 4)
#     5. Olivia Miller (ID: 5029, School: WKW SCI, Gender: F, CGPA: 3.87, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 5:
#     1. Yang Jun (ID: 5377, School: CCDS, Gender: M, CGPA: 4.17, Band: 1)
#     2. Bennett Liu (ID: 5816, School: CCDS, Gender: M, CGPA: 4.14, Band: 2)
#     3. Sabrina Zhao (ID: 4589, School: CCEB, Gender: F, CGPA: 4.11, Band: 3)
#     4. Yumi Tanaka (ID: 5565, School: ASE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Vira Dwi (ID: 3345, School: CCEB, Gender: F, CGPA: 3.80, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 6:
#     1. Daphne Li (ID: 2728, School: EEE, Gender: F, CGPA: 4.26, Band: 1)
#     2. Amit Agarwal (ID: 1490, School: EEE, Gender: M, CGPA: 4.15, Band: 2)
#     3. Kunal Mehta (ID: 2913, School: SoH, Gender: M, CGPA: 4.12, Band: 3)
#     4. Julia Tan (ID: 5218, School: MAE, Gender: F, CGPA: 4.04, Band: 4)
#     5. Shahid Raza (ID: 5797, School: MAE, Gender: M, CGPA: 4.02, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.12
#   Team 7:
#     1. Lola Zhang (ID: 3728, School: MAE, Gender: F, CGPA: 4.22, Band: 1)
#     2. Nisha Bansal (ID: 951, School: SSS, Gender: F, CGPA: 4.15, Band: 2)
#     3. James Jackson (ID: 5950, School: CEE, Gender: M, CGPA: 4.09, Band: 3)
#     4. Dallas Liu (ID: 1789, School: NIE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Devansh Mehta (ID: 1529, School: CCDS, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.10
#   Team 8:
#     1. Qiana Lestari (ID: 5770, School: NIE, Gender: F, CGPA: 4.25, Band: 1)
#     2. Amina Binti Zain (ID: 1564, School: EEE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Logan Martin (ID: 1043, School: MAE, Gender: M, CGPA: 4.12, Band: 3)
#     4. Ricky Chen (ID: 800, School: CoE, Gender: M, CGPA: 4.09, Band: 4)
#     5. Haruki Suzuki (ID: 401, School: CoB (NBS), Gender: M, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.12
#   Team 9:
#     1. Sophie Reed (ID: 4188, School: SSS, Gender: F, CGPA: 4.23, Band: 1)
#     2. Cora Zhang (ID: 3970, School: CoB (NBS), Gender: F, CGPA: 4.15, Band: 2)
#     3. Jonathan Wu (ID: 1007, School: CoB (NBS), Gender: M, CGPA: 4.09, Band: 3)
#     4. Trung Le (ID: 2010, School: CEE, Gender: M, CGPA: 4.06, Band: 4)
#     5. Vincent Wong (ID: 500, School: CoB (NBS), Gender: M, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 10:
#     1. Charlotte Gonzalez (ID: 4364, School: MAE, Gender: F, CGPA: 4.22, Band: 1)
#     2. Tessa Li (ID: 2161, School: EEE, Gender: F, CGPA: 4.14, Band: 2)
#     3. Alyssa Tan (ID: 4744, School: CCDS, Gender: F, CGPA: 4.10, Band: 3)
#     4. Ronald Tan (ID: 1974, School: CEE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Arjun Nair (ID: 463, School: MAE, Gender: M, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
# ============================================================
#
# Reading batch 9 (students 401 to 450)...
# Processing 50 students 9 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-106
#   Team 1:
#     1. Oscar Villanueva (ID: 2144, School: CoE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Hafiz Ahmad (ID: 2147, School: WKW SCI, Gender: M, CGPA: 4.14, Band: 2)
#     3. Akemi Takahashi (ID: 5676, School: EEE, Gender: F, CGPA: 4.12, Band: 3)
#     4. Aria Tan (ID: 3654, School: CCDS, Gender: F, CGPA: 4.04, Band: 4)
#     5. Neelam Rani (ID: 5088, School: CCEB, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 2:
#     1. Harrison Moore (ID: 3551, School: EEE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Om Tan (ID: 3054, School: CCEB, Gender: M, CGPA: 4.15, Band: 2)
#     3. Kathy Tan (ID: 4387, School: CCEB, Gender: F, CGPA: 4.05, Band: 3)
#     4. Minghao (ID: 623, School: CoB (NBS), Gender: F, CGPA: 4.00, Band: 4)
#     5. Sienna Lee (ID: 850, School: CCDS, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 3:
#     1. Nolan Reyes (ID: 1294, School: MAE, Gender: M, CGPA: 4.16, Band: 1)
#     2. Reyansh Iyer (ID: 4201, School: SPMS, Gender: M, CGPA: 4.14, Band: 2)
#     3. Priya Nair (ID: 1002, School: CCEB, Gender: F, CGPA: 4.12, Band: 3)
#     4. Charlotte Harris (ID: 5657, School: SPMS, Gender: F, CGPA: 4.02, Band: 4)
#     5. Aria Lee (ID: 3583, School: CCEB, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.06
#   Team 4:
#     1. Fahad Ali (ID: 113, School: MAE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Siddharth Gupta (ID: 1730, School: CoB (NBS), Gender: M, CGPA: 4.14, Band: 2)
#     3. Miyu Nishimura (ID: 5670, School: SoH, Gender: F, CGPA: 4.06, Band: 3)
#     4. Gabriella Dela Cruz (ID: 1785, School: MAE, Gender: F, CGPA: 4.01, Band: 4)
#     5. Arya Kapoor (ID: 4934, School: CCEB, Gender: F, CGPA: 3.97, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 5:
#     1. Cole Huang (ID: 3686, School: EEE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Guofeng (ID: 1888, School: CoE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Rahul Mehta (ID: 4783, School: MAE, Gender: M, CGPA: 4.08, Band: 3)
#     4. Cleo Morales (ID: 1415, School: NIE, Gender: F, CGPA: 4.02, Band: 4)
#     5. Jun Liu (ID: 5885, School: EEE, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 6:
#     1. Jason Robinson (ID: 930, School: CoE, Gender: M, CGPA: 4.52, Band: 1)
#     2. Piper Chen (ID: 3001, School: CCDS, Gender: F, CGPA: 4.15, Band: 2)
#     3. Nikhil Sharma (ID: 1580, School: WKW SCI, Gender: M, CGPA: 4.11, Band: 3)
#     4. Megan Zhao (ID: 5093, School: MAE, Gender: F, CGPA: 4.01, Band: 4)
#     5. Zara Malik (ID: 4753, School: EEE, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.14
#   Team 7:
#     1. Noel Pineda (ID: 4438, School: EEE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Eun-Hee Kim (ID: 1168, School: NIE, Gender: F, CGPA: 4.14, Band: 2)
#     3. Noah Morris (ID: 2112, School: SoH, Gender: M, CGPA: 4.11, Band: 3)
#     4. Jai Mehta (ID: 4581, School: SPMS, Gender: M, CGPA: 4.00, Band: 4)
#     5. Dylan Li (ID: 330, School: EEE, Gender: M, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 4, F: 1), Avg GPA: 4.07
#   Team 8:
#     1. Kavitha Tan (ID: 1929, School: EEE, Gender: F, CGPA: 4.30, Band: 1)
#     2. Isla Lee (ID: 5089, School: MAE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Oliver Martinez (ID: 4317, School: CoB (NBS), Gender: M, CGPA: 4.12, Band: 3)
#     4. Albert Wang (ID: 4732, School: EEE, Gender: M, CGPA: 4.01, Band: 4)
#     5. Gandhi Saputra (ID: 3471, School: CCEB, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 9:
#     1. Nisha Verma (ID: 164, School: LKCMedicine, Gender: F, CGPA: 4.18, Band: 1)
#     2. Jingyi (ID: 3330, School: SSS, Gender: F, CGPA: 4.15, Band: 2)
#     3. Kevin Wang (ID: 2713, School: MAE, Gender: M, CGPA: 4.09, Band: 3)
#     4. Hoang Nguyen (ID: 2385, School: ADM, Gender: M, CGPA: 4.02, Band: 4)
#     5. Sergei Ivanovich (ID: 5983, School: SPMS, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.09
#   Team 10:
#     1. Mira Binti Zaki (ID: 2588, School: SoH, Gender: F, CGPA: 4.20, Band: 1)
#     2. Tania Ng (ID: 1470, School: CCEB, Gender: F, CGPA: 4.15, Band: 2)
#     3. Quinn Larson (ID: 5898, School: CCEB, Gender: F, CGPA: 4.12, Band: 3)
#     4. Zedrick Ong (ID: 2370, School: MAE, Gender: M, CGPA: 4.05, Band: 4)
#     5. Thomas Harris (ID: 3008, School: CCDS, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
# ============================================================
#
# Reading batch 10 (students 451 to 500)...
# Processing 50 students 10 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-107
#   Team 1:
#     1. Zane Navarro (ID: 3867, School: CoB (NBS), Gender: M, CGPA: 4.18, Band: 1)
#     2. Carter Hall (ID: 5767, School: EEE, Gender: M, CGPA: 4.14, Band: 2)
#     3. Rina Ali (ID: 4040, School: CCEB, Gender: F, CGPA: 4.09, Band: 3)
#     4. Cheryl Ong (ID: 5790, School: CCEB, Gender: F, CGPA: 4.00, Band: 4)
#     5. Nina Binti Noor (ID: 937, School: ASE, Gender: F, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 2:
#     1. Qiang Zhang (ID: 5335, School: SPMS, Gender: M, CGPA: 4.20, Band: 1)
#     2. Liu Yang (ID: 5804, School: SPMS, Gender: M, CGPA: 4.16, Band: 2)
#     3. Ananya Roy (ID: 149, School: MAE, Gender: F, CGPA: 4.08, Band: 3)
#     4. Jia Li (ID: 2196, School: SBS, Gender: F, CGPA: 4.03, Band: 4)
#     5. Zulaikha Binti Rahman (ID: 1541, School: CCEB, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 3:
#     1. Lily Lim (ID: 2292, School: CEE, Gender: F, CGPA: 4.19, Band: 1)
#     2. Archer Powell (ID: 1979, School: NIE, Gender: M, CGPA: 4.12, Band: 2)
#     3. Emery Wu (ID: 4677, School: NIE, Gender: M, CGPA: 4.10, Band: 3)
#     4. Le Van Minh (ID: 5645, School: CCEB, Gender: F, CGPA: 4.02, Band: 4)
#     5. Charu Iyer (ID: 2012, School: SSS, Gender: F, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 4:
#     1. Bria Tsai (ID: 754, School: MAE, Gender: F, CGPA: 4.23, Band: 1)
#     2. Karan Patel (ID: 3973, School: WKW SCI, Gender: M, CGPA: 4.14, Band: 2)
#     3. Kai Qiang (ID: 180, School: CEE, Gender: M, CGPA: 4.04, Band: 3)
#     4. Lana Tan (ID: 3344, School: CCDS, Gender: F, CGPA: 4.00, Band: 4)
#     5. Kavita Singh (ID: 768, School: CoB (NBS), Gender: F, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.06
#   Team 5:
#     1. Riana Binti Abdul (ID: 598, School: MSE, Gender: F, CGPA: 4.25, Band: 1)
#     2. Omar Rivera (ID: 2916, School: SSS, Gender: M, CGPA: 4.12, Band: 2)
#     3. Arjun Sinha (ID: 4572, School: EEE, Gender: M, CGPA: 4.09, Band: 3)
#     4. Xiaoling Chen (ID: 2941, School: EEE, Gender: F, CGPA: 4.02, Band: 4)
#     5. Yumi Hayashi (ID: 1968, School: SBS, Gender: F, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 6:
#     1. Sana Menon (ID: 5212, School: EEE, Gender: F, CGPA: 4.22, Band: 1)
#     2. Suresh Bhat (ID: 89, School: CoE, Gender: F, CGPA: 4.14, Band: 2)
#     3. Yuri Grigorev (ID: 5960, School: CEE, Gender: M, CGPA: 4.10, Band: 3)
#     4. Daniel Tan (ID: 4074, School: CEE, Gender: M, CGPA: 4.00, Band: 4)
#     5. Nguyen Thi Hoa (ID: 2471, School: CCDS, Gender: F, CGPA: 3.87, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 7:
#     1. Saanvi Roy (ID: 895, School: CCEB, Gender: F, CGPA: 4.25, Band: 1)
#     2. Madison Torres (ID: 2475, School: SPMS, Gender: F, CGPA: 4.12, Band: 2)
#     3. Vera Chan (ID: 1308, School: CCEB, Gender: F, CGPA: 4.10, Band: 3)
#     4. Zane Wong (ID: 3849, School: CCDS, Gender: M, CGPA: 4.03, Band: 4)
#     5. Harvey Lim (ID: 2715, School: MAE, Gender: M, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 8:
#     1. Samantha Sanchez (ID: 1212, School: CoB (NBS), Gender: F, CGPA: 4.25, Band: 1)
#     2. Nina Zhao (ID: 4749, School: WKW SCI, Gender: F, CGPA: 4.15, Band: 2)
#     3. Meera Gupta (ID: 2334, School: EEE, Gender: F, CGPA: 4.04, Band: 3)
#     4. Chad Dela Cruz (ID: 2445, School: SPMS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Joko Susanto (ID: 4716, School: MAE, Gender: M, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 9:
#     1. Victoria Reyes (ID: 4901, School: MAE, Gender: F, CGPA: 4.20, Band: 1)
#     2. Misha Malik (ID: 112, School: CoB (NBS), Gender: F, CGPA: 4.14, Band: 2)
#     3. Samreen Ali (ID: 830, School: CCDS, Gender: F, CGPA: 4.07, Band: 3)
#     4. Xiangqi (ID: 4336, School: EEE, Gender: M, CGPA: 4.00, Band: 4)
#     5. Tanishq Reddy (ID: 1033, School: WKW SCI, Gender: M, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 10:
#     1. Amelia Lewis (ID: 4621, School: SPMS, Gender: F, CGPA: 4.22, Band: 1)
#     2. Hayden Wu (ID: 2877, School: CCDS, Gender: F, CGPA: 4.12, Band: 2)
#     3. Amara Siti (ID: 992, School: SSS, Gender: F, CGPA: 4.03, Band: 3)
#     4. Xiao Zhang (ID: 1463, School: EEE, Gender: M, CGPA: 4.02, Band: 4)
#     5. Min-Jung Kim (ID: 5132, School: ASE, Gender: F, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.05
# ============================================================
#
# Reading batch 11 (students 501 to 550)...
# Processing 50 students 11 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-108
#   Team 1:
#     1. Cameron Ward (ID: 1678, School: CCDS, Gender: M, CGPA: 4.19, Band: 1)
#     2. Chen Ming (ID: 5733, School: MAE, Gender: M, CGPA: 4.11, Band: 2)
#     3. Malia Tan (ID: 3972, School: CEE, Gender: F, CGPA: 4.08, Band: 3)
#     4. Riya Mehta (ID: 2470, School: CoB (NBS), Gender: F, CGPA: 4.02, Band: 4)
#     5. Hina Waseem (ID: 4574, School: CCDS, Gender: F, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 2:
#     1. Asher Thompson (ID: 3985, School: SPMS, Gender: M, CGPA: 4.52, Band: 1)
#     2. Kendrick Alvarado (ID: 2130, School: SSS, Gender: M, CGPA: 4.18, Band: 2)
#     3. Priya Menon (ID: 2616, School: SSS, Gender: F, CGPA: 4.09, Band: 3)
#     4. Harini Nair (ID: 3128, School: EEE, Gender: F, CGPA: 4.02, Band: 4)
#     5. Maya Devi (ID: 4881, School: EEE, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.16
#   Team 3:
#     1. Matthew Martinez (ID: 3933, School: CEE, Gender: M, CGPA: 4.57, Band: 1)
#     2. Shun Takahashi (ID: 1339, School: SSS, Gender: M, CGPA: 4.11, Band: 2)
#     3. Nadya Zainal (ID: 1905, School: MSE, Gender: F, CGPA: 4.09, Band: 3)
#     4. Mae Chang (ID: 1643, School: SBS, Gender: F, CGPA: 4.02, Band: 4)
#     5. Ivy Wang (ID: 1809, School: SSS, Gender: F, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.14
#   Team 4:
#     1. Liang Bo (ID: 2716, School: CoE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Mason King (ID: 2027, School: CCDS, Gender: M, CGPA: 4.18, Band: 2)
#     3. Lindsey Lin (ID: 3184, School: CCEB, Gender: F, CGPA: 4.10, Band: 3)
# ...
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.07
#   Team 7:
#     1. Ranya Al-Mansoori (ID: 3783, School: CCDS, Gender: F, CGPA: 4.17, Band: 1)
#     2. Derek Chen (ID: 4488, School: EEE, Gender: M, CGPA: 4.10, Band: 2)
#     3. Victor Santos (ID: 717, School: CCDS, Gender: M, CGPA: 4.10, Band: 3)
#     4. Chad Dela Cruz (ID: 5363, School: CoB (NBS), Gender: M, CGPA: 4.02, Band: 4)
#     5. Aisha Binti Rahman (ID: 5587, School: CCEB, Gender: F, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.05
#   Team 8:
#     1. Fang Xiu (ID: 3738, School: EEE, Gender: F, CGPA: 4.17, Band: 1)
#     2. Patty Lim (ID: 979, School: CCDS, Gender: F, CGPA: 4.12, Band: 2)
#     3. Aditi Chai (ID: 3447, School: SSS, Gender: F, CGPA: 4.03, Band: 3)
#     4. Dmitri Andreevich (ID: 3552, School: CEE, Gender: M, CGPA: 4.00, Band: 4)
#     5. Jack Peterson (ID: 4079, School: EEE, Gender: M, CGPA: 3.95, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 9:
#     1. Sophie Taylor (ID: 4939, School: CoB (NBS), Gender: F, CGPA: 4.52, Band: 1)
#     2. Zara Ali (ID: 4396, School: CCDS, Gender: F, CGPA: 4.11, Band: 2)
#     3. Ellie Rivera (ID: 2888, School: SSS, Gender: F, CGPA: 4.10, Band: 3)
#     4. Ayaan Shah (ID: 215, School: CCDS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Liang Bo (ID: 1088, School: LKCMedicine, Gender: M, CGPA: 3.91, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.13
#   Team 10:
#     1. Huilin (ID: 5196, School: SoH, Gender: F, CGPA: 4.20, Band: 1)
#     2. Sophia Smith (ID: 5352, School: MAE, Gender: F, CGPA: 4.15, Band: 2)
#     3. Jessica Tan (ID: 1544, School: CoB (NBS), Gender: F, CGPA: 4.04, Band: 3)
#     4. Cody Evans (ID: 3171, School: SBS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Una Kaur (ID: 3221, School: CCEB, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.08
# ============================================================
#
# Reading batch 118 (students 5851 to 5900)...
# Processing 50 students 118 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-97
#   Team 1:
#     1. Wicaksono Adi (ID: 127, School: CCDS, Gender: M, CGPA: 4.20, Band: 1)
#     2. Bodhi Yang (ID: 4602, School: SPMS, Gender: M, CGPA: 4.17, Band: 2)
#     3. Maya Wood (ID: 1915, School: CCEB, Gender: F, CGPA: 4.06, Band: 3)
#     4. Kaira Lim (ID: 4757, School: CCDS, Gender: F, CGPA: 4.01, Band: 4)
#     5. Jin-Ah Kim (ID: 3336, School: CCDS, Gender: F, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.06
#   Team 2:
#     1. Jayden Chen (ID: 2989, School: CoE, Gender: M, CGPA: 4.20, Band: 1)
#     2. Long Thi Bich (ID: 1222, School: EEE, Gender: M, CGPA: 4.17, Band: 2)
#     3. Siti Aminah Binti Ibrahim (ID: 2380, School: CCDS, Gender: F, CGPA: 4.10, Band: 3)
#     4. Diana Khan (ID: 3442, School: ADM, Gender: F, CGPA: 4.00, Band: 4)
#     5. Hannah Rogers (ID: 5648, School: SBS, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 3:
#     1. Keira Martinez (ID: 4356, School: CCEB, Gender: F, CGPA: 4.26, Band: 1)
#     2. Olive Wong (ID: 2111, School: CCDS, Gender: F, CGPA: 4.18, Band: 2)
#     3. Bashir Raza (ID: 1711, School: CCDS, Gender: M, CGPA: 4.11, Band: 3)
#     4. Quinn Yip (ID: 1901, School: CEE, Gender: M, CGPA: 4.04, Band: 4)
#     5. Margo Wang (ID: 2771, School: CoE, Gender: F, CGPA: 3.91, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 4:
#     1. Mei Liu (ID: 1707, School: SSS, Gender: F, CGPA: 4.25, Band: 1)
#     2. Xiu Ying (ID: 185, School: CCEB, Gender: F, CGPA: 4.17, Band: 2)
#     3. Tony Tsang (ID: 1786, School: CEE, Gender: M, CGPA: 4.07, Band: 3)
#     4. Zhou Wei (ID: 5560, School: SBS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Aria Thompson (ID: 863, School: SBS, Gender: F, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 5:
#     1. Priti Choudhary (ID: 2168, School: EEE, Gender: F, CGPA: 4.26, Band: 1)
#     2. Lola Zhao (ID: 3176, School: CEE, Gender: F, CGPA: 4.19, Band: 2)
#     3. Chao Zhang (ID: 3266, School: CoB (NBS), Gender: M, CGPA: 4.12, Band: 3)
#     4. Lachlan Thompson (ID: 394, School: CCEB, Gender: M, CGPA: 4.03, Band: 4)
#     5. Kiran Iyer (ID: 4714, School: CCDS, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.10
#   Team 6:
#     1. Scarlett Evans (ID: 4703, School: CoB (NBS), Gender: F, CGPA: 4.20, Band: 1)
#     2. Akira Kobayashi (ID: 5159, School: CoB (NBS), Gender: F, CGPA: 4.14, Band: 2)
#     3. Alexander Mitchell (ID: 2058, School: CoB (NBS), Gender: M, CGPA: 4.06, Band: 3)
#     4. Adrian Chen (ID: 118, School: ASE, Gender: M, CGPA: 3.97, Band: 4)
#     5. Asha Rahman (ID: 86, School: SSS, Gender: F, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 7:
#     1. Rongxian (ID: 3816, School: CCEB, Gender: F, CGPA: 4.30, Band: 1)
#     2. Zohra Khan (ID: 2122, School: SSS, Gender: F, CGPA: 4.18, Band: 2)
#     3. Violet Lee (ID: 862, School: CCEB, Gender: F, CGPA: 4.05, Band: 3)
#     4. Wei Fang (ID: 1953, School: SPMS, Gender: M, CGPA: 4.01, Band: 4)
#     5. Ali Raza (ID: 595, School: EEE, Gender: M, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
#   Team 8:
#     1. Bella Ramirez (ID: 1836, School: CoB (NBS), Gender: F, CGPA: 4.26, Band: 1)
#     2. Maya Gupta (ID: 1860, School: CoB (NBS), Gender: F, CGPA: 4.14, Band: 2)
#     3. Bohan (ID: 408, School: SSS, Gender: F, CGPA: 4.10, Band: 3)
#     4. Jasmine Wong (ID: 3917, School: MAE, Gender: F, CGPA: 4.01, Band: 4)
#     5. Quade Cruz (ID: 3284, School: SSS, Gender: M, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.08
#   Team 9:
#     1. Tanya Acharya (ID: 4618, School: CEE, Gender: F, CGPA: 4.20, Band: 1)
#     2. Emily Evans (ID: 854, School: SSS, Gender: F, CGPA: 4.19, Band: 2)
#     3. Savannah Wood (ID: 3218, School: SBS, Gender: F, CGPA: 4.06, Band: 3)
#     4. Mei Xuan Tan (ID: 1924, School: CoB (NBS), Gender: F, CGPA: 4.00, Band: 4)
#     5. Grayson Wright (ID: 3694, School: EEE, Gender: M, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.07
#   Team 10:
#     1. Maya Chua (ID: 5239, School: SBS, Gender: F, CGPA: 4.21, Band: 1)
#     2. Ayesha Siddiqui (ID: 935, School: CCEB, Gender: F, CGPA: 4.16, Band: 2)
#     3. Layla Zhao (ID: 5829, School: ADM, Gender: F, CGPA: 4.10, Band: 3)
#     4. Kira Dewi (ID: 3954, School: EEE, Gender: F, CGPA: 4.00, Band: 4)
#     5. Kinsley Price (ID: 1155, School: CCDS, Gender: F, CGPA: 3.87, Band: 5)
#     Summary: 5 students (M: 0, F: 5), Avg GPA: 4.07
# ============================================================
#
# Reading batch 119 (students 5901 to 5950)...
# Processing 50 students 119 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-98
#   Team 1:
#     1. Hugo Yang (ID: 3167, School: SoH, Gender: M, CGPA: 4.26, Band: 1)
#     2. Dhruv Singh (ID: 4172, School: CCDS, Gender: M, CGPA: 4.14, Band: 2)
#     3. Henry Hill (ID: 1777, School: WKW SCI, Gender: M, CGPA: 4.10, Band: 3)
#     4. Tara Menon (ID: 2934, School: EEE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Hana Wong (ID: 2875, School: CoB (NBS), Gender: F, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.11
#   Team 2:
#     1. Malachi Foster (ID: 4199, School: CEE, Gender: M, CGPA: 4.26, Band: 1)
#     2. Liu Chen (ID: 2517, School: ADM, Gender: M, CGPA: 4.14, Band: 2)
#     3. Budi Santoso (ID: 417, School: CCDS, Gender: M, CGPA: 4.05, Band: 3)
#     4. Michelle Lee (ID: 4412, School: SSS, Gender: F, CGPA: 4.02, Band: 4)
#     5. Emily Li (ID: 4243, School: EEE, Gender: F, CGPA: 4.01, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.10
#   Team 3:
#     1. Syahrul Bin Omar (ID: 3041, School: CCDS, Gender: M, CGPA: 4.20, Band: 1)
#     2. Haru Yamaguchi (ID: 5010, School: CCDS, Gender: M, CGPA: 4.14, Band: 2)
#     3. Matthew Evans (ID: 1639, School: EEE, Gender: M, CGPA: 4.11, Band: 3)
#     4. Zoe Lee (ID: 276, School: EEE, Gender: F, CGPA: 4.03, Band: 4)
#     5. Kaiming (ID: 4793, School: SBS, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.10
#   Team 4:
#     1. Asher Wang (ID: 3220, School: CCDS, Gender: M, CGPA: 4.27, Band: 1)
#     2. Jason Lam (ID: 1280, School: CEE, Gender: M, CGPA: 4.14, Band: 2)
#     3. Jay Patel (ID: 5369, School: SoH, Gender: M, CGPA: 4.03, Band: 3)
#     4. Mindy Kwan (ID: 1612, School: SSS, Gender: F, CGPA: 4.02, Band: 4)
#     5. Victoria Reed (ID: 2289, School: MAE, Gender: F, CGPA: 3.89, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.07
#   Team 5:
#     1. Josh Thompson (ID: 1537, School: NIE, Gender: M, CGPA: 4.18, Band: 1)
#     2. Colton Bailey (ID: 4414, School: MAE, Gender: M, CGPA: 4.12, Band: 2)
#     3. Ryusei Nakamura (ID: 3491, School: MSE, Gender: M, CGPA: 4.09, Band: 3)
#     4. Abigail King (ID: 4160, School: CoB (NBS), Gender: F, CGPA: 4.02, Band: 4)
#     5. Diana Binti Mohd (ID: 3122, School: MAE, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.06
#   Team 6:
#     1. Gage Fisher (ID: 4447, School: CCDS, Gender: M, CGPA: 4.22, Band: 1)
#     2. Carter Lee (ID: 4691, School: SPMS, Gender: M, CGPA: 4.11, Band: 2)
#     3. Zhi Xuan (ID: 947, School: CoB (NBS), Gender: M, CGPA: 4.04, Band: 3)
#     4. Finnley Brooks (ID: 568, School: EEE, Gender: M, CGPA: 4.02, Band: 4)
#     5. Paige Wang (ID: 107, School: EEE, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 4, F: 1), Avg GPA: 4.05
#   Team 7:
#     1. Siddharth Mehta (ID: 3942, School: CCDS, Gender: M, CGPA: 4.21, Band: 1)
#     2. Uriah Salazar (ID: 529, School: EEE, Gender: M, CGPA: 4.15, Band: 2)
#     3. Maya Lewis (ID: 3105, School: ADM, Gender: F, CGPA: 4.05, Band: 3)
#     4. Aiden Chen (ID: 4927, School: EEE, Gender: M, CGPA: 4.01, Band: 4)
#     5. Henry Bennett (ID: 3960, School: SPMS, Gender: M, CGPA: 3.85, Band: 5)
#     Summary: 5 students (M: 4, F: 1), Avg GPA: 4.05
#   Team 8:
#     1. Asha Devi (ID: 5545, School: CCDS, Gender: F, CGPA: 4.52, Band: 1)
#     2. Katherine Young (ID: 5097, School: CoB (NBS), Gender: F, CGPA: 4.14, Band: 2)
#     3. Ritika Sharma (ID: 5866, School: ASE, Gender: F, CGPA: 4.06, Band: 3)
#     4. Caleb Lim (ID: 4310, School: CCDS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Umar Sembiring (ID: 4035, School: CoE, Gender: M, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.13
#   Team 9:
#     1. Nianzu (ID: 5855, School: NIE, Gender: F, CGPA: 4.30, Band: 1)
#     2. Pei Li (ID: 3695, School: CCEB, Gender: F, CGPA: 4.18, Band: 2)
#     3. Leah Wilson (ID: 3983, School: SBS, Gender: F, CGPA: 4.08, Band: 3)
#     4. Logan Taylor (ID: 2335, School: CCDS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Jae-Suk Jung (ID: 4747, School: CCDS, Gender: M, CGPA: 3.97, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.11
#   Team 10:
#     1. Dawn Lim (ID: 5605, School: CCDS, Gender: F, CGPA: 4.20, Band: 1)
#     2. Avery Smith (ID: 1447, School: SSS, Gender: F, CGPA: 4.12, Band: 2)
#     3. Nina Lin (ID: 1126, School: CEE, Gender: F, CGPA: 4.08, Band: 3)
#     4. Judah Hall (ID: 738, School: MSE, Gender: M, CGPA: 4.03, Band: 4)
#     5. Alexander King (ID: 5550, School: SoH, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.09
# ============================================================
#
# Reading batch 120 (students 5951 to 6000)...
# Processing 50 students 120 times...
#
# === Team Assignments by Tutorial Group ===
#
# Tutorial Group: G-99
#   Team 1:
#     1. William Yang (ID: 5841, School: CoE, Gender: M, CGPA: 4.20, Band: 1)
#     2. Rafael De Leon (ID: 1586, School: MSE, Gender: M, CGPA: 4.11, Band: 2)
#     3. Ruby Nelson (ID: 5762, School: CCDS, Gender: F, CGPA: 4.08, Band: 3)
#     4. Nisha Malik (ID: 2766, School: SoH, Gender: F, CGPA: 4.03, Band: 4)
#     5. Amaya Tan (ID: 4913, School: SPMS, Gender: F, CGPA: 3.92, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 2:
#     1. Kylan Yang (ID: 1478, School: MAE, Gender: M, CGPA: 4.18, Band: 1)
#     2. Ikram Tan (ID: 4892, School: CCDS, Gender: M, CGPA: 4.11, Band: 2)
#     3. Sophie Rivera (ID: 4739, School: SSS, Gender: F, CGPA: 4.06, Band: 3)
#     4. Farah Binti Omar (ID: 943, School: CCEB, Gender: F, CGPA: 4.00, Band: 4)
#     5. Samantha Rogers (ID: 4342, School: CoE, Gender: F, CGPA: 3.88, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.05
#   Team 3:
#     1. Zachary Chen (ID: 4009, School: EEE, Gender: M, CGPA: 4.19, Band: 1)
#     2. Michael Walker (ID: 771, School: CoE, Gender: M, CGPA: 4.14, Band: 2)
#     3. Ella Santos (ID: 2897, School: SoH, Gender: F, CGPA: 4.03, Band: 3)
#     4. Maya Morgan (ID: 4855, School: CCEB, Gender: F, CGPA: 4.03, Band: 4)
#     5. Natalia Fedorova (ID: 2282, School: SSS, Gender: F, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 4:
#     1. Ronin Huang (ID: 2439, School: EEE, Gender: M, CGPA: 4.15, Band: 1)
#     2. Hana Binti Ali (ID: 5249, School: CCDS, Gender: F, CGPA: 4.10, Band: 2)
#     3. Phan Duc Minh (ID: 2264, School: WKW SCI, Gender: M, CGPA: 4.05, Band: 3)
#     4. Joanna Tan (ID: 5482, School: CEE, Gender: F, CGPA: 4.02, Band: 4)
#     5. Aki Yoshida (ID: 885, School: MAE, Gender: F, CGPA: 3.90, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.04
#   Team 5:
#     1. Maya Hughes (ID: 1063, School: ASE, Gender: F, CGPA: 4.27, Band: 1)
#     2. Natalia Wong (ID: 4630, School: ADM, Gender: F, CGPA: 4.11, Band: 2)
#     3. Nobu Yamamoto (ID: 283, School: WKW SCI, Gender: M, CGPA: 4.06, Band: 3)
#     4. Daniel White (ID: 1238, School: NIE, Gender: M, CGPA: 4.00, Band: 4)
#     5. Fatima Iqbal (ID: 5561, School: EEE, Gender: F, CGPA: 3.96, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.08
#   Team 6:
#     1. Lian Chen (ID: 2981, School: SSS, Gender: F, CGPA: 4.26, Band: 1)
#     2. Layla Turner (ID: 66, School: CoB (NBS), Gender: F, CGPA: 4.12, Band: 2)
#     3. Niko Setiawan (ID: 4718, School: CEE, Gender: M, CGPA: 4.05, Band: 3)
#     4. Travis Wong (ID: 1653, School: CCDS, Gender: M, CGPA: 4.02, Band: 4)
#     5. Naoko Ueda (ID: 1865, School: MSE, Gender: F, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.06
#   Team 7:
#     1. Meera Shah (ID: 1403, School: SSS, Gender: F, CGPA: 4.25, Band: 1)
#     2. Rina Tan (ID: 5085, School: CCEB, Gender: F, CGPA: 4.13, Band: 2)
#     3. Qasim Bin Noor (ID: 2578, School: CEE, Gender: M, CGPA: 4.05, Band: 3)
#     4. Vikas Mehta (ID: 1944, School: CCEB, Gender: M, CGPA: 4.01, Band: 4)
#     5. Matthew Garcia (ID: 5402, School: MAE, Gender: M, CGPA: 3.86, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.06
#   Team 8:
#     1. Xiaoling Zhang (ID: 1845, School: CCEB, Gender: F, CGPA: 4.17, Band: 1)
#     2. Queenie Li (ID: 1472, School: EEE, Gender: F, CGPA: 4.12, Band: 2)
#     3. Nash Li (ID: 740, School: SPMS, Gender: M, CGPA: 4.08, Band: 3)
#     4. Hassan Shah (ID: 766, School: WKW SCI, Gender: M, CGPA: 4.01, Band: 4)
#     5. Zion Tan (ID: 1554, School: SSS, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 3, F: 2), Avg GPA: 4.08
#   Team 9:
#     1. Katherine Morales (ID: 481, School: CCDS, Gender: F, CGPA: 4.18, Band: 1)
#     2. Mai Tran (ID: 4797, School: SoH, Gender: F, CGPA: 4.14, Band: 2)
#     3. Samuel Wright (ID: 122, School: CoB (NBS), Gender: M, CGPA: 4.08, Band: 3)
#     4. Sana Tan (ID: 3509, School: EEE, Gender: F, CGPA: 4.02, Band: 4)
#     5. Ali Zain (ID: 5329, School: CoB (NBS), Gender: M, CGPA: 3.94, Band: 5)
#     Summary: 5 students (M: 2, F: 3), Avg GPA: 4.07
#   Team 10:
#     1. Karla Bautista (ID: 1058, School: SSS, Gender: F, CGPA: 4.15, Band: 1)
#     2. Kiran Malhotra (ID: 3607, School: SSS, Gender: F, CGPA: 4.08, Band: 2)
#     3. Aria Wadhwa (ID: 253, School: EEE, Gender: F, CGPA: 4.03, Band: 3)
#     4. Aaliyah Howard (ID: 4819, School: CoB (NBS), Gender: F, CGPA: 4.00, Band: 4)
#     5. Manoj Patel (ID: 2443, School: CCDS, Gender: M, CGPA: 4.00, Band: 5)
#     Summary: 5 students (M: 1, F: 4), Avg GPA: 4.05
# Reading batch 121 (students 6001 to 6050)...
# No more students to process.
# All groups have been saved to 'student_groups.csv'
# All groups have been saved to 'student_groups.csv'
# Processing complete! Processed 120 batch(es) total.

# %% [markdown]
# ## 6) **Objective**: To create "diverse" groups based on three criterias: GPA, gender and schools.
#
# ### **i) GPA Distribution:**
# - The GPA spread shows a roughly **normal distribution** centered around **4.1**
# - **Bands** were used to group students evenly by academic performance
#
#
# ### **ii) Gender Distribution:**
# - Males and females are fairly balanced across the dataset
# - This ensures gender diversity when forming groups using the automated grouping algorithm
#
#
# ### **iii) School Distribution:**
# - Students come from **18 different schools**
# - Inter-school collaboration opportunities exist by pairing students from different faculties
#
#
#
# ---
#
# ## **Summary and Remarks:**
# **There is diversity in gender, school, and GPA in the dataset, therefore allowing fair team formation.**

# %%
import matplotlib.pyplot as plt
import csv

# Read data from records.csv file
tutorial_groups = []
gpas = []

with open('records.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        tutorial_groups.append(row['Tutorial Group'])
        gpas.append(float(row['CGPA']))  # Using CGPA column for GPA

# Organize data by tutorial group
group_data = {}
for i, group in enumerate(tutorial_groups):
    if group not in group_data:
        group_data[group] = []
    group_data[group].append(gpas[i])

# Calculate statistics for each tutorial group
sorted_groups = sorted(group_data.keys(), key=lambda x: int(x.split('-')[1]))
group_means = []
group_mins = []
group_maxs = []
all_student_gpas = []

# Prepare data for plotting
x_positions = []
y_gpas = []
group_labels = []

for i, group in enumerate(sorted_groups):
    group_gpas = group_data[group]
    
    # Add individual student points
    for gpa in group_gpas:
        x_positions.append(i)
        y_gpas.append(gpa)
        all_student_gpas.append(gpa)
    
    # Calculate group statistics
    group_means.append(sum(group_gpas) / len(group_gpas))
    group_mins.append(min(group_gpas))
    group_maxs.append(max(group_gpas))
    group_labels.append(group)

# Create the visualization
plt.figure(figsize=(20, 10))

# Plot individual student GPAs as scatter points with transparency
plt.scatter(x_positions, y_gpas, alpha=1.0, color='blue', s=30, label='Individual Students')

# Plot tutorial group average GPAs as red line
plt.plot(range(len(sorted_groups)), group_means, 'ro-', 
         linewidth=2, markersize=6, label='Group Average GPA')

# Customize the plot
plt.xlabel('Tutorial Groups', fontsize=15)
plt.ylabel('GPA', fontsize=15)
plt.title('GPA Distribution Across Tutorial Groups\n(Individual Students and Group Averages)', fontsize=14)

# Set x-axis labels to show every 10th tutorial group for readability
x_ticks = list(range(0, len(sorted_groups), 10))
x_labels = [sorted_groups[i] for i in x_ticks]
plt.xticks(x_ticks, x_labels, rotation=45)

# Set y-axis range from min_gpa-0.5 to 5
min_gpa = min(all_student_gpas)
plt.ylim(min_gpa - 0.5, 5.0)

# Add grid and legend
plt.grid(True, alpha=0.3)
plt.legend()

# Add horizontal line for overall average
overall_mean = sum(all_student_gpas) / len(all_student_gpas)
plt.axhline(y=overall_mean, color='blue', linestyle='--', 
            linewidth=2, alpha=1.0, label=f'Overall Average: {overall_mean:.2f}')

plt.legend()
plt.tight_layout()
plt.show()

# Print statistical summary
print("=" * 60)
print("STATISTICAL SUMMARY")
print("=" * 60)
print(f"Total Students: {len(all_student_gpas)}")
print(f"Total Tutorial Groups: {len(sorted_groups)}")
print(f"Overall Average GPA: {overall_mean:.3f}")
print(f"Minimum GPA: {min(all_student_gpas):.3f}")
print(f"Maximum GPA: {max(all_student_gpas):.3f}")

# Print group statistics
print(f"\nTutorial Group GPA Statistics:")
print(f"Average group mean GPA: {sum(group_means)/len(group_means):.3f}")
print(f"Lowest group average: {min(group_means):.3f}")
print(f"Highest group average: {max(group_means):.3f}")

# Show some sample groups with their averages
print(f"\nSample Group Averages:")
for i in range(min(5, len(sorted_groups))):
    print(f"  {sorted_groups[i]}: {group_means[i]:.3f}")
if len(sorted_groups) > 5:
    print("  ...")
    for i in range(len(sorted_groups)-3, len(sorted_groups)):
        print(f"  {sorted_groups[i]}: {group_means[i]:.3f}")
# Out:
# ============================================================
# STATISTICAL SUMMARY
# ============================================================
# Total Students: 6000
# Total Tutorial Groups: 120
# Overall Average GPA: 4.089
# Minimum GPA: 3.700
# Maximum GPA: 4.970
#
# Tutorial Group GPA Statistics:
# Average group mean GPA: 4.089
# Lowest group average: 4.054
# Highest group average: 4.131
#
# Sample Group Averages:
#   G-1: 4.096
#   G-2: 4.089
#   G-3: 4.105
#   G-4: 4.079
#   G-5: 4.078
#   ...
#   G-118: 4.106
#   G-119: 4.097
#   G-120: 4.120

# %%
import matplotlib.pyplot as plt
import csv
from collections import defaultdict

# Read data from records.csv file
tutorial_school_counts = defaultdict(lambda: defaultdict(int))

with open('records.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        tutorial_group = row['Tutorial Group']
        school = row['School']
        tutorial_school_counts[tutorial_group][school] += 1

# Get all unique schools and tutorial groups
all_schools = set()
all_tutorial_groups = sorted(tutorial_school_counts.keys(), key=lambda x: int(x.split('-')[1]))

for tutorial_group in tutorial_school_counts:
    all_schools.update(tutorial_school_counts[tutorial_group].keys())

all_schools = sorted(list(all_schools))

# Prepare data for stacked bar chart
tutorial_groups = []
school_data = {school: [] for school in all_schools}

for tutorial_group in all_tutorial_groups:
    tutorial_groups.append(tutorial_group)
    total_in_group = sum(tutorial_school_counts[tutorial_group].values())
    
    for school in all_schools:
        count = tutorial_school_counts[tutorial_group].get(school, 0)
        school_data[school].append(count)

# Create the stacked bar chart
plt.figure(figsize=(20, 10))

# Create stacked bars
bottom = [0] * len(tutorial_groups)
colors = plt.cm.Set3(range(len(all_schools)))

for i, school in enumerate(all_schools):
    plt.bar(tutorial_groups, school_data[school], bottom=bottom, 
            label=school, color=colors[i], alpha=0.8, edgecolor='grey')
    bottom = [bottom[j] + school_data[school][j] for j in range(len(tutorial_groups))]

# Customize the plot
plt.xlabel('Tutorial Groups', fontsize=12)
plt.ylabel('Number of Students', fontsize=12)
plt.title('Distribution of Schools Within Each Tutorial Group', fontsize=14)

# Rotate x-axis labels and show only every 5th label for readability
x_ticks = list(range(0, len(tutorial_groups), 5))
x_labels = [tutorial_groups[i] for i in x_ticks]
plt.xticks(x_ticks, x_labels, rotation=45)

# Add legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Add grid
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Print statistical summary
print("=" * 60)
print("STATISTICAL SUMMARY")
print("=" * 60)
print(f"Total Tutorial Groups: {len(tutorial_groups)}")
print(f"Total Schools: {len(all_schools)}")
print(f"Schools: {', '.join(all_schools)}")

print(f"\nSchool Distribution Across Tutorial Groups:")
for school in all_schools:
    total_students = sum(school_data[school])
    groups_with_students = sum(1 for count in school_data[school] if count > 0)
    print(f"  {school}: {total_students} students across {groups_with_students} tutorial groups")

# Show sample distribution for first few tutorial groups
print(f"\nSample Distribution (First 5 Tutorial Groups):")
for i in range(min(5, len(tutorial_groups))):
    print(f"  {tutorial_groups[i]}:")
    for school in all_schools:
        count = school_data[school][i]
        if count > 0:
            print(f"    {school}: {count} students")
# Out:
# ============================================================
# STATISTICAL SUMMARY
# ============================================================
# Total Tutorial Groups: 120
# Total Schools: 18
# Schools: ADM, ASE, CCDS, CCEB, CEE, CoB (NBS), CoE, EEE, HASS, LKCMedicine, MAE, MSE, NIE, SBS, SPMS, SSS, SoH, WKW SCI
#
# School Distribution Across Tutorial Groups:
#   ADM: 116 students across 78 tutorial groups
#   ASE: 104 students across 72 tutorial groups
#   CCDS: 702 students across 120 tutorial groups
#   CCEB: 465 students across 119 tutorial groups
#   CEE: 321 students across 112 tutorial groups
#   CoB (NBS): 793 students across 120 tutorial groups
#   CoE: 275 students across 105 tutorial groups
#   EEE: 788 students across 120 tutorial groups
#   HASS: 1 students across 1 tutorial groups
#   LKCMedicine: 83 students across 64 tutorial groups
#   MAE: 512 students across 120 tutorial groups
#   MSE: 156 students across 86 tutorial groups
#   NIE: 199 students across 93 tutorial groups
#   SBS: 302 students across 113 tutorial groups
#   SPMS: 276 students across 109 tutorial groups
#   SSS: 425 students across 119 tutorial groups
#   SoH: 332 students across 111 tutorial groups
#   WKW SCI: 150 students across 93 tutorial groups
#
# Sample Distribution (First 5 Tutorial Groups):
#   G-1:
#     ADM: 1 students
#     ASE: 1 students
#     CCDS: 5 students
#     CCEB: 1 students
#     CoB (NBS): 8 students
#     CoE: 3 students
#     EEE: 10 students
#     MAE: 4 students
#     MSE: 1 students
#     NIE: 1 students
#     SBS: 1 students
#     SPMS: 2 students
#     SSS: 5 students
#     SoH: 5 students
#     WKW SCI: 2 students
#   G-2:
#     ADM: 1 students
#     ASE: 1 students
#     CCDS: 7 students
#     CCEB: 6 students
#     CEE: 4 students
#     CoB (NBS): 4 students
#     EEE: 5 students
#     MAE: 3 students
#     MSE: 3 students
#     NIE: 2 students
#     SBS: 3 students
#     SPMS: 1 students
#     SSS: 4 students
#     SoH: 3 students
#     WKW SCI: 3 students
#   G-3:
#     ADM: 1 students
#     CCDS: 6 students
#     CCEB: 2 students
#     CEE: 6 students
#     CoB (NBS): 5 students
#     CoE: 3 students
#     EEE: 8 students
#     MAE: 7 students
#     MSE: 2 students
#     SPMS: 2 students
#     SSS: 2 students
#     SoH: 3 students
#     WKW SCI: 3 students
#   G-4:
#     ADM: 1 students
#     ASE: 1 students
#     CCDS: 5 students
#     CCEB: 7 students
#     CEE: 1 students
#     CoB (NBS): 9 students
#     CoE: 3 students
#     EEE: 6 students
#     LKCMedicine: 2 students
#     MAE: 4 students
#     MSE: 1 students
#     SBS: 2 students
#     SSS: 3 students
#     SoH: 3 students
#     WKW SCI: 2 students
#   G-5:
#     ADM: 1 students
#     ASE: 1 students
#     CCDS: 7 students
#     CCEB: 3 students
#     CoB (NBS): 10 students
#     CoE: 2 students
#     EEE: 8 students
#     LKCMedicine: 1 students
#     MAE: 2 students
#     MSE: 3 students
#     NIE: 1 students
#     SBS: 1 students
#     SPMS: 4 students
#     SSS: 3 students
#     SoH: 1 students
#     WKW SCI: 2 students
