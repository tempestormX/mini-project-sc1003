# %% [markdown]
# SC1003 Group 5 FDAB
# Mini Project Presentation

# %%
## 1. Overall interpretation of Task and Priorities ##

# %%
###1.1 Intrduction of Task###

# %%
###1.2 Thought Process and Computational Thinking Concepts Used + flowchart ###

# %%
###

# %%
##2. Creation of Dictionary ##

# %%
##3. ##Program to determine Average GPA in each group

# %%
##4. Gender diversity##

# %%
##5. Graphical representation of the results (Average GPA, Faculty Diversity)##
